# %%
# Imports

import pandas as pd
import numpy as np
from pprint import pprint
import re

# %%
# Import the data to dataframes

aacIn = pd.read_csv('../Data/Raw/Austin_Animal_Center_Intakes_20250419.csv')
aacOut = pd.read_csv('../Data/Raw/Austin_Animal_Center_Outcomes_20250419.csv')

# %% [markdown]
# Let's get the lay of the land, as they say.

# %%
# Headers--check them out
# First for aacIn (intakes)

aacIn.head()
# Out:
#   Animal ID    Name                DateTime     MonthYear  \
# 0   A521520    Nina  10/01/2013 07:51:00 AM  October 2013
# 1   A664235     NaN  10/01/2013 08:33:00 AM  October 2013
# 2   A664236     NaN  10/01/2013 08:33:00 AM  October 2013
# 3   A664237     NaN  10/01/2013 08:33:00 AM  October 2013
# 4   A664233  Stevie  10/01/2013 08:53:00 AM  October 2013
#
#                    Found Location Intake Type Intake Condition Animal Type  \
# 0         Norht Ec in Austin (TX)       Stray           Normal         Dog
# 1             Abia in Austin (TX)       Stray           Normal         Cat
# 2             Abia in Austin (TX)       Stray           Normal         Cat
# 3             Abia in Austin (TX)       Stray           Normal         Cat
# 4  7405 Springtime in Austin (TX)       Stray          Injured         Dog
#
#   Sex upon Intake Age upon Intake                         Breed         Color
# 0   Spayed Female         7 years  Border Terrier/Border Collie     White/Tan
# 1         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 2         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 3         Unknown          1 week        Domestic Shorthair Mix  Orange/White
# 4   Intact Female         3 years                  Pit Bull Mix    Blue/White

# %%
# Then for aacOut (outcomes)

aacOut.head()
# Out:
#   Animal ID       Name                DateTime MonthYear Date of Birth  \
# 0   A882831  *Hamilton  07/01/2023 06:12:00 PM  Jul 2023    03/25/2023
# 1   A794011      Chunk  05/08/2019 06:20:00 PM  May 2019    05/02/2017
# 2   A776359      Gizmo  07/18/2018 04:02:00 PM  Jul 2018    07/12/2017
# 3   A821648        NaN  08/16/2020 11:38:00 AM  Aug 2020    08/16/2019
# 4   A720371      Moose  02/13/2016 05:59:00 PM  Feb 2016    10/08/2015
#
#   Outcome Type Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0     Adoption             NaN         Cat    Neutered Male         3 months
# 1    Rto-Adopt             NaN         Cat    Neutered Male          2 years
# 2     Adoption             NaN         Dog    Neutered Male           1 year
# 3   Euthanasia             NaN       Other          Unknown           1 year
# 4     Adoption             NaN         Dog    Neutered Male         4 months
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix        Black/White
# 1              Domestic Shorthair Mix  Brown Tabby/White
# 2             Chihuahua Shorthair Mix        White/Brown
# 3                             Raccoon               Gray
# 4  Anatol Shepherd/Labrador Retriever               Buff

# %%
# Check out columns

aacIn.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Found Location',
#        'Intake Type', 'Intake Condition', 'Animal Type', 'Sex upon Intake',
#        'Age upon Intake', 'Breed', 'Color'],
#       dtype='object')

# %%
aacOut.columns
# Out:
# Index(['Animal ID', 'Name', 'DateTime', 'MonthYear', 'Date of Birth',
#        'Outcome Type', 'Outcome Subtype', 'Animal Type', 'Sex upon Outcome',
#        'Age upon Outcome', 'Breed', 'Color'],
#       dtype='object')

# %%
print(f'The Intakes dataset shape: {aacIn.shape}')
print(f'The Outcomes dataset shape: {aacOut.shape}')
# Out:
# The Intakes dataset shape: (173299, 12)
# The Outcomes dataset shape: (173078, 12)

# %%
aacIn.describe()
# Out:
#        Animal ID    Name                DateTime  MonthYear Found Location  \
# count     173299  123553                  173299     173299         173299
# unique    155805   29741                  119399        139          70010
# top      A721033    Luna  09/23/2016 12:00:00 PM  June 2015    Austin (TX)
# freq          33     760                      64       2189          31467
#
#        Intake Type Intake Condition Animal Type Sex upon Intake  \
# count       173299           173299      173299          173297
# unique           6               20           5               5
# top          Stray           Normal         Dog     Intact Male
# freq        118800           146790       94428           58825
#
#        Age upon Intake                   Breed        Color
# count           173298                  173299       173299
# unique              55                    3003          660
# top             1 year  Domestic Shorthair Mix  Black/White
# freq             28210                   33662        17930

# %%
aacOut.describe()
# Out:
#        Animal ID    Name                DateTime MonthYear Date of Birth  \
# count     173078  123540                  173078    173078        173078
# unique    155605   29688                  144670       139          8657
# top      A721033    Luna  04/18/2016 12:00:00 AM  Jun 2019    05/01/2016
# freq          33     756                      39      2244           121
#
#        Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# count        173032           79301      173078           173076
# unique           11              26           5                5
# top        Adoption         Partner         Dog    Neutered Male
# freq          84226           40250       94200            60693
#
#        Age upon Outcome                   Breed        Color
# count            173069                  173078       173078
# unique               55                    3002          662
# top              1 year  Domestic Shorthair Mix  Black/White
# freq              28670                   34037        17930

# %% [markdown]
# ### Checking Duplicates

# %%
# How many dupes do we have?

in_dupes = aacIn.duplicated(subset = ['Animal ID', 'DateTime', 'Animal Type', 'Name']).sum()
out_dupes = aacOut.duplicated(subset = ['Animal ID', 'DateTime', 'Animal Type', 'Name']).sum()

print(f'Duplicates in Intakes: {in_dupes}')
print(f'Duplicates in Outcomes: {out_dupes}')
# Out:
# Duplicates in Intakes: 42
# Duplicates in Outcomes: 26

# %% [markdown]
# There are very few duplicates, which is good. I think if the ID, date, name, and animal type match, they are reasonably full duplicates and can be dropped.

# %%
# Let's drop them

aacIn.drop_duplicates(subset=['Animal ID', 'DateTime', 'Animal Type', 'Name'], keep='first', inplace=True)
aacOut.drop_duplicates(subset=['Animal ID', 'DateTime', 'Animal Type', 'Name'], keep='first', inplace=True)

# %%
# Check it worked

in_new_dupes = aacIn.duplicated(subset = ['Animal ID', 'DateTime', 'Animal Type', 'Name']).sum()
out_new_dupes = aacOut.duplicated(subset = ['Animal ID', 'DateTime', 'Animal Type', 'Name']).sum()

print(f'Duplicates remaining in Intakes: {in_new_dupes}')
print(f'Duplicates remaining in Outcomes: {out_new_dupes}')
# Out:
# Duplicates remaining in Intakes: 0
# Duplicates remaining in Outcomes: 0

# %% [markdown]
# ### Animal ID

# %%
# Check out 'Animal ID' column for joining purposes

# Grabbing some variables to print
ids_in = len(aacIn['Animal ID'].unique())
ids_out = len(aacOut['Animal ID'].unique())

print(f'Number of unique Animal IDs in Intakes: {ids_in}')
print(f'Number of rows in aacIn: {aacIn.shape[0]}\n')

print(f'Number of unique Animal IDs in Outcomes: {ids_out}')
print(f'Number of rows in aacOut: {aacOut.shape[0]}\n')
# Out:
# Number of unique Animal IDs in Intakes: 155805
# Number of rows in aacIn: 173257
#
# Number of unique Animal IDs in Outcomes: 155605
# Number of rows in aacOut: 173052

# %% [markdown]
# There are fewer Animal IDs than rows in both datasets, and both datasets have different numbers of rows and IDs; this is likely because many of the animals from Intakes have not received an Outcome yet.

# %%
# There are fewer Animal IDs than rows in both datasets, and both datasets have different numbers of rows and IDs

print(f'There are {ids_in - ids_out} more unique Animal IDs in Intakes than Outtakes')
# Out:
# There are 200 more unique Animal IDs in Intakes than Outtakes

# %% [markdown]
# 200 more Animal IDs in aacIn than aacOut makes sense to me (it would indicate that there are 200 animals currently in the shelter).

# %%
# How many IDs are missing from each dataset, if any?

# Variables to print and reference

id_missing_in = aacIn['Animal ID'].isnull().sum()
id_missing_out = aacOut['Animal ID'].isnull().sum()

duped_ids_in = aacIn.duplicated(subset = 'Animal ID').sum()
duped_ids_out = aacOut.duplicated(subset = 'Animal ID').sum()

# Prints

print(f'There are {id_missing_in} missing IDs in Intakes.')
print(f'There are {id_missing_out} missing IDs in Outcomes.\n')
print(f'There are {duped_ids_in} IDs duplicated in Intakes')
print(f'There are {duped_ids_out} IDs duplicated in Outcomes')
# Out:
# There are 0 missing IDs in Intakes.
# There are 0 missing IDs in Outcomes.
#
# There are 17452 IDs duplicated in Intakes
# There are 17447 IDs duplicated in Outcomes

# %%
# Print rows with duplicated IDs

# Intakes

aacIn[aacIn.duplicated(subset = 'Animal ID', keep = False)].sort_values('Animal ID').head()
# Out:
#       Animal ID    Name                DateTime      MonthYear  \
# 22374   A006100   Scamp  12/19/2014 10:21:00 AM  December 2014
# 6926    A006100   Scamp  03/07/2014 02:26:00 PM     March 2014
# 75925   A006100   Scamp  12/07/2017 02:07:00 PM  December 2017
# 13576   A245945  Boomer  07/03/2014 05:55:00 PM      July 2014
# 29344   A245945  Boomer  05/20/2015 10:34:00 PM       May 2015
#
#                                       Found Location    Intake Type  \
# 22374              8700 Research Blvd in Austin (TX)  Public Assist
# 6926                    8700 Research in Austin (TX)  Public Assist
# 75925  Colony Creek And Hunters Trace in Austin (TX)          Stray
# 13576              Garden And Mildred in Austin (TX)          Stray
# 29344               7403 Blessing Ave in Austin (TX)          Stray
#
#       Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 22374           Normal         Dog   Neutered Male         7 years
# 6926            Normal         Dog   Neutered Male         6 years
# 75925           Normal         Dog   Neutered Male        10 years
# 13576           Normal         Dog   Neutered Male        14 years
# 29344           Normal         Dog   Neutered Male        15 years
#
#                         Breed         Color
# 22374    Spinone Italiano Mix  Yellow/White
# 6926     Spinone Italiano Mix  Yellow/White
# 75925    Spinone Italiano Mix  Yellow/White
# 13576  Labrador Retriever Mix           Tan
# 29344  Labrador Retriever Mix           Tan

# %%
# Outcomes

aacOut[aacOut.duplicated(subset = 'Animal ID', keep = False)].sort_values('Animal ID').head()
# Out:
#        Animal ID    Name                DateTime MonthYear Date of Birth  \
# 150493   A006100   Scamp  03/08/2014 05:10:00 PM  Mar 2014    07/09/2007
# 132575   A006100   Scamp  12/07/2017 12:00:00 AM  Dec 2017    07/09/2007
# 74205    A006100   Scamp  12/20/2014 04:35:00 PM  Dec 2014    07/09/2007
# 118420   A245945  Boomer  07/04/2014 03:26:00 PM  Jul 2014    05/23/2000
# 90873    A245945  Boomer  05/25/2015 11:49:00 AM  May 2015    05/23/2000
#
#            Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 150493  Return to Owner             NaN         Dog    Neutered Male
# 132575  Return to Owner             NaN         Dog    Neutered Male
# 74205   Return to Owner             NaN         Dog    Neutered Male
# 118420  Return to Owner             NaN         Dog    Neutered Male
# 90873          Transfer         Partner         Dog    Neutered Male
#
#        Age upon Outcome                   Breed         Color
# 150493          6 years    Spinone Italiano Mix  Yellow/White
# 132575         10 years    Spinone Italiano Mix  Yellow/White
# 74205           7 years    Spinone Italiano Mix  Yellow/White
# 118420         14 years  Labrador Retriever Mix           Tan
# 90873          15 years  Labrador Retriever Mix           Tan

# %% [markdown]
# It appears that duplicated Animal IDs are likely the result of the same animal coming into or out of the shelter multiple times. To deal with this, I think I will have to do a merge connecting Intake and Outcome dates as closely as possible for each animal.

# %%
# Strip white spaces, in case there are any

aacIn['Animal ID'] = aacIn['Animal ID'].str.strip()
aacOut['Animal ID'] = aacOut['Animal ID'].str.strip()

# %% [markdown]
# ### Column Names

# %%
# I will standardize the style of column names for convenience and ease of use

aacIn = aacIn.rename(columns = {"Animal ID" : "AnimalID", "DateTime" : "IntakeDT", "Found Location" : "FoundLocation", "Intake Type" : "IntakeType", 
                                "Intake Condition" : "IntakeCondition", "Animal Type" : "AnimalType", "Sex upon Intake" : "IntakeSex",
                                "Age upon Intake" : "IntakeAge"})
aacOut = aacOut.rename(columns = {"Animal ID" : "AnimalID", "DateTime" : "OutcomeDT", "Date of Birth" : "BirthDate", "Outcome Type" : "OutcomeType",
                                  "Outcome Subtype" : "OutcomeSubtype", "Animal Type" : "AnimalType", "Sex upon Outcome" : "OutcomeSex", 
                                  "Age upon Outcome" : "OutcomeAge"})

# %% [markdown]
# ### Nulls

# %%
# Check for nulls

print(f'Nulls in the Intakes dataset:\n', aacIn.isnull().sum(), sep = "")
print()
print(f'Nulls in the Outcomes dataset:\n', aacOut.isnull().sum(), sep = "")
# Out:
# Nulls in the Intakes dataset:
# AnimalID               0
# Name               49740
# IntakeDT               0
# MonthYear              0
# FoundLocation          0
# IntakeType             0
# IntakeCondition        0
# AnimalType             0
# IntakeSex              2
# IntakeAge              1
# Breed                  0
# Color                  0
# dtype: int64
#
# Nulls in the Outcomes dataset:
# AnimalID              0
# Name              49533
# OutcomeDT             0
# MonthYear             0
# BirthDate             0
# OutcomeType          46
# OutcomeSubtype    93762
# AnimalType            0
# OutcomeSex            2
# OutcomeAge            9
# Breed                 0
# Color                 0
# dtype: int64

# %% [markdown]
# Given that most of the nulls are in Names and columns that are independent between datasets, I think I can deal with nulls after the join.

# %% [markdown]
# ### Datatypes

# %%
print('Intakes:\n', aacIn.dtypes, sep = "")
print()
print('Outcomes:\n', aacOut.dtypes, sep = "")
# Out:
# Intakes:
# AnimalID           object
# Name               object
# IntakeDT           object
# MonthYear          object
# FoundLocation      object
# IntakeType         object
# IntakeCondition    object
# AnimalType         object
# IntakeSex          object
# IntakeAge          object
# Breed              object
# Color              object
# dtype: object
#
# Outcomes:
# AnimalID          object
# Name              object
# OutcomeDT         object
# MonthYear         object
# BirthDate         object
# OutcomeType       object
# OutcomeSubtype    object
# AnimalType        object
# OutcomeSex        object
# OutcomeAge        object
# Breed             object
# Color             object
# dtype: object

# %% [markdown]
# Most of these columns are and should be objects, but DateTime and MonthYear should be DateTime objects, and age should likely be an integer or float column. Eventually, we may want to codify some of these categories, particularly the Sex and Animal Type columns.

# %% [markdown]
# ### Datetimes

# %%
# Transform IntakeDT and OutcomeDT to datetimes

aacIn['IntakeDT'] = pd.to_datetime(aacIn['IntakeDT'], format = "%m/%d/%Y %I:%M:%S %p")
aacOut['OutcomeDT'] = pd.to_datetime(aacOut['OutcomeDT'], format = "%m/%d/%Y %I:%M:%S %p")

# Check that it worked

print(f'IntakeDate is now a {aacIn['IntakeDT'].dtype} datatype.')
print(f'OutcomeDate is now a {aacOut['OutcomeDT'].dtype} datatype.')
# Out:
# IntakeDate is now a datetime64[ns] datatype.
# OutcomeDate is now a datetime64[ns] datatype.

# %%
# I don't really need the "MonthYear" column, as I can just extract the month and year now from those datetime values

aacIn = aacIn.drop(columns = 'MonthYear')
aacOut = aacOut.drop(columns = 'MonthYear')

# Check that it did indeed work...

print(aacIn.columns)
print(aacOut.columns)
# Out:
# Index(['AnimalID', 'Name', 'IntakeDT', 'FoundLocation', 'IntakeType',
#        'IntakeCondition', 'AnimalType', 'IntakeSex', 'IntakeAge', 'Breed',
#        'Color'],
#       dtype='object')
# Index(['AnimalID', 'Name', 'OutcomeDT', 'BirthDate', 'OutcomeType',
#        'OutcomeSubtype', 'AnimalType', 'OutcomeSex', 'OutcomeAge', 'Breed',
#        'Color'],
#       dtype='object')

# %% [markdown]
# ## More Column Examination
#
# #### Independent (non-duplicated) columns

# %% [markdown]
# ### IntakeType

# %%
print(aacIn['IntakeType'].value_counts())
# Out:
# IntakeType
# Stray                 118785
# Owner Surrender        35453
# Public Assist          10392
# Wildlife                6463
# Abandoned               1900
# Euthanasia Request       264
# Name: count, dtype: int64

# %% [markdown]
# There are only 6 categories, with no mistypes or significant outliers. I think these are pretty good categories to work with.

# %% [markdown]
# ### IntakeCondition

# %%
print(aacIn['IntakeCondition'].value_counts())
# Out:
# IntakeCondition
# Normal        146754
# Injured        10755
# Sick            7920
# Nursing         3878
# Neonatal        1917
# Medical          596
# Aged             524
# Other            353
# Pregnant         155
# Feral            144
# Med Attn          86
# Behavior          79
# Unknown           46
# Med Urgent        20
# Neurologic        13
# Parvo              7
# Space              4
# Agonal             4
# Panleuk            1
# Congenital         1
# Name: count, dtype: int64

# %% [markdown]
# These I think I can definitely consolidate, to get rid of the outliers with just a few entries and group categories that represent similar conditions together for clarity and simplicity.

# %%
# Dictionary to map original intake conditions to condensed categories: 
# Normal, Injured, Sick, Medical, Neonatal, Nursing, Pregnant, Aged, Behavior, Feral, Other

conditions = {
    "Normal": "Normal", # Including specifying those columns I would like to leave as-is
    "Injured": "Injured",
    "Sick": "Sick",
    "Medical": "Medical", 
    "Med Attn": "Medical",
    "Med Urgent": "Medical",
    "Neurologic": "Medical", # Likely refers to neurological conditions, which will fall under Medical
    "Parvo": "Medical", # Refers to an illness especially common among puppies; I'm actually surprised there were so few in this category
    "Panleuk": "Medical", # Panleukemia, also a medical illness
    "Agonal": "Medical", # Refers to a dying creature; it is a severe condition, but there were only 4 in this category, I will change it to medical
    "Congenital": "Medical", # Likely refers to a genetic condition or disability--medical
    "Neonatal": "Neonatal",
    "Nursing": "Nursing",
    "Pregnant": "Pregnant",
    "Aged": "Aged",
    "Behavior": "Behavior",
    "Feral": "Feral",
    "Other": "Other",
    "Unknown": "Other",
    "Space": "Other" # I believe this refers to an animal being transferred between shelters relating to lack of space; 
                        # why it is here, I do not know
}

# Apply mapping to the 'Intake Condition' column

aacIn['IntakeCondition'] = aacIn['IntakeCondition'].map(conditions)

# %%
# Check that this worked

aacIn['IntakeCondition'].value_counts()
# Out:
# IntakeCondition
# Normal      146754
# Injured      10755
# Sick          7920
# Nursing       3878
# Neonatal      1917
# Medical        728
# Aged           524
# Other          403
# Pregnant       155
# Feral          144
# Behavior        79
# Name: count, dtype: int64

# %% [markdown]
# Seems to have worked perfectly!

# %% [markdown]
# ### FoundLocation

# %% [markdown]
# Despite being extra information and possibly interesting to evaluate, this column is just not within the scope of this project; so, we will drop it.

# %%
# Drop

aacIn = aacIn.drop(columns = 'FoundLocation')

# %%
# Check, as always

aacIn.columns
# Out:
# Index(['AnimalID', 'Name', 'IntakeDT', 'IntakeType', 'IntakeCondition',
#        'AnimalType', 'IntakeSex', 'IntakeAge', 'Breed', 'Color'],
#       dtype='object')

# %% [markdown]
# ### OutcomeType

# %% [markdown]
# I suspect this will be similar to IntakeType; let's take a look

# %%
print(aacOut['OutcomeType'].value_counts())
# Out:
# OutcomeType
# Adoption           84214
# Transfer           48499
# Return to Owner    25629
# Euthanasia         10766
# Died                1663
# Rto-Adopt           1236
# Disposal             872
# Missing               92
# Relocate              28
# Stolen                 5
# Lost                   2
# Name: count, dtype: int64

# %% [markdown]
# A few of these stand out. "Rto-Adopt" seems odd, since "Return to Owner" is already a category, and "Disposal" is...odd, considering "Euthanasia" and "Died" are both already categories of their own. My suspicion is that it refers to Euthanasia indirectly. "Relocate" seems very similar to "Transfer", and the other three ("Missing", "Stolen", and "Lost") can likely be grouped into one category.

# %%
# First, combine "Rto-Adopt" and "Return to Owner"

aacOut.loc[(aacOut['OutcomeType'] == 'Rto-Adopt'), 'OutcomeType'] = 'Return to Owner'

# Check

aacOut['OutcomeType'].value_counts()
# Out:
# OutcomeType
# Adoption           84214
# Transfer           48499
# Return to Owner    26865
# Euthanasia         10766
# Died                1663
# Disposal             872
# Missing               92
# Relocate              28
# Stolen                 5
# Lost                   2
# Name: count, dtype: int64

# %% [markdown]
# I am uncertain about "Disposal," though I expect it to be an alternate wording for "Euthanasia." I will check by first evaluating the timestamps for the two labels (the thought behind this is that possibly the wording could have changed for or at some point in time). If the times do not greatly overlap, it is almost certainly just a rewording.

# %%
# Grab the year values for each as variables

disposal_years = aacOut.loc[(aacOut['OutcomeType'] == 'Disposal'), 'OutcomeDT']
euth_years = aacOut.loc[(aacOut['OutcomeType'] == 'Euthanasia'), 'OutcomeDT']

# What years do each category fall within?

print(f'"Disposal" was used during the years: {sorted(disposal_years.dt.year.unique())}')
print(f'"Euthanasia" was used during the years: {sorted(euth_years.dt.year.unique())}')
# Out:
# "Disposal" was used during the years: [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
# "Euthanasia" was used during the years: [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]

# %% [markdown]
# Both have been used throughout the dataset, it appears. I will investigate OutcomeSubtype for the answer to this question.

# %%
print(aacOut['OutcomeSubtype'].value_counts())
# Out:
# OutcomeSubtype
# Partner                40247
# Foster                 17851
# Rabies Risk             4891
# Suffering               4123
# Snr                     4078
# SCRP                    3208
# Out State                931
# In Kennel                868
# Aggressive               612
# Offsite                  512
# In Foster                416
# Medical                  353
# At Vet                   352
# Field                    242
# Behavior                 176
# Enroute                  112
# Court/Investigation      100
# Emergency                 53
# Underage                  37
# In Surgery                33
# Customer S                20
# Prc                       20
# Possible Theft            16
# Barn                      16
# In State                  12
# Emer                      11
# Name: count, dtype: int64

# %%
# Lots of options there. Let's see which ones correspond with "Euthanasia" and "Disposal"

# Which correspond with euthanasia?

print(aacOut.loc[(aacOut['OutcomeType'] == 'Euthanasia'), 'OutcomeSubtype'].value_counts())
# Out:
# OutcomeSubtype
# Rabies Risk            4839
# Suffering              4123
# Aggressive              612
# Medical                 353
# At Vet                  240
# Behavior                176
# Court/Investigation     100
# Underage                 37
# Name: count, dtype: int64

# %%
# And which correspond with disposal?

print(aacOut.loc[(aacOut['OutcomeType'] == 'Disposal'), 'OutcomeSubtype'].value_counts())
# Out:
# OutcomeSubtype
# Rabies Risk    52
# Name: count, dtype: int64

# %% [markdown]
# There we go! "Rabies Risk" appears in both groups (in fact, it is the only one to appear with disposal), and is a pretty obvious cause for euthanasia. I'd say it's safe to consider "Disposal" a subset of "Euthanasia". Let's combine the two.

# %%
# Map "Disposal" to "Euthanasia"

aacOut.loc[(aacOut['OutcomeType'] == 'Disposal'), 'OutcomeType'] = 'Euthanasia'

# Check our work, as always

print(aacOut['OutcomeType'].value_counts())
# Out:
# OutcomeType
# Adoption           84214
# Transfer           48499
# Return to Owner    26865
# Euthanasia         11638
# Died                1663
# Missing               92
# Relocate              28
# Stolen                 5
# Lost                   2
# Name: count, dtype: int64

# %%
# "Relocate" seems awfully similar to "Transfer". Let's look at Subtypes again to make sure.

print('The "Relocate" Outcome Subtypes are ' + str(aacOut.loc[(aacOut['OutcomeType'] == 'Relocate'), 'OutcomeSubtype'].unique()))
print('The "Transfer" Outcome Subtypes are ' + str(aacOut.loc[(aacOut['OutcomeType'] == 'Transfer'), 'OutcomeSubtype'].unique()))
# Out:
# The "Relocate" Outcome Subtypes are [nan]
# The "Transfer" Outcome Subtypes are ['Partner' 'Snr' 'SCRP' 'Out State' 'Barn' 'In State' 'Emer']

# %% [markdown]
# That wasn't as helpful as I had hoped, but I do think that "Relocate" should be combined with "Transfer".

# %%
# Combine "Relocate" to "Transfer"

aacOut.loc[(aacOut['OutcomeType'] == 'Relocate'), 'OutcomeType'] = 'Transfer'

# Check

print(aacOut['OutcomeType'].value_counts())
# Out:
# OutcomeType
# Adoption           84214
# Transfer           48527
# Return to Owner    26865
# Euthanasia         11638
# Died                1663
# Missing               92
# Stolen                 5
# Lost                   2
# Name: count, dtype: int64

# %%
# Finally, compiling the last 3 into "Missing"

aacOut.loc[(aacOut['OutcomeType'] == 'Stolen'), 'OutcomeType'] = 'Missing'
aacOut.loc[(aacOut['OutcomeType'] == 'Lost'), 'OutcomeType'] = 'Missing'

# Check, yet again

print(aacOut['OutcomeType'].value_counts())
# Out:
# OutcomeType
# Adoption           84214
# Transfer           48527
# Return to Owner    26865
# Euthanasia         11638
# Died                1663
# Missing               99
# Name: count, dtype: int64

# %% [markdown]
# I think that's it for the OutcomeTypes! There are 6 remaining categories, and they feel to me distinct and specific. On to Subtypes!

# %% [markdown]
# ### OutcomeSubtype

# %%
# What are we looking at?

print(aacOut['OutcomeSubtype'].value_counts())
# Out:
# OutcomeSubtype
# Partner                40247
# Foster                 17851
# Rabies Risk             4891
# Suffering               4123
# Snr                     4078
# SCRP                    3208
# Out State                931
# In Kennel                868
# Aggressive               612
# Offsite                  512
# In Foster                416
# Medical                  353
# At Vet                   352
# Field                    242
# Behavior                 176
# Enroute                  112
# Court/Investigation      100
# Emergency                 53
# Underage                  37
# In Surgery                33
# Customer S                20
# Prc                       20
# Possible Theft            16
# Barn                      16
# In State                  12
# Emer                      11
# Name: count, dtype: int64

# %% [markdown]
# First, I remap Subtypes that are obviously abbreviations or similar, using common shelter industry terms.

# %%
# Snr -> Shelter Neuter Return (for clarity)

aacOut.loc[(aacOut['OutcomeSubtype'] == 'Snr'), 'OutcomeSubtype'] = 'Shelter Neuter Return'

# SCRP -> Scratched Person

aacOut.loc[(aacOut['OutcomeSubtype'] == 'SCRP'), 'OutcomeSubtype'] = 'Scratched Person'

# Emer -> Emergency

aacOut.loc[(aacOut['OutcomeSubtype'] == 'Emer'), 'OutcomeSubtype'] = 'Emergency'

# Out State -> Out of State

aacOut.loc[(aacOut['OutcomeSubtype'] == 'Out State'), 'OutcomeSubtype'] = 'Out of State'

# Prc -> Pet Resource Center

aacOut.loc[(aacOut['OutcomeSubtype'] == 'Prc'), 'OutcomeSubtype'] = 'Pet Resource Center'

# %%
# Check that everything is in order and worked

print(aacOut['OutcomeSubtype'].value_counts())
# Out:
# OutcomeSubtype
# Partner                  40247
# Foster                   17851
# Rabies Risk               4891
# Suffering                 4123
# Shelter Neuter Return     4078
# Scratched Person          3208
# Out of State               931
# In Kennel                  868
# Aggressive                 612
# Offsite                    512
# In Foster                  416
# Medical                    353
# At Vet                     352
# Field                      242
# Behavior                   176
# Enroute                    112
# Court/Investigation        100
# Emergency                   64
# Underage                    37
# In Surgery                  33
# Customer S                  20
# Pet Resource Center         20
# Possible Theft              16
# Barn                        16
# In State                    12
# Name: count, dtype: int64

# %% [markdown]
# Now I will explore some of the less clear ones to double check that they have been translated correctly and make sure that they do indeed warrant their own category.

# %%
# Scratched Person subtype

print(aacOut.loc[(aacOut['OutcomeSubtype'] == "Scratched Person"), 'OutcomeType'].unique())
# Out:
# ['Transfer']

# %% [markdown]
# Since Austin is an almost-entirely kill-free city, transferring animals that normally would be euthanized probably makes the most sense as a second resort. I think this is likely the right interpretation of "SCRP".

# %%
# Out of State subtype

print(aacOut.loc[(aacOut['OutcomeSubtype'] == "Out of State"), 'OutcomeType'].unique())
# Out:
# ['Transfer']

# %% [markdown]
# That subtype refers only to the Transfer outcome, which makes sense.

# %%
# What does "In Kennel" refer to?

print(aacOut.loc[(aacOut['OutcomeSubtype'] == "In Kennel"), 'OutcomeType'].unique())
# Out:
# ['Died' 'Missing']

# %% [markdown]
# I see why they would want to keep track of these events happening within the kennel, but it doesn't particularly help us get to our goal.

# %%
# Aggressive?

print(aacOut.loc[(aacOut['OutcomeSubtype'] == "Aggressive"), 'OutcomeType'].unique())
# Out:
# ['Euthanasia']

# %%
# Enroute?

print(aacOut.loc[(aacOut['OutcomeSubtype'] == "Enroute"), 'OutcomeType'].unique())
# Out:
# ['Died' 'Missing']

# %% [markdown]
# Same deal as "In Kennel". It makes sense that this was kept track of, but I'm not sure how helpful it will be.

# %%
# Field

print(aacOut.loc[(aacOut['OutcomeSubtype'] == "Field"), 'OutcomeType'].unique())
# Out:
# ['Return to Owner']

# %%
# Change that to "In Field" for my own sake

aacOut.loc[(aacOut['OutcomeSubtype'] == 'Field'), 'OutcomeSubtype'] = 'In Field'

# %%
# What is "Customer S"?

print(aacOut.loc[(aacOut['OutcomeSubtype'] == "Customer S"), 'OutcomeType'].unique())
# Out:
# ['Return to Owner']

# %% [markdown]
# That clarified nothing. I think I'll leave it for now and investigate it some more later. "Customer Service," perhaps? Or "Customer Support?"

# %%
# I suspect "Barn" refers to barn cats or a barn cat program. Let's see.

print(aacOut.loc[(aacOut['OutcomeSubtype'] == "Barn"), 'OutcomeType'].unique())
print(aacOut.loc[(aacOut['OutcomeSubtype'] == "Barn"), 'AnimalType'].value_counts())
# Out:
# ['Transfer' 'Adoption']
# AnimalType
# Cat    15
# Dog     1
# Name: count, dtype: int64

# %% [markdown]
# Likely but again not fully clear; I will leave this for EDA research.

# %% [markdown]
# I'm going to be leaving the rest of this column alone, since the categories are quite specific and circumstantial.

# %% [markdown]
# There are a significant number of null values in this column; it may eventually be dropped, but for now I will leave it alone.

# %% [markdown]
# ### BirthDate

# %%
# Take a look

print(aacOut['BirthDate'].value_counts())
# Out:
# BirthDate
# 05/01/2016    121
# 05/05/2014    120
# 04/21/2014    117
# 09/01/2015    117
# 04/20/2015    108
#              ...
# 05/10/2004      1
# 08/03/1998      1
# 10/23/2001      1
# 04/08/2001      1
# 01/16/2025      1
# Name: count, Length: 8657, dtype: int64

# %%
# What does this look like in the dataset?

print(aacOut[['AnimalID', 'Name', 'BirthDate']].head())
# Out:
#   AnimalID       Name   BirthDate
# 0  A882831  *Hamilton  03/25/2023
# 1  A794011      Chunk  05/02/2017
# 2  A776359      Gizmo  07/12/2017
# 3  A821648        NaN  08/16/2019
# 4  A720371      Moose  10/08/2015

# %% [markdown]
# So this actually does comprise of dates, which means I probably will leave it alone. I suspect I will need to change the datatype though...

# %%
print(f'"BirthDate" is a(n) {aacOut['BirthDate'].dtypes}.')
# Out:
# "BirthDate" is a(n) object.

# %%
# Convert to a datetime object

aacOut['BirthDate'] = pd.to_datetime(aacOut['BirthDate'], format = "%m/%d/%Y")

# %%
# Check our work, as always

print(f'"BirthDate" is a(n) {aacOut['BirthDate'].dtypes}.')
# Out:
# "BirthDate" is a(n) datetime64[ns].

# %%
aacOut['BirthDate'].head()
# Out:
# 0   2023-03-25
# 1   2017-05-02
# 2   2017-07-12
# 3   2019-08-16
# 4   2015-10-08
# Name: BirthDate, dtype: datetime64[ns]

# %% [markdown]
# ## Columns Duplicated Between Datasets

# %% [markdown]
# ### Name

# %% [markdown]
# #### Intakes

# %%
# How many names are we looking at?

print(len(aacIn['Name'].unique()))
# Out:
# 29742

# %%
# That's not quite 170,000. Let's see how many are just unnamed

print(aacIn['Name'].isnull().sum())
# Out:
# 49740

# %%
# Still not quite adding up. How many are duplicated?

print(aacIn['Name'].duplicated().sum())
# Out:
# 143515

# %%
# Uh-huh. I suppose that's where they all are.
# Duplicated names are fine, though, since we're not using this as a merge column or for any real analysis.
# Let's preview some names

names_full = aacIn['Name'].unique().tolist()
for name in names_full:
    print(name)
# Out:
# Nina
# nan
# Stevie
# *Donnie
# Pippin
# Sylvio
# Claire
# Heather
# *Petunia
# *Bismark
# *Mason
# *Dixon
# *Asti
# *Kochka
# *Grace
# Buffy
# Cate
# Moose
# Estrella
# Lucio
# Sera
# Mcdermot
# *Pogo
# Coco
# Jade
# Otter
# Juliet
# Sugar
# Daisy
# *Trevor
# *Romeo
# *Juliet
# *Paris
# *Mercutio
# *Tybalt
# *Benvolio
# *Taylor
# *Tyler
# *Doc
# *Happy
# Neville
# Annabelle
# *Tiny
# *Sneezy
# Bruce
# *Romo
# Lizzy
# Chan
# Zoe
# Suzie Q
# Honey
# Boris
# *Eloise
# Ned
# *Wilbur
# Zuzu
# Angie
# *J
# *Trey
# Butter
# Lillian
# Zooe
# *Miso
# *Elvira
# *Frisco
# Elvis
# Tazz
# Ziggy
# Jewels
# Azul
# Frosty
# *Lula Belle
# Deeohhgee
# Cowboy
# Gotti
# Zeus
# *Halloween
# October
# *Birch
# Chevy
# *Aries
# *Poodle
# Raisin
# Miley
# Chewey
# Serenity
# Walter
# Amie
# *Harry
# *Beth
# *Daisy
# Simba
# Canelo
# Spot
# Missy
# Batty
# *Sunshine
# Wyatts
# *Candy Corn
# Sebastian
# *Tudor
# Brownie
# *Riley
# Roxie
# Pumpkin
# Baby
# Jumper
# Diesle
# Poe
# Miss Kitty
# Carlos
# *Edgar
# Raven
# Bandit
# *Jesse
# Bosco
# *Broadway
# *Arthur
# Charley
# Costello
# *Peaches
# *Chris Angel
# Nikole
# *Nikko
# *Hercules
# *Teddy
# Dahlia
# Charcoal
# Gypsy
# *Flower
# T-Che
# Mittens
# Matilda
# Pearl
# *Dancer
# Travis
# *Allie
# *Gizzmo
# *Franklin
# *Sarah
# Zane
# Chloe
# Sable
# Cheddar
# *Graham
# *Lucy
# Rocky
# *Magic
# Glinda
# Diesel
# *Angel
# Avery
# Madeline
# Jj
# Baby Girl
# *Finn
# *Cake
# *Clover
# *Crimson
# *Joanna
# Azula
# Katniss
# Happy
# Maximus
# Phoebe
# Duke
# Dante
# Kiki
# Bella
# Yogi
# Max
# Ottis
# Lola
# Remi
# Manda
# Bert
# Twilight
# Jax
# Sesame
# Rufus
# *Bubbles
# *Roxy
# *Penny
# *Spunky
# *Button
# Ryder
# Kyrie
# Chiquilla
# Ellie
# Diva
# Muffin
# Nikii
# Blue
# Kane
# Grunt
# Scooter
# Rosco
# *Starla
# Tank
# Black
# Beau
# *Pammy
# Vegas
# Netty
# Sierra
# Lucas
# Puddles
# *Smurfy
# Juanito
# *Casey Jones
# Moon Shadow
# Bobby
# Yoda
# Sandy
# Annie
# Willow
# *Minerva
# Ruby
# *Andy
# Perrito
# Oscar
# Jo
# Kira
# Lily
# Scout
# Red
# Avalon
# Perla
# *Scottie
# Roscoe
# Buddy
# *Emmaline
# Apollo
# Dexter
# Jake
# Jezzabelle
# *Bruce
# Leroy
# *Harvey
# Ibu
# Malika
# Princess
# Andie
# Delilah
# *Blackberry
# Banjo
# Reesie
# Pooffy
# Gunner
# *Marcos
# Remmy
# *Charlie
# Momma
# Jack
# *Chelsea
# Angel
# Harley
# *Shadow
# Pollydoodle
# Melady
# Tulley
# Lincoln
# *Stubbs
# *Andante
# *Harmony
# *Adelaide
# *Melody
# Gucci
# Boo Boo
# *Jack
# Tasha Yar
# *Whit
# *Frosty
# Rock
# Archer
# *Lacey
# Truman
# *Lucille
# *Leland
# *Billy
# Brutus
# Coal
# Emily
# Zilla
# Tornado
# Jolene
# Titi
# *Lydia
# Tango
# Autumn
# Levi
# *Carl
# *Joe
# Jordan
# *Heidi
# *Janie
# Rusty
# Patch
# *June
# Sherlock
# Watson
# *Gatsby
# *Minkus
# Boss
# *Xenia
# Olive
# *Ollie
# *Zelda
# Chico
# Bucky
# Lucy
# Dody Becerra
# Minnie
# Casper
# Esperanza
# Molly
# *Gia
# *Gretel
# *Taco
# Harvey
# Billy
# *Zane
# *Midge
# Charlie
# *Silkie
# Rebel
# Ringo
# Filina
# *Henry
# *Phoenix
# *Big Otis
# Lucky
# Frijolito
# *Cloe
# *Ebbie
# Chester
# Seymour
# Mack Mack
# *Zach
# *Jester
# Laika
# Tequila
# *William
# *Leo
# Fuzzyball
# Mei Mei
# *Winnie
# Twinkle
# *Alice
# *Figgy
# Tifa
# Toby
# Chako
# D.O.G.
# G.O.D.
# *Austin
# *James
# *Jeffie
# *Lylah
# Star
# Hercules
# Pepper
# Nacho
# Sheba
# *Lucky
# *Fritz
# Bruno Beau
# Prof Griffin
# Doogle
# Sasha
# Mommas
# Pookie
# Cookie
# Baby Kitty
# *Amber
# Bear
# Buck
# *Loralinda
# Chiko
# Heidi
# *Red
# Cevrus
# *Marty
# *Levi
# *Cody
# Loki
# Gigi
# Spots
# *Millard
# *Missy
# *Mary
# *Moe
# *Milo
# Gretsch
# Katie
# *Klaus
# *Barsby
# Pony Boy
# Peaches
# Katrina
# Champ
# *Frank
# Ralphie
# *Howie
# *Helen
# *Bell
# *O'Malley
# Paddy
# Billy Jean
# Brittney
# *Rita
# Buzz
# George
# *Adele
# Hershey
# Oreo
# Cosita
# Josie
# *Willie
# Pascal
# Crixus
# Thor
# Lorenzo
# Maxwell
# Winston
# Baby Elic
# Shadow
# Skipper
# Cora
# Diamond
# Tootsie
# *Sadie
# Jackson
# *Hardy
# *Stan
# *Freckles
# *Vince
# Amalia
# *Ginger
# Gaspar
# Dior
# *Toffee
# Afton
# *Matilda
# *Tilly
# *Rasmussen
# Chicle
# *Lonnie
# Crickett
# Mariah
# Dot
# Marley
# Sox
# *Rosie
# Jet
# Maya
# *Guthrie
# Salsa
# Latte
# *Joey
# Alex
# Lady
# Fayah
# Jessie
# Jerry
# Wednesday
# *Birdie
# Prince
# Tabby
# Kurt
# Izzy
# Barrett
# Chuy
# Flynn
# Sailor
# *Johnny
# *So
# *Piglet
# *Kanga
# *Helio
# Leeloo
# *Luke
# *Hubert
# Oberon
# Damon
# *Sampson
# Dillon
# Keishla
# Bleu
# Habanero
# Ginger
# Maxi
# Bejon
# Cashew
# Eric
# The Admiral
# Bevo
# Mariposa
# *Jock
# *Jezzy
# *Nelson
# Taz
# Indica
# Oliver
# Neron
# *Maybelle
# *Juno
# *Hawkeye
# *Trapperjohn
# *Betty
# Haven
# *Barney
# *Freddie
# *Bam Bam
# Boo
# Candy
# Trick
# Treat
# Maddie
# Polly
# Spark
# Mickey
# Anabel
# Aquiles
# Misty
# Moebius
# Cactus
# Betsy
# Walter White
# Hootie
# Khaleesi
# Collins
# Silka
# *Gilligan
# Manny
# Dora
# *Emmie
# *Dexter
# *Hubble
# *Topher
# Nena
# *Steve
# *Meek
# *Bert
# *Ernie
# *Izzy
# Lorelei
# Tito
# Samson
# *Molly
# *Thauti
# Tesla
# *Khaleesi
# Bratt
# Oso
# Monty
# Mikey
# *Lissa
# *Mouse
# Marbles
# Nutmeg
# Snowball
# Cinnimen
# Itzie
# Floppy
# Lupe
# *Aggie
# *Billy Bob
# Bobbi Joe
# Atticus
# Skyler
# Iggy
# Bud
# *Suki
# Cinabun
# Pickles
# Tiki
# *Dee Dee
# *Cotton
# *Candy
# *Honeybear
# Buttercup
# *Terry
# *Timmy
# *Cheddar
# *Aztec
# *Marvin
# Fifi
# Terrance
# Lilly
# Romeo
# Malibu
# *Pixie Stick
# Pavlov
# King
# Abby
# Cognac
# Mona
# *Stoli
# Brooke
# *Alix
# Snickers
# *Dora
# Isabella
# Baby Boy
# Buffi
# Susie
# Sydney
# Chuck
# Pixie
# *Dahlia
# Rudy
# Randee
# Amadeus
# *Mortisha
# Marie
# *Baxter
# Pivo
# Pup
# Julia
# *Chris
# *Patty
# *Pete
# *Ringo
# Poptart
# Dylan
# *Bozo
# *Tulip
# *O. Henry
# *Petey
# *Perla
# Precious
# Bridget
# Zoey
# *Mitzi
# Xica
# Major
# Fred
# *Gladys
# *Alexander
# *Olga
# *Jackie
# Emo
# Patches
# Fridy Katy
# *Bow
# Porter
# Leia
# *Alana
# *Hazel
# Maggie
# Lulu
# *Yoshi
# *Durango
# Ethel
# Gabriel
# Gus
# G-Unit
# *Fiona
# Hawk
# Copy Cat
# Woodrow
# Ziven
# *Arnold
# Blues
# Davy
# *Dolly
# Grant
# *Jodie
# *Alita
# *Alley
# *Precious
# *Pluto
# *Nightshade
# *West
# *Ria
# Africano
# Disciple
# *Cooter
# Brittle
# Squirt
# Blou
# Leela
# Porky
# Cormac
# Chubbs
# Checkers
# Apple
# Mocha
# Jewel
# Kief
# Mistic
# Luna
# Bean
# Rifle
# Blaze
# Smokey
# *Marla
# *Sebastian
# Tripp
# Talulah
# Hank
# *Chase
# *Wiley
# Joey
# *Willow
# *Markie
# *Benjamin
# *Lionel
# Lobo
# Zelda
# Copper
# Panda
# *Wilson
# Junior
# Rocket
# *Mark
# *Mike
# *Carson
# *Cassie
# *Carter
# *Rusty
# *Maggie
# *Pat
# Twin
# Nala
# Neko
# Winne
# Jabon
# Mila
# *Moomoo
# Beya
# Evelyn
# Kitty
# Micki
# Manchitas
# Poppy
# *Cydney
# Gomita
# John
# *Sophie
# *Sunny
# Brandy
# Spaz
# Ices
# Quattro
# *Lihue
# Jasper
# Suki
# *Jenna
# Tart
# Zuko
# *Dirk
# Puma
# *Nick Fury
# *Agentcolson
# Scruffie
# Pickle
# Frenchie
# Blake
# Bowser
# Waffles
# Trixie
# Robin Hood
# Little John
# *Jim
# *Jil
# *Jackson
# *Juliep
# Spooky
# Sabrina
# Gillian
# Ace
# Harper
# *Kento
# *Ryo
# *Rowen
# *Cye
# Willy
# Ranger
# Ariel
# *Jill
# Kirby
# Maggie Mae
# Adam
# *Tom
# *Jerry
# Tucker
# Capone
# Fourty
# Dallas
# *Possum
# Tanner
# Pugsly
# Sprinkles
# Midnight
# Subie
# Brolli
# Nappa
# Mort
# Rue
# Maja
# Tyoma
# Roo
# Satie
# Larue
# Tex
# *Shy Boy
# Gizmo
# Rosie
# *Ivan
# *Mister
# *Kiwi
# *Gwynnie
# Cece
# Blackie
# Rex
# *Scruffy
# Deacon
# *Faith
# Petey
# *Buster
# Foster
# *Doodlebug
# Tiny
# *Leroy
# *Sugar
# *Spice
# Kilo
# *Lou
# Paige
# Guy
# Doggie
# *Bonnie
# *Clyde
# Lana
# *Samson
# *Tillie
# *Saxton
# Ladybird
# *Tobias
# Jones
# Jazz
# *Twinkle
# *Sparkle
# *Diamond
# *Malachi
# Knox
# *Sybil
# Weto
# *Eleanor
# Nan
# Dixie 2
# Bobo
# Sophie
# *Emmit
# Dottie
# *Mimi
# Ash
# *Murphy
# *Beau
# Sparkle
# *Jasmine
# *Sen
# Sonja
# Magneto
# Chiquita
# Spencer
# *Monty
# *Pearl
# Twinkie
# Gracie
# Sofia
# Jinx
# U
# Blanca
# Wiggles
# Mya
# Rafa
# *Barnaby
# Fina
# Lizzard
# Fumanchu
# Pretty Boy
# Chase
# Bailey
# Ferdinand
# *Cher
# *Mcneal
# Tony
# Frankie
# Sonny
# Gage
# Domino
# *Chloe
# *Clint
# Sassy
# Little Bit
# *Elroy
# Isabelle
# Homer
# Chelsie
# Linda
# Gordo
# Lexy
# Leyla
# *Liberty
# Cosette
# Darla
# August
# Pandora
# Bumper
# Nano
# *Spearmint
# *Peppermint
# Pinto
# Spice
# Starr
# Pablo
# Dixie
# *Nitro
# Willie
# Pinky
# Grey
# Ruby Lee
# Litle Girl
# *Ava
# *Shasta
# Gatsby
# Shadowfax
# Butters
# Keilo
# Tiger
# Bruno
# *Wilma
# *Angie
# *Jess
# *Puffball
# *Orson
# Lamb Chop
# Milo
# Rhino
# Beaux
# *Sonia
# Zooey
# Archie
# Bambi
# Bishop
# Lotus
# Holiday
# *Emily
# Martini
# Amber
# Bones
# Blade
# Ami*
# *Niles
# *Diego
# *Shelby
# Sammy Pants
# Skittle
# Viper
# Springdale
# *Millie
# Samantha
# *Minnie
# *Milton
# *Marcus
# *Mila
# Chewie
# Salem
# *Dorian
# Layla
# *Snickers
# Faye
# *Allaster
# Peewee
# Manolo
# Jay Jay
# Rocco
# Tater Tot
# Bootsy
# *Gigglez
# *Friskey
# Firecat
# Elvin
# *Lambchop
# *Wyatt
# *Jenny
# *Clairees
# Stella
# *Gable
# Miss Black
# Hazel
# Elaina
# Bosha
# *Crystal
# *Alex
# *April
# Dolly
# *Darwin
# Neeko
# *Cruiser
# *Hobb
# Tuna
# Dietz
# *Max
# Blanco
# Ivy
# Alie
# *Moby
# Tyson
# *Bear
# *Forest
# *Fox
# *Franka
# *Violet
# Nikki
# Chica
# Krypto
# Patience
# Egypt
# Pie De Choco
# Fire
# Roxy
# Floyd
# Murphy
# Hudson
# Amy
# *Sparrow
# *Jules
# *Betsy
# Faith
# Ghost
# Josh
# Stray-38
# Pansy
# Cindy
# *Dobby
# Opossum
# *Jack Frost
# *Ghost
# *Snowbelle
# Cocoa
# *Andie
# *Zenia
# *Timber
# Pigui
# Churaca
# Trouble
# Lance
# *Pink
# *Liza
# Ice
# Barry
# Sly
# Gwen
# Tj
# *M Aybelle
# Stripe
# Tolouse
# Cat 1
# Jesse
# Sam
# Pasco
# Chocolate
# Osa
# *Chipmunk
# *Julian
# Conan
# *Marlin
# Riley
# Gidget
# *Bambi
# Dakota
# Ricky
# *Juliette
# *Ralph
# *Jordan
# *Izz
# *Snuffy
# Aidan
# Moira
# Pristy
# Otto
# *Olivia
# Gabby
# Casey
# Kimbo
# Athena
# Galadriel
# Pez
# Acorn
# Oden
# Ophelia
# Mango
# Ashley
# Sohpie Jean
# Vienna
# Bolt
# Mosley
# Lacey
# Shelby
# *Chip
# *Herbie
# *Jake
# *Nina
# Elizabeth
# *Ella
# *Smokey
# Huckleberry
# Amaranth
# Bob
# *Andre
# Tiger Lilly
# Danika
# Mina
# Dizzy
# Jo-Jo
# Logan
# Mozart
# Silver
# Brodie
# Buddha
# Felix
# *Mia
# *Jeff
# Bohdi
# Mouse
# *Donald
# *Goofy
# *Parcheesi
# *Bingo
# Jojo
# *Trixie
# Trudy
# Tommy
# *Azure
# Meerka
# Michaelangel
# *Sable
# *Squirrel
# Finn
# *Casper
# Yeti
# Tigger
# Inie
# Mini
# Mo
# Bubbles
# *Gabby
# *Monkey
# Fido
# Callie
# Toothless
# *Sherlock
# *Cricket
# Ethyl
# *Lulu
# *Bella
# Miles
# Cassie
# *Ruby
# Binx
# *Simon
# *Garfunkel
# Mia
# Double
# *Jelly
# *Pancho
# Captain
# Pokey
# Decker
# *China Berry
# Simon
# Timmy
# Rockstar
# Ruth
# *Marcia
# *Tildee
# Delores
# *Aqua
# *Neeko
# Bullet
# *Wendy
# *Fara
# *Tigger
# Pancho
# Jason
# Beanie
# *Sasha
# *Tiny Tim
# Chewy
# *Princess
# Belle
# Tigre
# Bingo
# *Arya
# Wiz
# Ava
# Boomer
# Woody
# *Athos
# *Aramis
# *Porthos
# Molahkia
# Anne Bonnie
# Freddie
# Stark
# *Piper
# *Jasper
# Depot
# *Rosco
# Arthur
# *Caramel
# Mika
# Miki
# Sara
# *Gidget
# Desi
# *Jonathon
# *Huey
# *Louie
# *Stewie
# Sylvester
# *Sweet Dee
# *Brea
# Emma
# Mesa
# *Squeaky
# *Nettie
# Clarence
# Sadie
# *Cocoa
# Smitty
# *Jones
# Sammie
# Promise
# Pup Pup
# Hunny
# Bo
# Vader
# Xochitl
# *Thumper
# *Sailor
# *Cecily
# *Suloni
# Lily Pearl
# *Nikki
# Seisha
# Tres
# Harry
# Cali
# *Pechula
# *Peony
# Caesar
# Two Face
# Bettie
# Kit Tay
# *Grizz
# Garfield
# Peluchin
# *Leif
# Rascal
# *Jingle
# *Sir Thomas
# Olympus
# *Speedygonz
# *Veruca
# Chato
# *Blinky
# *Preston
# Diego
# Chief
# Macho
# *Gaby
# *Posie
# Norbert
# Canela
# Herby
# *Bells
# Jingles
# *Hayden
# Mello
# Cupcake
# Will
# Rosalie
# *Sparky
# Kaua'I
# Rain
# Bebop
# Sugar Baby
# Chino
# Pierre
# Abbey
# Cooper
# *Kevin
# Gonzo
# *Moses
# Anna
# *Gracie
# *Lovie
# 010314
# Goofy
# *Josie
# *Jennie
# *Striker
# Moonie
# *Pepper
# *Dark Knight
# *Casanova
# Bonnie
# *Christmas
# *Callie
# *Pookie
# *Skipper
# Alley
# Chichi
# Big Mack
# Goldie
# Kooli
# *Iris
# Wrigley
# Scotch
# Chikis
# *Amy
# *Meg
# *Jo
# *Silver
# *Mikey
# *Molly Blue
# Louie
# Mary
# Kaya
# Odin
# *Junebug
# *Treasure
# Skips
# Little Girl
# Arctic
# *Zoe
# *Elinor
# *Margaret
# *Eeyore
# Rye
# Alana
# *Justin
# Beemo
# Puffy
# Presley
# Vince
# Jago
# *Chester
# *Nemo
# *Emma
# *Pilgrim
# *Miles
# *Lilah
# *Sammy
# Seth
# Ohana
# Sparky Rex
# Clover
# *Littlejerry
# *Nathan
# Jameson
# *Blossom
# Rory
# Navi
# Worf
# Peanutbutter
# Getzy
# Melly
# Yankeedoodle
# Henry Jones
# Buddah
# Fozzy
# Kanga
# *Joc
# *Paige
# Panger
# Gaby
# Mimi
# Nuno
# Kuki
# *Bishop
# *Pumpkin
# *Sissy
# *Biscuit
# *Gabe
# *Gigi
# *Tufty
# *Jade
# Buster
# *Gilly
# Minzi
# Gee
# *Trinity
# *Albert
# *Miriam
# Primor
# Dee Dee
# *Dreyfus
# *Dori
# Florence
# Chai
# Dickens
# Narley
# Ella
# Pio
# Bree
# *Jason
# Andy
# *Blue Bell
# Queenie
# Shy-Anne
# Duncan
# Lightining
# *Pollie
# Barko
# Cujo
# Luther
# *Tabo
# Crystal
# *Etta
# Austin
# *Caleb
# Tinkerbell
# *Corky
# Zeva
# Jazzy
# *Norma Jean
# *Minne
# Struggle
# Brandie
# Emerald
# *Kimby
# *Lisa
# Bumble
# *Kitty
# *Simba
# Benny
# *Sandy
# Harmony
# Mabel
# *Kesha
# Moses
# Django *Dj*
# Chap
# Oppa
# Kiko
# Cream
# Savannah
# Mollie
# *Colonel
# Darwin
# Lewis Batman
# Sparky
# Santa Girl
# Nyxie
# *Gus
# *Holly
# Hugo
# Juju
# Satan/Ebony
# *Tina
# Cesar
# Puppy
# Nevaeh
# Big Boy
# Bebe
# *Annie
# Fender
# Dash
# *Owen
# Hilary
# Miller
# *Anatoly
# Bird
# *Stevie
# *Nite
# *Sally
# *Sam
# Crush
# Fenrir
# Chaser
# *Ciara
# Cindi Lou
# Camilla
# *Wags
# Tika
# Kathy
# Tupelo
# *Scrappy
# Bodi
# Luno
# Frassina
# Redford
# Calka
# *Ram
# General
# *O'Hara
# *Scarlett
# Fredo
# Peanut
# Eubie
# Mama
# Elmer
# Cleo
# Kona
# *Casey
# *Joy
# Macie
# Scottie
# Achilles
# *Eli
# Cash
# *Rex
# Violet
# Sawyer
# *Tony
# *Buddy
# Rufuss
# *Warner
# *Mars
# *Mona
# Snkaefarm
# Ricardo
# Motya
# Lolys
# Jorge
# Peanut Siete
# *Garcia
# *Ricky
# *Hershey
# *Juneau
# Kj
# Kora
# Maria
# *Madison
# Brie
# Ceelo
# Eberhart
# *Hector
# Pally
# *Vega
# *Hoop
# *Myrtle
# *Harvest
# *Koda
# Rodeo
# Berdie
# Frenchy
# Fitz
# Harris
# Babaloo
# *Sophia
# Fluffy
# *Tomatillo
# Juliette
# *Marble
# Holly
# Sweetie
# Joe
# Bambina
# Taquita
# Chique
# *Bonita
# Bodhi
# Hansel
# *Guapo
# *Dottie
# *Hope
# *Gabriel
# *Bloo
# *Eedo
# Indigo
# *Comet
# *Noelle
# *Cupid
# *Cinnamon
# *Sage
# *Venus
# *Twiggy
# *Tiger
# *Dasher
# *Pushkin
# *Sinatra
# Mr Pink
# *Rosemary
# *Lily
# Powder
# Elephant
# Prof Butters
# *Gizmo
# Mario
# Baby Doll
# *Reese
# Zoey Beth
# Sam Buster
# *Ginny
# *Cooper
# *Primo
# Pinguena
# *Star
# Jinxy
# Jenny
# *Mr. Pepper
# Love
# Cassiel
# Snicker
# Forest
# Chucho
# Elsie
# Sopi
# Ember
# Barley
# *Shiloh
# Snoopy
# Penny
# *Brandy
# Lila
# Randy Quaid
# *May
# *Linux
# Chris
# *Akon
# Scrufty
# Tinkle
# Remy
# *Blue
# Biggy Smalls
# Carrie
# *Mercedes
# T.J.
# Napoleon
# Rita
# Marga
# *Lucas
# Reece
# *Madeleine
# Baxter
# *Blitzen
# Moe
# *Rocky
# *Drake
# *Glenda
# *Ice
# *Travis
# Brewster
# Negra
# Opal
# Sunshine
# Vana White
# Davidson
# Greta
# Skye
# *Suzanne
# Kong
# *Parker
# Luckey
# *Brandi
# *Danny
# Middie
# Zeebee
# *Indigo
# Vincent
# Benji
# Betty
# *Flufferkins
# Jasmine
# *Thelonious
# Will Jr.
# Rainey
# *St. Nicks
# Flash
# Piper
# Gibson
# Dumpling
# Skippy Jon
# Valentine
# Suzi
# *Kringle
# Snow White
# Rigbee
# Mike
# Pete
# *Katie
# *Seamus
# Ford
# Jethro
# Axel
# Sofie
# Sally
# Pearly
# Viola
# Darma
# Hero
# Nicky
# Enrico
# Lark
# Sascha
# Maddi
# Leader
# Noel
# Seamus
# Finch
# Merle
# Jumo
# Mufasa
# Rudolph
# Lillie
# Sa
# *Matthew
# *Shrek
# Candy 2
# *Pop-Tart
# Lanni
# Lightning
# *Abby
# Dutchess
# Javi
# Daniel Leon
# Chance
# Fatboy
# White Girl
# Zahrah
# Rapunzel
# *Prince C.
# Blitz
# Prissy
# Spartacus
# *Grandy
# *Hayes
# Coop
# Bell
# *Oreo
# *Prince
# *Roscoe
# *Charming
# Boudreaux
# *Velvet
# *Perfect
# *Turner
# Maui
# Halo
# Jesse James
# *Daniel
# Amelia
# Peyton
# Vixen
# Chicharin
# *Q
# Benjaman
# Maruka
# *Martin
# *Nelly
# Skippy
# *Russell
# Nevins
# *Luna
# *Natasha
# Lea
# *Winston
# Baylah
# *Atticus
# *Xavier
# Roxi
# Lordrassilon
# Rafiki
# Calderono
# Finnegan
# Lacy
# Ally
# Hunter
# Seis
# *Calypso
# *Echo
# Pulguso
# Nita
# Chula
# Lluvia
# Bartleby
# Lele
# *Dudley
# *Cliff
# 621869
# Chipper
# Luke
# Scruffy
# Barca
# Zorro
# Celste
# Gil
# *Bijou
# Rickie
# Capitan
# Joanna
# Sagan
# Dream
# Zena
# *Mini Mouse
# Niko
# Stoli
# Jacob
# *Pickles
# Fiona
# Rico Suave
# King Richard
# Kano
# Turbo
# *Caddie
# Susan
# Moog
# Dobie
# Stephanie
# Appie
# Tabbie
# *Robbie
# Nugget
# *Ashleigh
# Freckles
# *Churley
# Einstein
# Kluts
# Cha Cha
# Holly Berry
# Cinnamon
# *Clarissa
# Tynan
# *Pongo
# *Priscilla
# Deuce
# *Peanut
# Wiley
# Espana
# Bongo
# Mamma Mia
# Pinta
# Deliah
# Pork Chop
# *Rose
# *Captin
# *Junie
# Asher
# Aussimoon
# *Marguerite
# Kahlua
# Scampi
# Ollie
# *Rudy
# Sampson
# Alfred
# Maddox
# Ginger Peace
# Marmalade
# Kiowa
# Charli
# Equinox
# Rio
# Tilly
# Kimchi
# Rocko
# Shades
# Norman
# Kato
# Snookie
# Kiara
# Sarsa
# Paloma
# Zara
# Thomas
# *Kelsie
# Killer
# Reese
# Lesser
# *Lina
# *Kitten
# Biscuit
# Percy
# Juice
# Mugen
# *Ash
# *Lee
# Waffle
# *Uhmi
# *Bunny
# *Amélie
# *Evie
# *Gimpy Cb
# Huck
# Capo
# Maynard
# Mercedes
# Beagle
# Theodore
# Dale
# Frank
# Marshall
# *Taffy
# Scuffy
# *Checkers
# Hannibal
# Sissy
# Lala
# Chaka
# Moonshine
# Zooley
# Carly
# Porkchop
# Waylon
# *Peach
# *Ariel
# *Toonces
# *Tigra
# *Lola
# Trigger
# *Tucker
# Lee
# Marina
# *Kid
# Mellow
# Migas
# Black Jack
# Nickles
# Tuck
# *Boxer
# *Uma
# *Ulrika
# *Uliana
# *Ursula
# *Ulysses
# *Bandit
# Maeve
# Skip
# *Melvin
# *Nick
# Cuatemo
# Becky
# Hawkeye
# Nikita
# *Clifford
# Manchas
# *Morris
# Quico Kico
# *Catie
# Grayc
# River
# *Chowder
# *Lotusblosso
# Susie Q
# Aurora
# Aquarius
# Marlee
# Harlan
# J C
# *Baby
# *Martty
# *Guinness
# *Harper
# Ebenezer
# *Mack
# Plex
# Driscol
# Elsa
# Kila
# Cloud
# *Colt
# Sweeney Todd
# *Lorna
# Sunny Bunny
# Stacy
# Dobby
# Allie
# Linus
# Dino
# Sirius
# *Annalea
# Cuervo
# *Tara
# *Kim
# Josephine
# *Firefly
# Nix
# *Wayne
# Jagger
# Onix
# Bobby Lee
# Dos
# Tugga
# T Rex
# Zeke
# Daise
# Millie
# Nikko
# Peluche
# Ernie
# Alexandra
# *Alvin
# *Olive
# *Zeppo
# Manuka
# *Grover
# Rowdy
# Kimmie
# Doofy
# Ferguson
# *Poppy
# Budgie
# Orion
# Quixote
# *Emery
# *Yeti
# Cho-Cho
# Scooby
# Scarlett
# Koda
# Muneca
# *Greta
# Princessa
# Cat
# Chata
# *Kayla
# Benson
# *Holland
# *Chinook
# *Marissa
# Lady Isis
# Gracie Bear
# Neymar
# Lady White
# *Hersheys
# Tiny Louise
# *Bibble
# Roxxy
# *Cuddles
# *Anthony
# *Edith
# *Maya
# Rodney
# *Judge
# *Stanley
# *Lassie
# *Dennis
# Kyla
# Passion
# *Cherry
# Pinguis
# Whisky
# Satchmo
# *Da Vinche
# *Frida
# Palomo
# G Money
# Starbuck
# Puppies
# Buoy
# Barnaby
# *Giselle
# Salvadore
# *Pippa
# Skyla
# Mo Cuishle
# Swiffer
# Kitty Girl
# Beans
# Sinatra
# Chispita
# Nomen
# *Henry Ford
# *Connie
# Victoria
# *Martial
# Rose
# China
# Piaf
# Gideon
# Sedona
# Hotpocket
# Doughie Bear
# *Frances
# Theloneous
# Pacino
# *More
# *Toney
# *Tim
# Ripley
# Hardware
# Piet
# *Mickey
# Siren
# *Cupcake
# *Hannah
# Curlytail
# Trixi
# Pippa
# *Lillian
# *Darla
# Milly
# Nemo
# *Alfalfa
# *Haley
# *Fairbanks
# Best Friend
# *Spanky
# Judge Judy
# *Archie
# Poncho
# Bebee
# Thunderdog
# Miss Piggy
# Duffus
# Lorenza
# Asawan
# *Kalee
# Peludita
# Pandita
# Leslie
# Queen
# *Boone
# *Tomas
# *Ricki
# Skeeter
# Kitten
# Grumpo
# *Mika
# *Regina
# *Maddie
# *Edie
# *Katina
# *Kenny
# Elphaba
# Chuey
# *Princeton
# Lauttie
# *Dingo
# Peanut Butte
# Titus
# *George
# *Martha
# *Cinder
# Rosalee
# Chona
# Sid
# Snowflake
# Monster
# Mint
# Judah
# Echo
# Traveler
# Sweetie Pie
# Cain
# *Sitka
# Trina
# *Maestro
# *Desi
# *Hammy
# Grace
# Beauty
# Jaxson
# Riker
# Sheila
# Nelson
# Laurel
# Hardy
# Nod
# Roswell
# *Apollonia
# Riley Mae
# *Baron
# Abra
# *Eliza
# *Mackenzie
# *Colton
# Spartus
# Brisco
# Buckley
# *Mr Fabulous
# Beethoven
# Clyde
# *Toby
# Mischief
# *Anders
# *Hansel
# Liam
# *Hank
# *Angelina
# Noodles
# Matty
# Spotty
# Amanda
# Jules
# *Paully
# Milhouse
# Pitufo
# Nestle
# Rj
# Tragen
# Ashes
# Storm
# *Curtis
# *Isabella
# *Ferdinand
# *Cinnabun
# Nuka
# *Nevil
# Pequena
# Truffles
# Dirty
# Trudge
# *Bianca
# Brick
# Muñeca
# Zaih
# *Chevy
# Martin
# Bueller
# Dragon
# Kyu
# London
# *Katniss
# *Pinto Bean
# *Tommy
# Missty
# Dekota
# Lupe Fleasco
# Osita
# Adrian
# Kentucky
# *Stella
# Zion
# Whiskey
# Nibbles
# Gregory
# Cotton
# *Cohen
# *Freddy
# *Frannie
# *Freya
# *Jessie
# Fletcher
# Mitchell
# Thelonious
# Vivica
# Kayna
# Italia
# *Muffin
# Sadee Lynn
# Fredrick
# Chanel
# Quick
# *Peking
# *Jojo
# Zimm
# *Chiko
# *Thunderkit
# Lefty
# *Bobby
# Godiva
# Susey
# Cody
# *Rob
# *Lexi
# Ina
# Duchess
# Riggs
# Polo
# Alice
# Magnus
# *Jimmy
# *Newton
# *Marie
# Ron Weasley
# Cupulin
# Lonestar
# Tootles
# Mcnugget
# *Woody
# *Bo Peep
# *Buzz
# *Gina
# L.A.
# Obi
# Nana
# *Oscar
# Brian
# Boni
# Dum Dum
# Buster G
# Flower Pot
# *Ray
# *Little Bit
# *Rich
# *Matty
# Jesus
# *Dewey
# *Davey
# Dynamite
# Webster
# *Francie
# Han Solo
# *Twiggie
# Winnie
# *Tonka
# Lyle
# Tiger Lou
# Dolly Lou
# Wedo
# *Tosca
# *Tesla
# *Tristan
# Vivian
# Little Boy
# Milky
# Alabama
# Cell
# Mayhem
# *Homer
# *Dorito
# Pablito
# *Lovey
# Arenal
# Guerra
# Oddy
# *Butter
# Sweetheart
# Grayson
# Elmo
# Shaq
# Skittles
# Paris
# Sheldon
# Chalky
# Sweet Pea
# Artemis
# *Salty
# Fergus
# *Wesley
# Ein
# Remus
# Olaf
# Abbie
# *Silvermist
# *Chedder
# Siegfried
# Starbucks
# Mallo
# *Frankie
# Enrico Furmi
# Mowgli
# Jude
# Kayla
# Isis
# *Ladybug
# Roman
# Morena
# *Janna
# *Savannah
# *Dominick
# Figaro
# Cj
# Zip
# Natasha
# Chalmers
# Sophia
# *Polly
# *Felicity
# *Dusty
# Bowie
# Pom Pom
# Karma
# Xander
# *Larry
# *Rainer
# *Belinda
# *Shep
# Chikita
# Bebie
# *Peter
# Crash Davis
# *Tito
# Hildago
# *Sofia
# Whiskers
# Chuckie
# Giselle
# Bannon
# *Rasputin
# Zephyr
# *Bogo
# *Benson
# Arya
# Dukey
# Ethal
# *Dynamite
# Harriet
# *Munchkin
# Chomper Jr
# Sage
# Osiris
# Mac
# Bro
# Taffy
# Razor
# Oriel
# Pancha
# Tammie
# Pup 6M
# Frodo
# Ted
# Heater
# *Toughguy
# Wilson
# Cane
# Rush
# *Hopscotch
# *Chuck
# Paco
# *Toasty
# Chupychu
# Torque
# Hemi
# Weenie
# Chonchi
# Catman
# *Marcopolo
# *Kaley
# Eli
# Ruffles
# Zena Susi
# Rambo
# *Dice
# *Bob Barker
# *Jax
# Freya
# Rufus Jenkin
# Prince Dubbi
# Marshmallow
# Cheeto
# Day
# Ten
# Dell
# *Steven
# Crusher
# Loretta
# Luca
# June
# *Sprinkle
# *Andi
# Aiden
# Mocho
# *Robbin
# *Daffy
# Onyx
# *Kirby
# Frances
# *Magpie
# Moki
# Shippo
# Krash
# *Annabell
# Hera
# Sullivan
# Kinda
# Beauby
# Jezebel
# *Shellby
# *Dixie
# Miche
# *Elvis
# Lavender
# Velcro
# *Lady
# Eva
# Chelsea
# Mugzi
# *Kelly
# Twitch
# Matt
# Toto
# O'Malley
# *Beauty
# Noname
# Nitro
# Hambone
# Ebee
# *Walterwhite
# Babe
# Maite
# Rider
# Rowan
# Sofi
# Puchi
# Fritz
# Dixon
# Pitachio
# *Dutchess
# Boly
# Juno
# Sophie*
# *Duke
# Madaket
# Luz
# Jumbo
# Puff
# Gallium
# Maximiliano
# Mitten
# Blue Jeans
# *Bastian
# Lil Baby
# Sneezy
# *Allison
# Cherry
# *Fantine
# Billie Jean
# Spike
# *Julius
# *Pedro
# *Babs
# *Faye
# *Magnolia
# Bogie Motors
# *Aspen
# *Hickory
# *Chestnut
# *Nutmeg
# Cochise
# Lizzie
# Lil Dude
# *Spartacus
# *Huckleberry
# Freyja
# *Dude
# *Sly
# Mandy
# *Vaughn
# *Lilly
# Dosha
# Temple
# Aiko
# Aster
# Monroe
# Kb
# *Caliopy
# Kiss
# *Grady
# *Vera
# *Batgirl
# *Spiderman
# Olive Hoover
# Shelley
# *Merry
# *Marvin Gaye
# Biggie
# *Mindy
# *Beckham
# *Bullet
# *Jj
# Bucket
# Zeda
# *Matt
# *Slippers
# Debo
# Trevor
# *Ransom
# *Jack Black
# Bentley
# Teri
# Yayo
# *Bubba
# Leelo
# Leo
# Zilkie
# Pilar
# Ziegen
# *Oliver
# Owen
# *Goldie
# Lolo
# Dorian
# Myles
# Glory
# *Bernie
# Noah
# *Bosley
# *Christoff
# Delgado
# Munecca Meoe
# Ben
# Buca
# Spudz
# Stella 4
# *Curious
# Tella
# *Apollo
# Reed
# Choko
# Shatu
# *Sochi
# Sonny Boy
# Morgan
# *Katja
# Shaila
# *Roman
# Astro
# Thaktar
# *Mishka
# *Jane
# *Truffle
# *Penny Sue
# *Moonbeam
# Aries
# Wally
# Pennie
# Cookies
# *Tater
# *Alaska
# Begheera
# *Cornelius
# Nancy
# *Vespa
# Keiser Soze
# Ian
# Buttons
# Shiner
# Penny Lane
# Penelope
# *Pony Girl
# Lisa
# *Micah
# *Jefferson
# *Panda
# Trippy
# Scamper
# Jimi
# Sapphire
# Mattie
# Lil Behr
# *Tigress
# Kaira
# Mellie
# *Quest
# Jeeves
# Ophye
# *Binks
# Brayson
# Ruger
# Essie
# Mira
# Tabitha
# *Gibbs
# Nino
# *Nadia
# Maton
# Swisher
# Kennex
# Delta
# Shiloh
# Venom
# *Lazaro
# *Coal
# Tuxedo
# Scrappy
# Irma
# Gary
# Carl
# Eve
# Miloe
# Whopper
# Perlita
# Booker
# Barack
# Patrick
# Reg
# Xena
# Bj
# *Lanie
# *Tessa
# Miracle
# Skillet
# *Soze
# *Denali
# Allen
# Boy Named Su
# Mama Dog
# *Joseph
# *Winifred
# Gizzard
# Chanfle
# Calliope
# Bubba
# *Topper
# Little One
# *Bond
# Buggsy
# Sonic
# *Garnet
# Coketa
# Dejah
# *Pi
# *Scout
# Masy
# *Nero
# *Charlotte
# *Harrison
# *Tinsel
# Bently
# *Vigo
# *Beatrice
# *Trini
# Lovie
# B.G.
# Sussy
# Calie
# Sugar Bella
# *Daisy Mae
# *Dandy
# Monkey
# *Ronnie
# *Dana
# *Misty
# *Katy
# Canella
# Mckitty
# Bidz
# *Claudius
# Ruexb
# Cataleya
# Seven
# Whisper
# *Ciroc
# Rutherford
# Timmie
# Tundra
# *Potato
# Bessy
# Aria
# Hannah
# Brinn
# *Lestat
# *Samuel
# Ares
# *Bo
# Danny
# Bonnie P.
# Herman
# Tera
# Pikachu
# Batter
# Flor
# *Amos
# Batman
# Opie
# Phelix
# Faleas
# Helen
# *Axel
# Scooby Doo
# Bam Bam
# Sexy
# *Benji
# *Joplin
# Snowy
# Allonsdanser
# *Mcenroe
# Alvin
# Titan
# Elli
# Haley
# Tracker
# *Titus
# Ajax
# Chulo
# *Mizzou
# Otis
# *Mac
# Kip
# Rico
# Shiba
# Clifford
# *Lucinda
# Gitzo
# Higgs
# Kobe
# Zillah
# Izabella
# Wilma
# Tonka
# Stich
# Cue
# *White Snake
# *Briggs
# Cassandra
# Kiska
# Shaye
# Cruz
# Tails
# Paul
# *Dr. Dog
# Odessa
# Marfa
# Ooli
# Nikola
# *Pharaoh
# Doc
# Scrapper
# Obama
# Mordey
# *Ponyboy
# *Madeline
# *Charisma
# Sachi
# Capulin
# *Beanie
# Tut
# *Starry
# *Bailey
# Amir Dunmore
# *Emmitt
# *Monte
# Fancy
# *Parvati
# Gisselle
# Loulou
# Shtinker
# Razz
# Muneco
# *Marius
# *Norman
# Ozziepawsbor
# *Leah
# Lili
# Pichin
# Mr. Johnson
# *Snuggles
# Reagan
# *Esme
# *Sky
# Dub
# Bryson
# Chauncey
# *Honey
# *Ron
# Kiwi
# *Severus
# *Tippy
# *Mutny
# *Sara
# *Seth
# Grover
# Gorgeous
# Bruiser
# Spanky
# *Steamer
# *Thoth
# *Trinket
# Blue Eyes
# Dori
# *Sherman
# Dewey
# *Edward
# *Onyx
# Shruffy
# Weda
# The Captain
# Bacardi
# Wolf
# Mamba
# Papi
# *Effie
# *Jhonny
# *Prim
# *Eddie
# Curly
# *Shamrock
# *Pam
# Bully
# *Jolene
# *Roy
# Glitzy
# *Alistair
# *Bill
# *Eric
# Gertrude
# Pedro
# Yeller
# *Evelyn
# *Osiris
# *Colby
# *David
# *Pandora
# *Jacob
# *Ducky
# *Penelope
# *Percy
# Reggie
# Rascel
# *Armand
# Sky
# Scamp
# Ladybug
# *Tabitha
# *Merrick
# *Julia
# *Belle
# Boz
# *Rowan
# *Michael
# *Carlotta
# Myrtle
# Justin
# Idgie
# *Creamsicle
# Zak
# Papuchon
# Dio
# Stoops
# Prieto
# *Sookie
# Joel
# *Nefertiti
# Pya
# Brynn
# *Isis
# Kevin
# *Nighthawk
# *Anubis
# Popcorn
# *Hermione
# Enzo
# Piglet
# Kibbles
# *Rick
# *Fluff
# *Akhom
# *Akori
# *Dakota
# *Renee
# Elise
# *Bravo
# Boots
# *Quinn
# Widow
# *Mustard
# Moon
# *Rosalie
# *Newt
# Nahti
# Aspen
# *Blackbird
# Bonita Bubbl
# Arnie
# *Fred
# Carrott
# Clint
# *Shadie
# *Nicholas
# *Momba
# Xeon
# Bandido
# Ruilo
# Pulgi
# *Gage
# July
# Hoss
# Tom
# Dane
# Shorty
# Lover
# *Delilah
# *Hugh
# *Payton
# Russell
# *Jessica
# Jackie
# *Neville
# Bogey
# *Leonard
# *Demetri
# *Seymore
# *Hedwig
# Calypso
# Romy
# Champs
# Reana
# Renji
# Mr.Giggles
# *Beans
# Peeves
# Tinka
# Donut
# Gitzy
# Lou
# Grizzly
# *Spencer
# Tatiana
# *Nilla Bean
# Miny
# Skinny Pete
# *Theo
# V
# *Chico
# Wyatt
# Maudie
# Yager
# *Santino
# Shrekann
# Chokolate
# *Gibson
# Sirus
# Toast
# *Buffy
# *Amelia
# Newton
# Mr Puppy
# *Santiago
# Shakira
# Sparkles
# Winslow
# *Hailey
# *Sheila
# *Albus
# *Daphne
# *Darby
# Gretchen
# Gringo
# *Claude
# Roja
# Starla
# Yuri
# Hanna
# Ambrot
# *Gloria
# Yum Yum
# Lilith
# *Percival
# *Francine
# Marble
# Cornelius
# Cru
# Mala
# Boti
# Inca
# *Balsamic
# Bago
# Pachuco
# Monte
# Littletyrone
# *Ayla
# *Barbara
# *Byron
# *Gerald
# Vitruvius
# Robert
# Lady Bug
# *Treble
# Gambit
# Slumber
# Siesta
# Martha
# Truly
# Mundo
# Leelou
# Chichio
# Sarah
# Douglas
# Rangerrick
# Kola
# Lencho
# Chip
# Cami
# Franklin
# Castiel
# Sir Winsor
# Koko
# Jazzper
# Righteous
# Dinero
# Lexi
# Ck
# *Gale
# Trace
# *Flour
# *Zena
# Roy Jones
# *Merit
# Shiva
# Necrobutcher
# *Bey
# Yankee
# Freedom
# Vela
# Chia
# *Jewels
# Bertie Lu
# Cesar Chavez
# Sami
# Jiggy
# Corrie
# *Leia
# Shelly
# Negro
# Judy
# Teeger
# Persephone
# Griffin
# *Spring
# Kelly
# *Trina
# Johnny Bravo
# *Bojangles
# *Kit Kat
# Serrano
# Pongo
# *Zeke
# Yoyo
# Aya
# Speedeni
# Nymeria
# Schultz
# Yellow
# *Marmalade
# *Melinda
# Macy
# *Boogie
# Garden
# Marla
# Spirit
# Desmo
# Seren
# *Madelyn
# Barbie
# Bama
# *Faline
# Cucho
# Cabel
# *Ivy
# Yoruichi
# *Gavin
# Benjamin
# *Cronus
# Snow
# Sleepy
# Melinda
# Tina
# Janine
# Shilo
# Pugster
# *Alfie
# Dollar
# Laila
# *Charles
# Kimba
# *Filbert
# Salam
# *Zinnia
# *Skeeter
# Alfie
# Cosmo
# Mindy
# *Cliffy
# Cyan
# Lil Bit
# Fluff
# Alejo
# Hormiga
# Jayla
# Runt Runt
# *Katie Kat
# Slugger
# Anakin
# *Carlton
# Shiksa
# Carlie
# April
# Cotton Elle
# Willa
# Coby
# Kingsley
# *Hooch
# Braker
# Easy
# Guzi
# *Cesar
# *Josh
# *Ryan
# Stella Luna
# Kit Kat
# B.J.
# Pocas
# Chuchu
# *Christy
# *Aladdin
# *Terra
# *Charcoal
# Boy
# Daddy
# Westley
# Pia
# Tashi
# Carmen
# Justice
# Maximo
# Snuggles
# Dismiss
# Shade
# *Dwight
# Cookie-Poo
# Animal
# Caprice
# *Marco
# Lolly
# Kofi
# Socks
# Kinta
# *Marzipan
# *Ryo-Ohki
# Niki
# *Zazzle
# Huckelberry
# *Nicholson
# *Bartholomew
# Bugs
# *Moonpie
# *Riddick
# Mack
# *Phyllis
# *Peeta
# *Nutlet
# Maxine
# Anna Nicole
# *Duncan
# Rolly
# Gandolf
# Shamrock
# Mykelti
# Jazzmen
# Draco
# Claude
# Colby
# *Willis
# Lock
# Chanelle
# Prada
# Frida
# *Dill
# *Sydney
# *Patches
# *Todd
# Peppy
# Gorda
# Shady
# Tyrus
# Tormund
# *Elliot
# Jirah
# Sammy
# Hog
# Cleopatra
# Java
# *Bucky
# *Naomi
# Sintex
# Tee-Nee
# Kelio
# Mishka
# Tyrone
# *Chachi
# Mugs
# Scratch
# Prometheus
# Ellen
# *Lindsey
# Takis
# Gufi
# *Hambone
# Kayne
# Norma Jean
# Eddie
# Sugar Plum
# Swisha
# Sandor
# Johnny Cash
# Bettie Page
# *Prissy
# Cinna
# Ivan
# Zack
# Axle
# *Cato
# Queso
# Biddy
# Maize
# *Munch
# Frijol
# Orange Cat
# *Girly
# Baylee
# *Jelly Bean
# Osito
# Van Gogh
# *Iona
# Sophia Loren
# *Sanders
# *Louise
# Tipper
# *Beetle
# *Flutterby
# Saroc
# Bonny
# *Cragen
# *Sweetie
# Zeta
# Doljah
# Isiaiah
# Tammy
# Elliot
# Nick
# Merry
# Georgia
# Buddy Buddy
# *Gypsy
# *Theodore
# *Agatha
# Hershel
# Brown
# Phil
# Summer
# Maxey
# Sheba Baby
# Olivia
# *Evee
# *Claire
# Bud E.
# *Misha
# Shatta
# Blacky
# Coco Littles
# *Pom-Pom
# Beatrice
# Sobie
# *Elizabeth
# *Victoria
# *Richard
# *Mi Mi
# Parker
# *Roe
# *Farley
# Lemon Drop
# Gemma
# Anthrosol
# Rei
# Phillia
# *Denny
# Troy
# Midas
# *Scooter
# Little Bug
# Rice
# Chopper
# Pantera
# D-Wayne
# Sabo
# *Walker
# *Dina
# Rainy Bow
# Moon Pie
# * Mario
# *Miller
# *Clay
# C.C.
# Kayo
# Biah
# Chica Loca
# Reba
# Finley
# Tabs
# Aberdeen
# Tyler
# Pecos
# *Lourdes
# *Leon
# *Snowflake
# *Mitch
# Syl
# *Darion
# *Franziska
# Marian
# Kloe
# Rocky Road
# Punkin
# Farley
# Chug
# *Boudreaux
# Moo
# *Gunther
# Bedo
# *Sven
# *Toothless
# Kasami
# *Newman
# J.B.
# Talini
# *Koopa
# Saddie
# *Rufus
# Blizzard
# Kylie
# *Shy Guy
# *Lex
# *Buttercup
# *Rabbit
# *Rado
# Michi
# Conner
# Gala
# Peqqy
# Daisee
# Regan
# Desdemona
# Macduff
# Kent
# Macbeth
# Iago
# *Ophelia
# Gusga
# Tatia
# *Chili
# Libby
# *Tramp
# Leonardo
# Teddy Graham
# Sunday
# Ali
# Grisha
# Wicked
# Tess
# Momo
# Finnley
# Chaplin( Loco)
# Tuzi
# Mags
# Juicy
# *Josephine
# *Napoleon
# Doug
# Flecha
# *Stitch
# *Odessa
# Zero
# Sis
# Stomppy
# Milla
# *Fluttershy
# Nali
# *Pinkie Pie
# *Spike
# Gretel
# Deja Vu
# Mrs. Norris
# Emma Bella
# Mutt
# Moca
# *Dobie
# *Shirley
# Mico
# No Name
# Romulus
# *Lexie
# Spud
# Suca
# Jello
# *Mabel
# Ozzie
# Raz
# *Derek
# Shalimar
# Sherman
# Camino
# Fanniemae
# *Whitt
# Sinsae
# Theo
# Rogue
# Doxie
# Zac
# *Avery
# *Tilly May
# Terra
# Juna
# Channell
# Novio
# Purrsie
# Jill
# *Liddie
# *Griffin
# *Fraggle
# *Bilbo
# Rella
# *Jazzy
# *Jello
# *Felix
# *Davis
# *Trudy
# *Mayze
# Pluto
# Joy
# Bitsy
# Ben Ben
# Amps
# Sydney Love
# Cuddles
# Zorrito
# *Pickle
# *Hera
# *Zeus
# Bea
# *Billie
# Lenny
# Lilo
# Lexie
# Rote
# Rajeh
# *Biskit
# *Castor
# *Pollux
# *Salliemae
# Arlo
# *Luna Belle
# Cutie
# Cortez
# Cuzzle
# *Elsa
# Louise
# Addie
# Melanie
# Foley
# Charm
# *Chilli
# *Manchitas
# *Arwen
# *Aragorn
# Splinter
# *Slate
# Prya
# *Cookie
# *Barristan
# *Ashara
# Little Cat
# *Amy Lou
# Kc
# *Bombay
# Isa
# Pirate
# Calvin
# *Fezzik
# Petra
# *Basil
# Rommel
# Mug
# Purrmuffin
# Tinker Bell
# Kamilla
# Weasel
# Boone
# Dinky
# *Chimichanga
# *Queso
# Jimmy
# *Niblet
# *Fudge
# *Sprinkles
# Jericho
# *Prancer
# Keesa
# Louie Pepper
# *Sherbet
# *Creamcicle
# *Orangina
# *Mario
# Nigel
# Kuma
# Seti
# Jammer
# *Camelot
# Peppa
# Tux
# Scruffles
# *Hopper
# B. Dog
# *Luvalot
# Jonsi
# *Drew
# Odie
# Dede
# *Sylvia
# *Sullivan
# Swirly
# Kash
# Raja
# Chaco
# Teddy
# *Butters
# Genki
# Guthor
# Rupaul
# Sir
# Rollo
# Korbindallas
# Player
# Lovey
# Potter
# Merci
# *Orlith
# Bubb
# *Finch
# *Raven
# *Hawk
# *Wren
# Arty
# Eddy
# *Pecan
# *Hamm
# *Miguel
# *Arliss
# *Suzette
# *Feather
# Country
# Mae
# *Otto
# *Sundae
# Christine
# Lil' Mama
# Dana
# *Ritzy
# Steve
# Super
# *Rainey
# *Long John
# Pixy
# Chubby
# Wii
# Tia
# Oakley
# Moma
# *Hilly
# *Peewee
# Anubis
# *Coco
# Chachi
# Bungee
# *Astaire
# *Isadora
# *Radar
# *Carolina
# Ittybitty
# Darth Vader
# Rallah
# *Abigail
# *Kitkat
# *Rolo
# *Laurel
# *Mimosa
# *Hobart
# Clementine
# *Oakley
# Teagan
# Mojo
# *Mr.Black
# *Mica
# *Jon
# *Daenerys
# *Bran
# Itty Bitty
# *Sunnie
# *Sheeba
# Chepe
# Kathrine
# Dolce
# Mister
# Macah
# Rango
# Leah
# Scarlet Rose
# *Saltydog
# Campion
# Buki
# Flynn Ryder
# June-Bug
# Chin-Chin
# Tiger Lily
# Icy
# *P.T. Barnum
# *Uno
# *Trace
# *Dolce
# Lourdez
# *Carrot Cake
# *Reeses
# Em
# *Midnight
# Taco Cat
# *Ninja
# *Puzzles
# Henry
# Bb
# Pyrex
# Coqueta
# *Squeak
# May 2
# *Flo
# Caliman
# Campbell
# Miss K
# Si
# Coconut
# *Tonto
# *Patsy
# Neo
# *Peabody
# *Ruxpin
# Shirley
# Allan
# Piggy
# Nova
# Chaos
# Infinity
# *Pabst
# *Maybe
# *Lotus
# *Fern
# Flakey
# Fenek
# *Kodiak
# *Schmidt
# *Trip
# Maddy
# Stewie
# Dotty
# *Ryder
# Unique
# Puddin'
# Suzie
# *Kingoflove
# *Brooke
# Donny
# *Artie
# *Soot
# Money
# *Higgins
# *Jupiter
# *Cassiopeia
# *Europa
# Prec Punkin'
# *Lewis
# *Lincoln
# *Rainbow
# Joanie
# Z
# Chuli
# Stoney
# Baker
# Cupid
# Mary Jo
# Maggi
# Lucille Ball
# Jamie
# Kai
# *Amigo
# *Orville
# Madison
# *Pablo
# Mr. Cuddles
# *Uffa
# Destin
# Louis
# *Jenkins
# *Jay
# Nub
# *Ozzie
# Qwayzar
# Rinker
# *Lansing
# *Olympia
# *Bernard
# Champion
# Petunia
# Q Ball
# Kaleysee
# Renner
# Evans
# *Tidbit
# Savage
# *Jamie
# *Jan
# *Freesia
# *Verbena
# Chavez
# Chuckee
# *Plato
# Knight
# Kerra
# Bear Bear
# Jamocha
# *Corban
# *Duchess
# *Leelou
# *Will
# *Karen
# Madgi
# *Gretchen
# Assassin
# *Lion
# *Panther
# *Leopard
# Solo
# Des
# *Ally Marie
# *Dylan
# *Norma
# *Jaime
# *Gemma
# Peepsqueak
# *Joli
# *Mignon
# Franny
# *Moon Doggie
# *Thelma
# Chacha
# Pringle
# Eboni
# Catera
# Daphne
# Stormy 3
# Stormy 2
# Javiersita
# *Clancy
# *Jojen
# *Meera
# *Paul
# *Louisa
# *Alpha
# Tiddle Bug
# Frito
# Jillaroo
# Bombon
# M.J.
# *Karrie
# Eevee
# Bosley
# Orange
# *Whisper
# *Lavender
# Sparks
# *Tyron
# *Seven
# *Nike
# *Nyx
# *Cheetah
# *Mako
# *South
# Ramona
# *Cersei
# Squeaky
# *Paco
# Patsy
# Gambler
# Chrissy
# *Jonah
# Guero
# Bodie
# Barky
# Leona
# *Haddie
# Snoop
# Pilot
# Aeris
# *Elsie
# *Idris
# *Smores
# Ragnar
# Big Worm
# Kia
# Swagger-Swag
# Binga
# Merlin
# Kaila
# Sloopy
# Cochi
# Datsun
# Renee
# *Jon Snow
# Kit Cat
# *Elton
# Makarov
# *Emmie Lou
# Blu
# Lugs
# Dice
# Bambino
# Tinker
# Tyrian
# *Zoey
# *Curly Sue
# Peluchi
# *Pico
# Steve-O
# *Brenna
# *Jude
# Bonbo
# Tee-Mo
# *Starlight
# Kasey
# Churchill
# Toonami
# Pip
# Tempo
# Cholo
# Cheeco
# Barney
# *Dallas
# Stuart
# Fergie
# Mary Kate
# Lucian
# Jace
# Mason
# Alec
# Coronel
# Little Red
# *Granny
# *Elly Mae
# *Jed
# *Jethro
# Liam 2
# Messi
# Kingston
# Houston
# Taco
# Cola
# *Arrow
# *Lila
# *Marybell
# *Hoppin' Jon
# Kujo
# *Goose
# *Rooster
# Four
# *Cheesebrgr
# Chadwyck
# *Liam
# Asia
# Betty Boop
# *Bernice
# Fideo
# Harlie
# Teal
# Bosque
# *Gilbert
# *Susie
# Earl
# *Hooper
# *Suzie
# *Chalupa
# Flaco
# Yogottie
# Fanny
# *Odette
# *Snickerdood
# *Quinne
# Abe Lincoln
# Edgar
# Lela
# Montgomery
# *Angela
# *Julie
# Printer
# Lady J
# Calla
# Mary Jane
# *Calvin
# *Navin
# Kuppuru
# Snazz
# *Crumbs
# *Kiska
# *Shady
# Boscoe
# Drako
# *Lolly
# Jedi
# Asad
# Young Blood
# *Cashew
# *Sassafrass
# Shotzy
# Arwen
# *Slider
# Frio
# *Nessa
# Minnie Mouse
# *Mozart
# *Beethoven
# Robin
# Lory
# Jemina
# James
# Genevieve
# *Cameron
# *Stripes
# *Kerbey
# *Storm
# Booch
# Stitch
# Tidus
# Kovu
# *Tiger Lily
# *Chauncy
# West
# *Thurgood
# *Domino
# Irwin
# *Rosalind
# *Milicent
# *Fitzwilly
# *Barnabas
# Mo Mo
# Appa
# *Jacks
# *Salsa
# Tigris
# *Onion
# *Sprout
# *Asparagus
# Corey
# Big Daddy
# *Sheldon
# *Howard
# *Rajesh
# Slinky
# Elf
# Munchkin
# *Sprite
# *Mr. Pibb
# *Dr. Pepper
# *Fifi
# Tortie
# *Duffy
# *Vienna
# Paka
# Chui
# *Miss Etta
# Archilles
# Rufo
# *'Stache
# *Handlebar
# *Mountainman
# *Rolly
# *Lil Sis
# *Big Sis
# *Carmen
# Smoke Dawg
# *Watson
# *Jam
# Mars
# *Jerrico
# *Apple
# *Pear
# Freeda
# Yula
# Tobi
# *Aj
# Castro
# Holmes
# Samuari
# *Murray
# Ms. Birdy
# Evan
# Shy Guy
# *Cole
# Valentina
# Akasha
# Lestat
# Morrigan
# *Tootsie
# *Ruby Red
# Rupert
# *Brian
# Dug
# Tinnie
# Bruce Lee
# Kio
# Brody
# Svi
# Khloe
# *Vida
# Olivie
# Spartan
# Duffy
# Doris
# *Georgia
# *Darwen
# *Eowyn
# *Gimli
# *Five
# *Reno
# *Otis
# *Amor
# *Puffer Cat
# Collaway
# Kozee
# Brienne
# *Snoopy
# Ryanne
# *Carlo
# Makato
# Mj
# *Shrimp
# *Squid
# Coyote
# Night Fury
# *Mojo
# *Randy
# Maude
# Cobi
# *Rainy
# *Suzy
# *Sarita
# *Orton
# *Maverick
# Marty
# Trooper
# Kate
# *Hilda
# *Impa
# *Irene
# Magic
# *Plecostomus
# *Truman
# *Koi
# *Walt
# *Saul
# *Skyler
# Amazon
# *Wallace
# Wren
# Elliott
# *Stacey
# Mckinzie
# *Twix
# *Skittles
# *Starburst
# Sundae
# Bach
# Lyla
# Nuve
# *Wally
# Elle
# Pepe
# *Buckee
# *Pipkin
# Boo D.
# *Wynken
# *Blynken
# *Nod
# Janice
# *Puff
# *Adorable
# Holt
# Porsche
# *Libby
# Enoch
# Frisco
# Fran
# *Ozzy
# *Tess
# Marky Mark
# Bernie
# Shaka
# Tukufu
# *Margot
# *Zephyr
# *Derrick
# *Yogi
# Kendall
# *Sylvie
# *Blu
# Iris
# *Paulie
# Dalton
# Calamari
# Solomon
# Twitter
# Lucius
# Agnes
# Lil' Bit
# *Bowie
# *Phoebe
# *Juniper
# *Isaac
# Lovely Boy
# Dulce
# Dozer
# Leyah
# Mr. Magoo
# S'Mores
# Gaspi
# Ivory
# Mau-Mau
# *Carmella
# *Lala
# *Waldo
# Rosa
# Dog
# *Tasha
# *Tuck
# Sharpie
# Enyo
# *Rhoda
# Penelope Ros
# *Roxie
# *Wimberly
# *Aster
# *Ferris
# *Kiki
# *Kira
# Tigerwoods
# Stewart
# *Portia
# Crag
# *Pebbles
# *Bello
# Isla
# Fe
# Fungus
# Oates
# Cocco
# Braveheart
# *Boo
# Juma
# Stryker
# *Don
# Ernest
# Goliath
# *Rocket Man
# *Audrey
# Marzi
# Katy
# *Periwinkle
# *Sawyer
# Khan
# *Ranger
# Big Dog
# *Dutch
# *Two Bit
# Mokie
# Achado
# Bullit
# *Samantha
# Link
# *Chino
# *Frappe
# Zaza Zula
# *Draper
# Monday
# Straya
# Charro
# *Trigger
# *Wicca
# *Ebony
# *Felicia
# *Alberto
# *Tessie
# Weezy
# Ada
# Toloose
# *Widget
# Libby 2
# *Harold
# Ene
# Tipi
# Appi
# *Simone
# Winkie
# Mcqueen
# *Xochi
# Stax
# Zipper
# *Catnip
# *Summer
# *Milburn
# Tink
# Spaghetti
# Sweety Pie
# *Stephen
# Cow
# *Pringle
# *Bridget
# Kat
# Baby Cow
# Ting Ting
# *Gordy
# *Gwen
# *Glory
# *Georgie
# *Marcel
# *Dalton
# Randy
# Darby
# *Bitsie
# Durant
# *Sir Parker
# *Kate
# Remington
# *Sabine
# Meena
# *Martina
# *Hops
# *Peggy
# *Samba
# Chucky
# *Champ
# *Jeffrey
# *Sharpie
# *Bumper
# Harlow
# *Rena
# *Scarlet
# *Hanna Jo
# Brosco
# Pink
# Pepperonirol
# *Maria
# Mama Bear
# *Lennox
# Malcolm
# Blackberry
# Coffee
# *Teddy Bear
# Blinky
# Inky
# *Asha
# Leonidas
# Nym
# Posh
# *Mr. Pip
# Townes
# Golden Boy
# *Spruce
# *Cedar
# Deablo
# *Deltadawn
# Camillo
# *Vern
# Kinetic
# Mosey
# Smaug
# Little Man
# Root Beer
# Juni
# Charlie 2
# *Lizzie
# *Izy
# *Popcorn
# *Crackers
# *Hamilton
# Chicho
# Karl
# Mancha
# Diezle
# Keeton
# *Macon
# Toadstool
# G.
# Tutmosis
# *Big Joe
# *Flynn
# Brindie
# *Porter
# *Walter
# *Luigi
# Other
# Cigarette
# Pupper
# Saja
# Bo Bo
# Hailey 2
# *Moose
# *Otter
# *Lemming
# *Bettina
# *Ghia
# Kermit
# Mitch Zuniga
# Vero
# Shwayze
# *Big Red
# Emme
# Fonzi
# Maybe
# Hathor
# *Tolkien
# Dinah
# Mancat
# *Jonathan
# *Donny
# Shakespeare
# June Bug
# Caramel
# *Henrietta
# Adelaide
# Quincy
# Speedy
# D. J.
# India
# *Winkie
# Khyra
# Shug
# *Bennett
# Mitty
# Heart
# Marilyn
# *Harriet
# Tortilla
# *Bindi
# *Nash
# *Ben
# *Maryellen
# *Veronica
# *Heather
# *J.D.
# *Banshee
# Fence
# *Maple
# *Infinity
# *Christie
# *Rogue
# Bay
# *Nelda
# Pebbles
# Jelly
# Peekaboo
# Girlie
# Lita
# Brystal
# Babyblueeyes
# Bruce Wayne
# *Lizzy
# Rajah
# *Sauerkraut
# *Frankfurter
# Poquito
# Greyworm
# *Linus
# Geoffrey
# *Cheyenne
# Tootsie Roll
# Quanah
# Frannie
# Billie
# Maverick
# *Mr. Bean
# Blue Bell
# *Morgan
# Khalesi
# Optimusprime
# *Kuma
# Roger Roger
# Chumino
# Gunnar
# Shimi
# *Pancake
# *Waffles
# *Tango
# Geo
# *Rust
# *Elaine
# *Raylan
# *Eddy
# Dugan
# *Zed
# *Ziggy
# Guera
# Chingon
# Tarva
# Palona1
# Raton
# *Lyra
# Philemon
# Dimond
# *Presley
# Outlaw
# Nikai
# *Murphey
# Gypsie
# Ann Richards
# Avenue
# Matthew
# *Bob
# *Saffron
# *Coop
# Elwood
# Jaxon
# Bila
# Nacha
# Pecas
# Triceratops
# *Ted
# *Biggles
# *Bumble
# Mew
# *Nymeria
# Kyle
# Carla
# Paw
# Crybaby
# Pebble
# Nyx
# Bristol
# Reno
# *Blake
# Samus
# *Hoss
# Beka
# Farrah
# Loco
# *Bobbin
# Pollyanna
# Rumor
# Maisy
# Drake
# Shekina
# Booboo
# Sweet Boy
# Ink
# Furby
# *Tex
# *Twila
# Harley Quinn
# Sarge
# Donovan
# Lady Sasha
# *Carlos
# Dawn
# Poseidon
# Paisley
# Cayden
# Bernard
# Rooster
# Ebis
# *America
# Saedi
# *Ocho
# Bummer
# Dude
# Moogi
# Calli
# *Booker
# *Punkin
# Freddy
# *Flash
# *Janet
# Bunny
# Dot Dot
# Tica
# *Celine
# Malkin
# Crosby
# Heisenberg
# *Sunkist
# *Babe
# Endo
# Sadie Mae
# Cedrick
# *Tinker
# *Pietro
# *Logan
# Kitty Lou
# Skitty
# Biskit
# *Velma
# Kaui
# *Vegas
# *Versace
# *Tammy
# *Sammie
# *Cammie
# Lindy Hop
# *Sweet Pea
# Boy Kitty
# *Keen
# Porthos
# Pancake
# *Kit
# Neptune
# *Astrid
# Nike
# Liz
# *Cheryl
# *Emile
# *Wind
# *Rain
# Yoshi
# Thundernuget
# Teddy Roosev
# Azia
# *Mr. Skippy
# Clara
# Obi-Wan
# Christie
# Scott
# Drago
# *Ann
# Rosebud
# *Lamb
# Kayro
# *Gertie
# *Lightning
# Saki
# *Sedona
# Hans
# *Piccolo
# Lem Lem
# Gusto
# *Juan
# Chubs
# Dubbs
# *Mini Cooper
# Jenny Tyson
# Sadie-Mae
# Granger
# Fox
# French Fry
# Hopper
# Oz
# Cielo
# Lorelai
# Moxie
# *Mariah
# Tybalt
# *Marina
# *Dagwood
# *Blondie
# Knuckles
# *Fitz
# Klaatu
# *Mittens
# Fozzy Bear
# Michaelscott
# *Ray Ray
# *Lulu Belle
# *Tinman
# Jc
# Sparticus
# *Koko
# *Jacy
# Stacie
# Roberta
# Walker
# *Shortcake
# *Smokie
# *Regan
# Sushi
# Twix
# Shanudie
# Buff
# X
# Cry Baby
# *Adam
# *Malcolm
# Gill
# Art
# Peggy
# *Pudding
# *Lance
# Geddy
# *August
# *Shelly
# Shroom
# *Ana
# *Saxon
# *Redford
# *Annabella
# *Clark
# *Carrie
# *Corey
# *Blaine
# *Blynn
# *Bodan
# *Beryl
# Denver
# Ukiah
# *Sheri
# Booskie
# Miguel
# *Ennis
# *Errol
# *Ephram
# Miss Pheobe
# Jazzie
# Keah
# *Beast
# Dimples
# *Deebs
# *Collin
# *Tootie
# Memphis
# Nubbins
# Trinity
# *Jd
# Lemmy
# Spruce
# *Leti
# Loupgaru
# *Coconut
# *Tabby
# *Dex
# Mousse
# Petals
# Chuck Taylor
# Ruckus
# Rocca
# *Moo
# *Xarren
# Dogtor Roxo
# Denali
# Pavel
# Macey
# Vesper
# *Athena
# Pepito
# *Cassidy
# Tomtom
# Squishy
# L.J.
# Mustachala
# Marvin
# Rin
# *Lorenzo
# Sugar Foot
# *Balboa
# Smoke
# Capeice
# Ceasar
# Kush
# *Rhett
# *Golio
# Kaypo
# Fluffette
# Nutterbutter
# Gia
# Twister
# *Everest
# Nippy
# Loli
# Lucca
# *Hugo
# *Cowboy
# *Bree
# Ronin
# *Zachary
# Koopa
# Hotsauce
# Chemmie
# *Benny
# Scarlet
# *Zeak
# Axl
# *Bosco
# *Cosco
# *Hannah Blue
# *Snowcream
# Johnny
# Niblet
# Text
# Mitch
# Hitler
# Gemini
# *Mick
# Tod
# *Azul
# *Celeste
# *Lelou
# Cheech
# *Sidney
# Gino
# Shabba
# Nansen
# Chiquis
# Chunk
# Heartbreaker
# Cheyenne
# Dj
# Ninja
# Rumierre
# Lexx
# Kisses
# Kelvi
# Babyprincess
# Mazzy
# Ami
# Joan H
# *Chance
# Carnelo
# Nemesis
# Yuki
# Left Eye
# *Pinochle
# *Sport
# Multipass
# Alfonso
# Althea
# *Foxy
# *Shiner
# *Yukon
# *Lunchbox
# *Aria
# *Macaroni
# Edge
# Kreydos
# *Ruffles
# Jimmy Page
# *Opal
# Terry
# Dingo
# *Meechum
# Groot
# *Captain
# Marbelle
# Pitty
# *Roger
# *Rory
# Chinston
# *Kisa
# *Rachel
# *Judy
# *Auggie
# Moosifer
# Django
# Solobino
# Helios
# Sansa
# Tui
# Ryuuko
# *Alonzo
# Macintosh
# Chita
# Tobias
# Silvy
# Serena
# Kaiman
# Bandito
# *Buttrscotch
# Tiger Girl
# *Repete
# Valencia
# Satusma
# Goldilocks
# Minneloa
# *Valentino
# Reilly
# Puzzles
# Vicente
# *Ellie
# Morpheus
# Junies
# *Jillian
# Trisha
# *Mercury
# Plato
# Sugar Bear
# *Vincent
# Flex
# *Pingpong
# Ms. Whiskers
# Zarina
# Snow Ball
# Morticia
# *Herk
# Noori
# Tejota
# *Tula
# *Glenn
# *Carol
# *Michonne
# *Daryl
# Ed
# Rick
# Jean Grey
# *Wolfgang
# Bindi
# Basil
# *Weibe
# Dahrma
# Roxanne
# Suzzy
# *Kennedy
# *Jazz
# *Gracie Lou
# Kai Franco
# *Baloo
# *Amanda
# Planet
# Fate
# Pokey Dot
# Fay
# *Remy
# *Rafe
# *Superman
# *Dempsy
# Drax
# Peridot
# Pichu
# Rukia
# Gyula
# *Pauly
# *Bess
# *Frisky
# Tulip
# Mr Wiggles
# *Hadley
# Herbie
# Tigger Lily
# *Savvy
# *Bolt
# Puddin
# Koby
# Ana
# Sodapop
# Crash
# Rossco
# *Dovey
# Fleck
# Charlotte
# Abigail
# Phoenix
# *Tero
# *Larkspur
# *Dally
# P. Pistol
# *Wonka
# *Manny
# *Mundy
# Dikembe
# Ronaldo
# Dwight
# *Scooby
# Sombra
# *Lynne
# *Oak
# *Cyprus
# Hammer
# Corazon
# She-Ra
# *Forrest
# *Roja
# *Sierra
# Trousers
# Kozi
# *Demitri
# *Mance
# Galileo
# Slash
# Myka
# *Nermal
# Hana
# Brittany
# Mr. Cookies
# Bw
# Wendy
# Guiness
# Nelly
# *Weezie
# Ojoe
# Rikki Tikki
# Hicks
# Booger
# Truluck
# *Pistachio
# Peach
# Kettle
# Cyrus
# *Bevo
# *Rico
# Meeko
# Lokita
# Sandi
# *Merida
# Jupiter
# Pep
# *Frita
# *Davie
# Kota
# Dachs
# Kyra
# Marseau
# *Brad
# *Hallie
# *Cowboybebop
# Prinsesa
# *Jerrid
# *Delfino
# T
# *Meowski
# Corbin
# *Roddy
# Tillie May
# Bria
# Brisk
# Bertha
# Rylie
# Shadows
# Ziva
# *Nolan
# Freeway
# Boogie
# Shae
# *Bongo
# Bravo
# Goldy
# *Tugg
# Lexus
# Garbage
# Tom Cat
# Beowoof
# *Howdy
# Nila
# Elote
# Tobie
# *Little One
# Catniss
# Chencho
# Dr. Spangler
# Fuzz
# *Summerlee
# Mikale
# Tuesday
# Corra
# *Kell
# Bosales
# Pogeaux
# *Deena
# Chispa
# Mama'S
# *Akira
# Mongo
# Ace Regalado
# Darcy
# *Deedee
# Beast
# Sherra
# Miko
# Sully
# Tish
# Baux
# *Pip
# *Hudson
# Spock
# Georgie
# Rooney
# Vito
# *Gilley
# *Ford
# Sprout
# Preciosa
# *Jumbo
# *Boss
# Hudson Hawk
# *Richie
# Linkin
# Ramsey
# Cayenne
# Nadira
# Manches
# Filbert
# Smokie
# Sona
# *Henderson
# Lover Boy
# Gray
# Tally
# *Ingrid
# Chuco
# Holo
# *Huggy Bear
# Luka
# *Hans
# *Marit
# *Jango
# Mr. West
# *Bashful
# Brooklyn
# Mr. Meowgi
# Phillis
# Jager
# Butterscotch
# *Raul
# Mr. Blue
# Chicharro
# Shenanigan
# Buba
# Jaycup
# Kya
# Evinrude
# Suesue
# Sadie Gray
# *Ed
# Noches
# Troubles
# Durango
# Negrito
# Tupac
# Dustin
# *Dillon
# *Jynx
# Fin
# Barbara
# Loverboy
# Hope
# Vega
# Kokomo
# Taker
# Tea-Tee
# Arabella
# Doom
# Nellie
# Mochi
# Kobi
# Pooh Bear
# Nolan
# Pearce
# *Dawn
# Cyrano
# Soko
# Shasta
# *Zsa Zsa
# *Vinny
# Stacey
# Brix
# *Zooey
# *Socks
# Kouga
# Chapo
# Fezzik
# Serious
# Tobby
# *Cami
# Francois
# Mr.Belvedere
# *Doug
# Brisket
# Bone
# Cass
# Ira
# *Gandolf
# Sandy Boy
# Mambo
# *Marley
# A-Sir
# Milt Jackson
# Mister Frodo
# *Izabella
# *Ace
# Wiz Catifa
# Diablo
# Mr Bunny
# Tuli
# Gandalf
# *Arnie
# Sy
# Carry
# *Herman
# *Valentine
# *Moon
# Roko
# Ryleigh
# Macarron
# *Kristy
# *Nattie
# *Halie
# Suzanne
# *Aimee
# *Hattie
# Apache
# Philo
# Charles
# *Jenni
# Cindy Lou
# Garrison
# Beatrix
# *Gonzo
# Action
# Infamous
# Zayda
# Claudio
# *Winky
# Runner
# Alizay
# *River
# Chop
# Sugg
# Benz
# *Parry
# *Miko
# *Maribelle
# *Nigel
# Ab
# Perrywinkle
# *Dax
# Mr. Biggy
# *Little John
# *Shredder
# Majic
# Canello
# *Carla
# *Pepsi
# Miss Sally
# Chicken
# Colbie
# Maxx
# Poochie
# Stefani
# Fitzy Blue
# Gordita
# Sinjin
# *Sienna
# *Mort
# Westin
# *Harpo
# *Hopkins
# Bernice
# Mcruber
# Hailey
# *Lee Anne
# Jenna
# Sunkist
# Squeek
# Princess Lea
# *Rae
# Rika
# Joplin
# *Freda
# *Hal
# *Baby Blue
# Gringa
# Tugboat
# Pagoda
# *Lefty
# Dahmer
# Sir Pounce
# Bluto
# Duma
# Kali
# *Cosette
# *Eponine
# Klaus
# Gob
# *Johnny Cat
# Jakey
# Willie B
# *Julep
# *Ajax
# *Magilla
# *Deacon
# Javier
# Nordeste
# Cai
# Dusty
# Garen
# Levon
# Maryjane
# *Glacier
# *Brenda
# *Perth
# *Flint
# France
# R-Two
# Minny
# *Keegan
# *Miette
# *Lyle
# *Coby
# Zucchini
# Giant
# *Yoda
# Blanche
# Marlyin
# Kazy
# *Nickel
# Galaxy
# Tallulah
# *Posey
# Nino Brown
# Chicago
# S.J.
# K.J.
# Zeba
# Kaden
# Ike
# *Ridley
# *Pretzel
# *Roadbug
# Sunset
# Sun
# Phantom
# *Corkie
# *Maizy
# Moctezuma
# Lynx
# Lina
# *Nate
# *Ned
# *Kerby
# *Kyle
# *Bruja
# Lulis
# Nash
# Rawhide
# Isabel
# Ping
# *Grams
# Addison
# *Patron
# Gavin
# *Milly
# Samhain
# *Maximus
# Friday
# *Wrigley
# Sherbet
# *Mr
# *Tangelo
# Gina
# Mr. Bones
# *Anatoli
# *Brutus
# *Bootsy
# *Fluffernutt
# Camo
# Audrey
# *John Boy
# *Jellybean
# *Cassandra
# Felipe
# Tarzan
# Gracey
# *Pfelix
# Immy
# Bup
# *Paloma
# Kacy
# *Louis
# Jazzbo
# Melo
# Braille
# Roti/Haji
# *Thunder
# *Toto
# *Pee Wee
# Kassidy
# S'More
# *Elda
# *Willy
# *Xander
# *Felina
# Wade
# Metta
# *Bluebonnet
# *Jeremiah
# Sterling
# *Darcy
# *Bingley
# *Georgiana
# *Montgomery
# *Silvia
# *Caroline
# Exalibur
# *Honeybee
# Willey
# *Céline
# Shaft
# *Marlee
# Coquito
# *Brody
# Harold
# Xochi
# Sputnik
# Keani
# Todd
# Goobey
# *Elijah
# *Emmy
# *Elspeth
# Nicholas
# Kiedis
# *Cafe
# Nicolas
# Tee
# *Fawn
# *Rickon
# *Theon
# Zee
# *Anne
# Anna Mae
# Ernest T
# Cathy
# Saly
# Trunks
# *Romi
# *Michelle
# *Holmes
# Stormie
# Brandi
# Periwinkle
# Queen Padme
# Snax
# *Snackie
# Kenney
# Nooli
# *Edwina
# Magi
# *Reggie
# Thunder
# Tiney
# *Tinkerbell
# Roger
# Dukesa
# Lalo
# Preston
# *Nora
# Mr Sprinkles
# *Pixie
# Kitty Garcia
# Dezi
# *Whittaker
# *Queen Bee
# Krunch
# Mick Jagger
# *Bramwell
# Charlene
# Savini
# Junie
# Guerro
# Huffy
# Jorgo
# Tennessee
# *Tiffany
# Scotty
# *Zorro
# Josette
# Snooky
# Mr Pibbs
# *Sterling
# Cider
# *Diane
# Darger
# Darcey
# Clay
# Kari
# Thayer
# Savvy
# Jd
# *Flicker
# W
# Joojups
# *Kramer
# Adorable
# *Ross
# Meggy
# Conrad
# *Gustav
# *Brooklyn
# *Teague
# He-Man
# Tookies
# Butch
# Sabana
# Sandro
# *Joanie
# *Cherie
# Chappie
# Ethan
# *Lupe
# *Becca
# Sosa
# *Riddle
# *Phantom
# Toba
# Andromeda
# *Tank
# *Quattro
# Magnolia
# Meow
# Peppermint
# *Cobalt
# Sparkly
# Christy
# Rugby
# Lovely
# Tug
# Asma
# Hot Dog
# *Shiela
# Biela
# Lori
# Spider Man
# Amenia
# Spider Woman
# *Chrissy
# Monarch
# Chavo
# *Harley
# *Giblet
# *Stewart
# *Riblet
# Chalupa Btmn
# *Shakespeare
# Ross
# *Roxanne
# Bibie
# Lollipop
# Anabele
# Sereno
# Boulder
# *Nimby
# *Boston
# *Eva
# *Jaxon
# *Griff
# *Glen
# *Iron Man
# Dozian
# Spicey
# *Elmer
# Beamer
# Tre
# Gilly
# *Doodle
# *Rocco
# *Franky
# *Dizzy
# *Boots
# *Lindy
# *Bizzy
# *Tizzy
# *Mary Lou
# Stacks
# Lena
# *Sabrina
# *Grayson
# Dan
# Zues
# *Ping
# Brahma
# *Montie
# Chiquillin
# Cornal
# *Dessau
# Hermes
# Ezra
# Moscow
# *Raj
# *Brodie
# Sugar Ray
# *Tee Nine E
# *Brownie
# Clio
# Jeep
# Reeses
# *Bea
# *Valent
# *Waffle
# *Flap Jack
# *Jeb
# Muffy
# Bola
# *Mary Jane
# *Boris
# Bluebell
# Silvi
# Wild Bill
# Texas Kisses
# Maury
# Gustav
# *Henny
# *Celia
# *Magnus
# *Donatello
# *Lil Bit
# Purdy
# *Noodle
# Hashbrown
# *Heath
# Popy Jr
# Nico
# Chansy
# Howard
# *Noah
# Talia
# Tomas
# *Landon
# Maple
# Sooter
# Miss Oliver
# Hulk
# Prieta
# *Maximillion
# Bronx
# Little Foot
# *Mocha
# Brik
# *Bubblegum
# Lovett
# Penny Jane
# *Annabelle
# Tara
# Winry
# Bashful
# Daedalus
# Supreme
# *Thomas
# *Leonardo
# *Zeppelin
# Jezzy
# Obie
# *Halifax
# Weiser
# Tippy
# Carlos Perez
# Paprika
# Clove
# Avalanche
# Nene
# Velvet
# *Cleveland
# Arizona
# Caleb
# *Licorice
# *Ethel
# Ander
# Flo
# Nicole
# Guzman
# Firulais
# *Cheesy Puff
# Beau-Beau
# *Ricardo
# *Dodger
# *Dinah
# *Ramona
# Baily
# *Kinki
# *Marigold
# Ruffy
# *Bugsy
# *Bubba Gump
# Dayz
# Pocky
# *Dustin
# *Wanda
# Raccoon
# *Isa
# Guthrie
# *Autumn
# Pong Pong
# Perdy
# Socrates
# Ligra
# Rubio
# Puchis
# Tula
# Popki
# Bane * Deceased
# Choncho
# *Tigre
# *Deanna
# *Zip
# Ondeado
# Grimm
# Swade
# *Cappucino
# *Cindy
# Cole
# Mitzy
# *Pamela
# Shy
# Little Dude
# *Porridge
# *Lynette
# *Lyndon
# *Garfield
# Yety
# Little Boo
# *Thunderbird
# *Pagani
# Lazy
# Doobie
# *Bradley
# Bessie
# Wilbur
# Jaws
# *Groucho
# Kookie
# *Taurus
# *Spooky
# Bugsy
# Moby
# Georgia Grac
# Julep
# *Thurston
# *Trenton
# Mcgregor
# Armani
# *Esmerelda
# *Huck
# *Nib
# Snakes
# *Philomena
# *Yoakum
# *Salty Dog
# Jayme
# Nokia
# Oils
# Thane
# Shinji
# White
# *Trooper
# Chori
# *House
# Larry
# *Galleta
# *Fuego
# *Friskie
# Tasser
# Teller
# *Chick
# Sal
# Reye
# Lyriq
# Magnum Pi
# *Tazi
# Chubacca
# Chacho
# *Anna
# Kyoko
# Peter Cooper
# Lennon
# Tips
# *Gary
# *Chrissie
# Shelbey
# *Geronimo
# Grif
# Banana
# Fig
# Pouncers
# Fat Boy
# Beauregard
# *Kylie
# Stuff
# *Sassy
# Swanson
# Man
# Rainy
# Rosey
# Haylie
# Bagel
# Gromit
# *Karma
# *Riggs
# *Lillith
# Malo
# Cc
# *Gunnar
# *Degas
# *Picasso
# Aragorn
# Loba
# *Pooh Bear
# Comet
# *Augustus
# *Livia
# Kako
# Disa
# *Karissa
# Volcom
# Oasis
# *Starbar
# *Dozer
# Mark
# *Schotzy
# T.T.
# Marigold
# *Nicki
# *Ronni
# Spider
# *Hollywood
# *Fernando
# Possum
# *Mckinley
# *Yosemite
# Flicka
# *Bluto
# Nala Faith
# Skama
# *Chunkster
# Marisol
# Jilly Pattyc
# *Reginald
# Rampage
# Tiko
# Todd Packer
# *Horatio
# *Kai
# *Paprika
# *Clove
# *Curry
# Royce
# *Tostada
# *Pinto
# Pumba
# Zazu
# *Lara
# *Victor
# *Major
# Cappuccino
# Greg
# Jelly Bean
# *Clive
# Bellah
# Jonny Cash
# *Tori
# *Tanya
# *Tia
# *Aldo
# Bobbie
# Baby 2
# *Elmo
# Mimsy
# *Philippe
# *Sylvester
# *Beloved
# Bonzae
# *Twyla
# *Big Ben
# *Acorn
# *Butternut
# *Spaghetti
# *Zuchinni
# Shania
# Fun Guy
# *Dino
# *Kings
# *Monroe
# Chickla
# Carter
# Aisha
# Tigey Sue
# Handsome
# Augustus
# Pelusa
# Boing
# *Octavio
# Big Chief
# Prinsess Joj
# Wolverine
# Challino
# Leo Blue
# *Kasey
# Brees
# Dali
# Goldielux
# *Clementine
# *Lori
# Tiva
# *Powder
# *Swizzle
# *Lagarto
# *Zander
# Blair
# Deja
# Ruby Grace
# *Tahoe
# Beebee
# Vanilla
# *Rocket
# Silly
# Fantasia
# *Lolita
# Big Red
# Poopy
# Toffy
# Aniwaya
# Stinks
# Allister
# *S'Mores
# Mack Brown
# Hobie
# Raina
# Centurion
# *Sheba
# *Maddy
# Avaddon
# Tiffany
# Togo
# Stanley
# Leroux
# Rage
# Tsequila
# *Cutie Pie
# *Rascal
# Poot
# Miso
# Jim Bob
# Riot
# Rumble
# Chichita
# *Razzle
# *Dazzle
# Rajun
# Radar
# Carolina
# Blakie
# *Norton
# Kat Klops
# Blossom
# Cal
# *Rio
# William
# Ryan
# Jeff
# Sugar Sugar
# Adara
# Addy
# Zaida
# *Christopher
# T-Rex
# *Turkey
# *Cranberry
# Yodi
# Lika
# Bart
# *Shaina
# Annabell
# White One
# Sherbert
# Zhajha
# Kilah
# *Sid
# *Arlo
# *Popeye
# Punkin'
# *Richardson
# *Paula
# *Joannie
# *Bigfoot
# *Boomer
# Jett
# *Dale
# Bruce Willis
# Icicle
# Fuzzy
# Casanova
# Ra Ra
# *Mel
# Cloy
# *Peter Pan
# Alexis
# Chuchi
# *Bastet
# *Scoobie
# Gabi
# Graves
# Peeka
# *Neo
# Elvira
# *Jewel
# *Ember
# Charger
# *Spinoza
# Maunster
# *Gobble
# Beany
# *Mochi
# *Charlize
# Murdock
# *Remington
# Jeremiah
# Voodoo
# Kallie
# Carmelo
# Reynolds
# Kibbeh
# *Rue
# Dez Peanut
# Ragzee
# Wolfe
# Aaru
# *Lacy
# *Smith
# Jezza
# Cokito
# Mallory
# Lyam
# Little Mama
# Osyrus
# Chiky
# Jelly Bellie
# Kerubina
# Lareine
# *Oswald
# *Dandelion
# Kapie
# Ho-Ho'S
# Rascah
# Alf
# Lemur
# Twink
# Remmie
# Zoltan
# *Lainey
# *Marbles
# Hello Kitty
# Crook
# Beanz
# Nubia
# Horton
# *Marvel
# *Mattie
# *Stardust
# Berkley
# Chicken Kitt
# Laila Fifi
# Sugar Cane
# *Fergus
# *Dean
# Lady Red
# Ella Blue
# Paivi
# Grizzley
# Storie
# Milli
# Piru
# *Crosby
# Vail
# Luda
# *Laurie
# Roc
# *Rhodes
# Momma Kitty
# Meridith
# Voyager
# Pelos
# Page
# Castor
# Pollux
# Freda
# *Rembrandt
# Firecracker
# Nukeem
# Moby Dixson
# Cowgirl
# *Bock
# Zana
# Spring
# Zippy
# *Charms
# *Sue
# Tripod
# Sace
# *Macy
# Sylvia
# *Shanti
# Ms Kitty
# *Lenny
# Baiya
# Rouge
# Lex
# *Orlando
# Angel Marie
# *Bebe
# Picqui
# Duqueza
# Itty Bitty K
# Mishiro
# Hiddles
# Schmellow
# *Chopper
# *Snow
# Peetie
# Chaz
# Godzilla
# Rigby
# *Luci
# *Elfie
# *Koa
# Cameron
# Arianna
# *Opossum
# *Nellie
# Neice
# Bowmore
# Jacques
# *Leila
# Dutches
# Rakscha
# Bock
# *Agnes
# Oreto
# Doogie
# Grey Boy
# Harly
# Peebee
# Rally
# Francine
# Queens
# Eros
# *Bentley
# Zen
# Colt
# Dempsey
# *Gunner
# Abbadon
# Prince Charm
# Eagle
# Connor
# Asuna
# Luigi
# Hurley
# Jam
# Cb
# Twiggy
# *Ygritte
# Odus
# *Trula
# Mit Mit
# Cashie
# Emmie
# Noodle
# Kini
# Salamay
# *Harbor
# Moet
# *Buttons
# Natalia
# *Bryant
# Chaparro
# *Chancellor
# Jaydee
# *Haus
# Sassafrass
# Peluchona
# Vangogh
# Foxy
# Dandy
# Rolo
# Stranger
# Avatar
# Big Foot
# Camila
# *Remulade
# Maryanne
# Wendell
# *Zipper
# Sheriff
# Q-Tip
# Nebula
# Darrell
# Lucia
# Genghis
# Charlee
# Camden
# Carsen
# Ditch
# Iztli
# Hoggy
# Howler
# Bollita
# Brown Suga
# Sallie
# *Lika
# Chiquito
# Nacho Libre
# Madi
# Twixy
# *Inky
# Brinkley
# *Maisie
# Sauce
# *Pita
# Orson
# Silas
# Miami
# *Tino
# Pauwtucket
# *Kimi
# *Stetson
# Chacota
# Brina
# Dozier
# *Mcallister
# *Tweety
# Sienna
# Riku
# Gray-1
# Curry
# Fat King Lou
# *Oona
# Rogue Momo
# Zuma
# *Bono
# *Fluffs
# Jizzle
# Gale
# Hopkins
# Midge
# Luis
# Meaux
# Rufio
# Hickup
# Snipe
# Caid
# *Kyra
# Katana
# Shoshes
# Blitzen
# Bahkara
# Zila
# Bricks
# Kyzer
# Chachacci
# Cricket
# Foxie
# *Sacramento
# Hendrix
# Carle
# Cake
# Dodger
# Claudia
# Felix Jupe
# Scout Jupe
# Twyla
# Kandi
# Chapito
# Cusi
# Mesha
# Ty
# Cat Woman
# Rello
# Umpire
# *Hunca Munca
# *Kinsey
# *Tanner
# Dumaris
# Wes
# Maru
# Dudley
# Chelsey
# Guido
# Lua
# Fossa
# *Lily Pad
# Alfiee
# Bramble Pelt
# *Nightshadow
# Cymbah
# Tweak
# *Bruno
# Hydie
# Gorilla
# *Sahara
# *Collette
# *Mildred
# Leyna
# Boosts
# *Mallory
# Arielle
# *Susan
# Tido
# Rubble
# Legend
# Mazey
# *Mateo
# *Ursa
# *Aurora
# Ramone
# *Jersey
# Aladar
# Samwise
# Decklyn
# Stubs
# Natural
# *Joni
# *Calla
# Big Austin
# *Perdita
# Shadoe
# Samuel
# Shaggy
# Lola Bleu
# Niky
# *Miori
# *Puma
# *Perkins
# *Thing 3
# Half Pint
# Kitty Kitty
# Zari
# Geno
# *Brett
# Robbie
# *Dedee
# Vida
# *Padmé
# Sherry
# Kalamazzoo
# *Montana
# Darth Caedus
# Squirrel
# *Kade
# Boswell
# *Loki
# Sarang
# Olive Mae
# Crayon
# Mox
# Road Dog
# Miss Crush
# *Esmeralda
# Snowbelle
# *Ella Mae
# *Jordy
# Calypto
# Striker
# *Kaipo
# *King Bacon
# Night Wing
# Haze
# Auslyn
# *Xena
# Marco
# Miss
# Zahn
# Snickrdoodle
# Mackenzie
# *Delta
# Jane
# Whitey
# Ida
# *Miley
# Tigri
# Herc
# Little B
# Pesto
# Sinch
# Compadre
# Bouncer
# *Troy
# Boxer
# Shanti
# *Pillsbury
# *Biscotti
# Cher
# *Sallie
# *Emma Mae
# *Alphonse
# Wera
# Kuromi
# C
# Tooth
# *Hampton
# *Buggs
# David
# *Rebel
# Gizbert
# *Tuna
# Versace
# Malachite
# *Windsor
# *Coronado
# Hopscotch
# Deedee
# Sugarcat
# Pearson
# Manson
# Phife
# *Joker
# Meeper
# *Cecilia
# Sunny
# Stud
# Che
# Ena
# *Angus
# Riko
# Nalu
# *Sarai
# Crockett
# Bochy
# Catsby
# *Henri
# *Amie
# Mulder
# *Custer
# *Cielo
# Bo-Jack
# *Perry
# Little Ricky
# Jak
# Mouphtaou
# Fawn
# *Edna
# Muchkin
# Quinn
# *Mr. Peabody
# Briggs
# Elijah
# Topaz
# Tracy
# Pac
# *Mogwai
# Pelé
# Bailee
# Jacki
# *Hanna
# Smooches
# Mordie
# Mylo
# Bella Swan
# Finnick
# Happy Face
# Chet
# Scoot
# Cadence
# Granny
# King Noodles
# Argos
# Brock
# *Caesar
# Tramp
# *Trapper
# Panther
# Abraham
# *Mr Muffin
# Padme
# Dean
# Pipper
# Poppett
# Noche
# Morocco
# Da Vinci
# Moo Moo
# *Belfast
# *Pfieffer
# Bon Bom
# Ellabelle
# Feather
# Francis
# Starlit
# Bug
# *Skye
# Sven
# *Rowdy
# Boi
# Lewis
# Sprinkle
# Giovanni
# Red Bull
# Bob Barker
# Wendy Davis
# Poppa
# *Rihanna
# Dbo
# Coda
# Rohan
# Hot Rod
# Indy
# Valintino
# Orbit
# Sandman
# Guey
# America
# Wishbone
# *Holton
# *Laverne
# Loca
# Stud Muffin
# *Popsicle
# Marsha
# Zulu
# Slim
# *Stryker
# Amos
# Una
# Jim
# Minion
# *Francis
# Annie Mae
# Figgy
# *Dotty
# Bartledby
# *Bethany
# *Kashi
# *Franz
# Snickerdoodl
# Mitzi
# *Carly
# *Sonora
# Marcus
# Nell
# *Dijiba
# *Primrose
# Huey
# Indiana
# Jordy
# Colugo
# Soto
# Sister
# Bahgeera
# Liberty
# Aldo
# Betty Lou
# *Patrick
# Zebra
# Peter Pan
# *Brady
# Nani
# *Vinnie
# Lucho
# Deisel
# Cairo
# Snowbell
# *Mee Mee
# *Cee Cee
# Home Girl
# Klondike
# Loosey
# Daryl
# Corndog
# Jersey
# Chuyee
# *Stuart
# Cha-Chi
# Delena
# Zu Zu
# ...
# Daizy
# Remington Steel
# Big Brown
# *Lil Cabbage
# Catrick Swayze
# Tiger Two
# Laplace
# *Baby Spinach
# *Scuba Steve
# Zeus Deku
# Rauw
# Solie
# Kilanani
# Boaz
# *Zipp
# *Alexander Hamilton
# *Aaron Burr
# Trio
# Krispy
# *Martian
# Jaximo
# Mazda
# *Porsche
# *Rolls Royce
# Nipcey
# *Raikou
# *Suicune
# *Entei
# Oreo #2
# *Hela
# *Pomme
# Lady Faye
# *Caitlin
# Tanjerine
# 396G
# 368G
# Panic
# Pain
# Rhaegar
# *Mr. Wiggles
# Sensei Meow Meow
# More White/Black
# Mostly Black/White
# Mama Duck
# Scrawny Toscana
# *Firestar
# (More White)
# (More Orange)
# *Swiftie
# *Monfrere
# Chapii
# *Balverie
# *Braemar
# *Vanellope
# *Sir Ebony
# *Chidi
# *Tajani
# *Kedzie
# Radley
# Funnel Cake
# Marlei
# *Arvid
# Luma
# *Mr. Hollywood
# Jiblett
# Verse
# Linden
# Holder
# *Bitly
# Molly Jo
# J
# *Lyanna
# Mr Man
# *Rainbow Dash
# *Twilight Sparkle
# 142 Grams
# *Marcello
# *Scootaloo
# *Schena
# *Yellow Collar
# *Blue Collar
# Johnny Rambo
# *Bearnaise
# *Tzatziki
# *Foyot
# Race
# Bartina
# *Moscato
# *Mcconaughey
# Suwe'N
# Toodles
# Tiny Cat
# *Peepers
# Kelsier
# Kittykat
# Fuzzy Dunlop
# 373 Grams
# A909925
# A902926
# Henrieta
# Anakin Skinwalker
# *Polly Pocket
# Whiskey Pickles
# *Deven
# *Ansel Adams
# *Courvoisier
# Nyx Nova
# Oatchi
# *Nezzie
# *Cassterpiece Theatre
# *Troubadour
# D'Artagnan
# Lokis
# *Skateboard
# Stripee
# *Coleslaw
# Snikers
# A903157
# A903162
# A903163
# A903164
# A903165
# A903166
# A903160
# A903179
# Motzy
# Bella Rose
# Finway
# Tangelo
# Choclete
# 271 Grams
# *Wilhelmina
# *Dhalia
# Eurydice
# *Janice From Accounting
# Erna
# Federica
# Leiry
# A903399
# A903400
# A903401
# A903402
# A903403
# A903397
# A903411
# 903412
# A903413
# A903409
# Chani
# Mr. Einstein
# A903434
# Itty Bitty Bom Bom
# Stacy*
# *Chili Pepper
# Sandra (Maki)
# *Rice Puddin'
# *Red Beans
# Buckie
# *Blueheart
# *Tigerfur
# *Blackfoot
# A903517
# A903534
# *Copperfield
# Mr. Bubbles
# Gollo
# Katalina
# Knowledge Dog
# Sj
# A903578
# Boca
# *Applejack
# *Livewire
# *Major Melon
# Teo' Ke Ro
# *Pride
# *Mighty Mouse
# A903684
# *Electron
# *Proton
# Krea
# *Firebird
# *Barracuda
# *Chevelle
# *Keefe Gemstone
# *Kelvin Gemstone
# *Judy Gemstone
# Bellanova
# A903840
# *Updog
# *Mush
# *Miro
# *Roope
# *Stanky
# *Dutchy
# Kraft Single (Cheese)
# A903812
# *Good Dog Carla
# Marcellus
# Chops Aubergine
# Pawpad Asparagus
# 406 Grams
# Alexis Rose
# Ginseng
# *Caspar
# *Tab
# *Steely
# Ame
# *Shego
# Mari Lu
# Bunbun
# *Gala
# A904181
# Flaco The Taco
# *Gertrude Mcfuzz
# *Yertle
# *Mayzie
# Plomo
# *Buggie
# Iceberg
# Wolfee
# The Smoke
# 178G
# Novi
# *Sicily
# *Sir Squishums
# *Idli
# Lunaa
# Sherly
# 254 Grams
# 298 Grams
# 351 Grams
# *Penelope Catterton
# *Thomas Catterton
# *George Catterton
# *Stoopy
# Remie
# *Noodle Soup
# Macavity
# Nova Cyrs
# Marilu
# Ji Ji
# *Lister
# *Rimmer
# *Kryten
# *Kochanski
# *Cara Cara
# Stetson*
# Jahseh
# Mr Manly Man
# Hope*
# *Terracotta
# *Million Dollar Max
# *Marc
# *Scarface
# Nickson*
# *Trisket
# *Chick Magnet
# *C.J.
# Habib
# *Mary Wilson
# *Diana Ross
# *Blackstar
# Leo Oscar
# Baby Soco
# Chila
# *Princess Lady
# Lady Corazon
# A904701
# A904706
# *Almond Butter
# *Hei Hei (Mayday)
# Chocoti
# *Big Ernie
# *Sgt. Pepper
# Snackeater
# Tucker Harris
# Nobara
# Stout Unicorn
# A904827
# *Crush
# *Pym
# Chimiltrufia
# Scobby
# *Nanook
# *Urban Cowboy
# *Flufferina
# Raffaella
# Deuse
# *Sherbie
# *Lean Cuisine
# *Hungry Man
# *Hami
# Amaru
# *Lukah
# Jonesy
# Curley
# *Cassowary
# Bingka
# *Azriel
# Cashw
# Will Feral
# *Keiko
# *Jadzia
# *Henry Turner
# *Macchiato
# 390G
# 234G
# 306G
# *Bean Burrito
# *Sunday
# *Saturday
# Hydra
# A905248
# *Cheeseburger
# Pico De Gallo
# Dieesel
# Sir Walter Wallington
# *George Harrison
# *Ringo Starr
# N*John Lennon
# A905352
# Cowgirl Blue
# Delano
# Frankie Jr
# A905371
# A905373
# Baby Shay
# A905366
# Dwight Schrute
# *Irlene
# *Ceylon
# *Able
# Grams
# *Dunn
# Saltine
# Kunta
# Lady Mae
# A905412
# *Cassarella
# *Mandrake
# *Pepino
# *Coreen
# *Lute
# *Ukulele
# *Raisinet
# Princess Fiona
# Topochico
# *Halsey
# *Kiddo
# *Lady Elaine
# *Daniel Tiger
# *King Friday
# A905557
# *Kricket
# Thistle
# Klombo
# *Honey Butter
# *Sweet Tea
# Amani
# A905707
# *Pawlie
# *O.G.
# *Top Hat
# *Ritz
# *Treatie
# *Whisket
# *Big Bend
# *Reduced Sodium
# *Lightly Salted
# *Mary-Kate
# Bochee
# Little P
# Oakley Tabs
# *Neymar
# *Renaldo
# Jagy
# *King Tiny
# 177 G
# *Laa-Laa
# *Dipsy
# *Tinky Winky
# *Princess Sunala
# *Pencil
# Lired
# *Elgon
# *Ocean Breeze
# *Bleppy
# Jinji
# *Pothole
# *Nesta
# *Junimo
# Tortuga
# *Cason
# Marion
# *Hungry Hungry Hippo
# Jackalope
# *Abe Perlman
# *Falkorie
# *Aladdin Sane
# *Burpy
# *Tooty
# *Here
# *Everythings
# *Better
# Mag
# Mr. Wiggles
# Mr Baby
# *Beauty Queen
# Arelene
# Pomni
# *Orange Popsicle
# *Red Cherry Cobbler
# *Purple Fruity Crisp
# *Sugary Strawberry
# *Blueberry Pie
# Blaire
# *Ryvita
# Jaydub
# Matty The Catty
# Junipurr
# *Pecan Sandy
# *Milano
# *Iosefka
# Cerberus Maneater
# *Bomb Pup Pupsicle
# *Hotdog
# Layliah
# *Casscarina
# *Skipbo
# Skirty
# Artichoke
# *Candy Land
# *Leonardo "Leo"
# *Fargo
# Bella Donna
# *Summer Breeze
# Umbreon
# A906739
# Be'O
# Moondance
# *Monty Burns
# *Slinky Blinky
# Zurie
# Junie Pawtunia
# 119 Grams
# Purple
# *Bluekit
# Bilbo Bagins
# *Taiki
# A906871
# 388 Grams
# 353 Grams
# A906884
# Monica
# A906892
# A906893
# *Crumb
# *Americus Nation
# *Marsha Mallow
# *Muppley
# *Ice Cube
# Jay*
# Marc Anthoni
# *Mysterium
# *Farkle
# Shortcake
# Tiny Tom (Tt)
# Ero
# *Muffler
# Glimmer
# Charlie Brown
# Brindy  * Sophie
# *Rimfire
# Sneky
# *Livvy
# John Charlie
# *Cattails
# Uncle Bob
# *Vin Diesel
# Prez
# *Boot Scootin'
# Peresphone
# *Marcianita
# *Putty
# Mr.Turtule
# Mbapp
# *Patchwork
# Gashiki
# *Lazu
# *Pezzo
# Citrine
# *Marielle
# Mingi
# San
# Archie Bradley
# Mccall
# Bruce Lee Wayne
# Lowky
# *Cheez
# Hush Puppy
# *Lola Anne
# *Girl
# Mazekeen
# *Blinker
# 119 G-Green
# 104 G-Yellow
# Eeyore
# *Tree House
# *Torro
# A908046
# Cella
# *Cheez-It
# Morrison
# *Zanzibar
# Maxito
# Princess Cookie Doodle
# *Fancy Nancy
# Sindi
# *Tallkit
# Cello
# *Furtado
# Tones
# *Nunchucks
# *Dust Bunny
# *New York
# *Kelvin
# Koga
# *Baldur
# *Brynn
# Brian*
# *Yola
# 177 Gram
# *Saja
# Bramble
# Microwave
# *Tootsie Pop
# *Dubble Bubble
# *Jacqueline
# Lady Diana
# Obisidian
# Leo Benji
# Kenay
# Tanglewood
# Bella Rue
# Cossi
# *Cinnamon Swirl
# Caper
# *Tampa Ray
# Basas
# Soot
# Ali Howard
# Dutchie
# *Casspirin
# 365 Grams
# Jolene Ruth
# *Josefina
# *Kirsten
# Punxsutawney
# *Kilometer
# *Ralph Jr
# Graham Cracker
# Lil Miss
# *Fuzzy Mctickles
# Tippa
# *Harland
# *Beta
# *Yang
# *Yin
# *Katy Cat
# *Ohhh Bonnie Mcmurray
# *Thornton
# *Meatball Max
# *Pina Colada
# Pinguino
# 139 Grams
# *Mulch
# Greedo
# Skipps
# Kurt Balzary
# 228 G
# 222 G
# 221 G
# *Coconut Tree
# *David James
# Crawl
# *President
# *Governor
# *Vp Vice President
# *Senator
# *Prime Minister
# *Shogun
# (Red)
# (Green)
# (Pink)
# (Purple)
# (Blue)
# *Rugg
# Fito
# Lobo Bass Holmquist
# *Rasheed
# Pimpenta
# Pastique
# *Poire
# *Kohi
# *Tapi
# *Oca
# *Taro
# *Lychee
# Peach Cobbler
# *Lisbon
# *Bubbers
# *Confetti
# *Platy
# 58 Grams
# 65 Grams
# *Father Peppercorn
# Zoey*
# Lil Bear*
# *Nigiri
# *Saki
# Quija
# *Beau Poulet
# Benjamin Barry
# *Cassat
# *Renoir
# *Arnold Pawmer
# *Tiger Woods
# *Yuuma
# Crackers
# Little Cheese
# Jimmy Dean
# Achilles Maximus
# *Lickety Split
# Putz
# *Luna Lou
# *Texas Sheet Cake
# Danni
# Audrie
# Carrot Cake
# Malekai
# *Soley
# *Aine
# D'Artgnan
# *Evinrude
# *Scrub
# *Madame Snuggles
# *Frassasas
# *Cassafras
# *Fracasass
# *Cafrasass
# *Sacafrass
# Pibe
# Bo Peepz
# *Sha'Carri
# Blueberry Puptart*
# Beelzebuddy
# *Mrs. Brisby
# *Princess Consuela
# *Althea
# *Reeces Puppycups
# *Tumnus
# *Streuss
# *Mamma Mia
# A910357
# *Con Meo
# Snickerdoodle
# Corlys
# Wednesday Adams
# Renly
# *Myoga
# *Miroku
# *Sesshomaru
# *Kagome
# *Baby Shippo
# Yonah
# *Geedorah
# Derrick
# *Little Larry
# *Casscarone
# Maleficent
# Shiefra
# Lindley
# *Geist
# *Specter
# *Icahbod
# *Twin
# Happiness
# Joe*
# *Jinja
# *Leafpelt
# Leonardo*
# *Cootie
# Levi*
# J-Rock
# *Amity
# *Doyle
# *Baela
# Luna Grace
# *Dietrich
# Kendrick
# *Kune Kune
# *Mohawk
# 257 Grams
# Hargow
# *Mr. Garibaldi
# Mowie
# *Piggums
# Tascualita
# *Porky
# Peperchini
# Cadillac
# Unknown-Stray
# Lambchop*
# Viv Westwood
# Con Meo
# *Blue Laguna
# Yuno
# *Sigma
# Zayla
# Pupi
# *Peanut Brittle
# Creeg Cotter
# *Honey Butter Biscuit
# Atreus
# Honda
# *Picante
# *Grigio
# Havoc
# Haylo
# Peter Pumpkinhead
# *Top Sail
# *Morocco
# *Graha
# *Small Fry
# Pot
# Azzie
# *Chandy
# 228 Grams
# *Dimples
# Piknik
# Eunice
# Chew Barka*
# *Sarah Jessica Barker
# Luna Wayne
# *Booboo
# Lil Guy
# Chocolate Drop
# Vic-2
# Lexie Gray
# *Sorenson
# Ekmek
# *Nutter Butter
# Mama Bear Mae Mae
# *Patrizia
# *Rocky Boy
# *Montey
# *Flamekit
# *Polkadot
# *Razzle Dazzle
# *Jigglypuff
# A911724
# A911725
# A911726
# A911727
# A911728
# *Fido
# Megan
# A911745
# *Aquemini
# *Ms. Jackson
# *Cattanova
# Blessed
# Gun Gun
# *Lykiri
# Coruff
# Ray Ray
# Kitten 3
# Pretty Jane
# *Casscarine
# Mikie
# *Dunk
# *Moto Moto
# Blue Moon
# Lelo
# *Hitchcock
# *Calista
# *Clayton
# 127 Grams
# 320 Grams
# *Frank The Tank
# Grams 107
# Grams 135
# Grams 175
# Grams 222
# Grams 182
# Grams 198
# Grams 255
# *Balerion
# *Jean-Ralphio
# *Juanita
# *Akiko
# *Rampage
# Oboe
# Dorothy*
# *Aunt Em
# Uncle Henry*
# Tommie
# *Mitts
# *Tan
# *Green
# Denny
# Shardaisey
# Yarrow
# *Cassina
# Philip
# Midg
# *Dilbert
# Philbert
# Jamal
# *Chai Latte
# *Wills
# Jane Sparrow
# Bubbles*
# Raulito
# Buga
# Charming*
# *Raspberry Beret
# The Nugget
# *Pedro Pspspascal
# Smash
# *Dravin
# Canelita
# *Ho-Oh*
# Keeta
# *Bella Tricks
# *Pacha
# Yatra
# Gouda
# Hexx
# Ruppert
# Aussie Blue
# Siyah
# Mushu
# Asmodaus
# Wiglaf
# Wybie
# *Toetoe
# Yittle Man
# *Petrichor
# Smidge
# Mykala
# *Selena Kyle
# Tessaiga
# Bobcat
# Sisy Wilson
# *Shinichiro
# *Ms. Stripes
# Emerson Hope
# *Pumpkin Patch
# Joan Jett
# Nunu
# *Wilder
# *Chips
# Mr. Chow
# *Gumbi
# *Rock N Roll Rodney
# Dick Grayson
# *Rosalia Mommacita
# Infinity Grey
# *Kasper
# *Brofus
# *Tortie-Llini
# Apollo Austin
# *Balin
# *Meta
# Waffle Fry
# Onyx Spade Waiters
# *Madame Butterfly
# *Curious George
# 263 Grams
# *Bradbury
# *Tacoma
# Wiwi
# *Merci
# *Azeraq
# *Kiryu
# *Nishiki
# *Barlowe
# *Lightning Bolt
# *Cracker
# *Warlock
# Butch Cassidy
# *Hayden Pawner
# *Freddy Cougar
# *Count Sam
# Atena
# *Scallop
# Chappa
# *Barnes
# *Skooter
# *Jarrod
# *Lass
# Ace Aka Theodore
# Gumbi
# Jannet
# *Missi
# *Queeni
# Coca Cola
# *Marble Cake
# *Cassette
# *Discman
# *Vinyl
# Bobcat "Bubs"
# Rouxx
# Serena*
# Hunna
# Naylani
# True
# Chikki
# *Mallori
# *Little Miss
# *Cassimere
# *Grimby
# Doodles
# *Posh
# *Modry
# Mr.Toad
# *Princess Polka Dot
# *Cairo (Fka Moe)
# *Polly Jean
# *Orty
# *Heddy Lamar
# Fluff Wizard
# *Tootsie Roll
# Trap 18
# *Alondra
# *Onion Ring
# Toasted Marshmellow
# *Chai Tea
# *Maple Syrup
# *Cashmere Scarf
# *Earl Grey Tea
# Little Bitt
# *Paradise
# Mr. Mcgillicuddy
# Solis (Cannoli)
# *Alain
# Concrete
# Hilo Ray
# *Aquarius
# *Timothee Chalamet
# *Snax Daddy
# *Golden Sophia
# Chequis
# *Vox
# Dear Abby
# *Ireland
# *Marlon Garlin
# Matcha (Mama)
# *Fable
# Maple Rose
# Lady Clemantine
# *Remy Ma
# Tri
# Trulo
# Lionhart
# *Bram Stoker
# Astella
# *Pumpkin Spice
# Squash
# Nyla Amore
# *Baize
# 130 G
# 116 G
# 83 G
# 67 G
# *Apple Cider
# *Sweater Weather
# *Dratini
# Tinku
# Dashawn
# *Ashoka
# Baby Monroe
# *M&Ms
# One
# *Bubble Gum
# *Fun Dip
# *Frassy
# *Classy
# *Cassy
# *Adley
# *Lil Ghosty
# *Fundip
# Little Gray
# *Pumpernickel
# *Arthur Conan Doyle
# *Surprise
# *Delight
# *Honeycrisp
# Laszlo
# Blanquito
# Ichigo
# Comet Morin
# *Dreamsycle
# *Tutti Fruiti
# *Fregosi
# *Cassperella
# Neves
# 250G
# Chozen Toguchi
# *Cumbre
# *Baron Von Poodleman
# The Joker
# Kally
# Khamily
# *Shemp Howard
# Goodboy
# *Marsh
# Tom Boots
# *Zero
# Stanford
# *Arlet
# *Chalamet
# K C
# *Tommy Thompson
# Ninjat
# *Grizzy
# *Mr Pickles
# *Jolene*
# Luzetta
# Meech Kaine Hadnot
# Daddy Yankee
# Issa
# *Brother
# Baylard
# Sophi
# Cardboard
# *Heimdall
# Zeva Gabriella
# *Princess Margaret
# Lettie
# *Swishy
# *Mysterio
# *Boo Bear
# *Pricilla
# *Bibimbop
# Tatsumaki
# 239G
# Myrna
# Buchu
# Beefy Boi
# Kazin
# Shirley Temple
# Meech
# *Kanina
# *Pappy Van Winkle
# *Cardigan
# *Scarf
# *Chatty Catty
# Bella Bean
# Tilley
# Fajr
# *Mummy
# *Zombie
# *Wobble
# *Lexus
# *Cowbell
# *Dracula
# *Michael Scott
# Justin Timberlake
# *Misery
# Duquesa
# *Tytus
# *Ranger Rick
# *Roots
# Cheryl
# Goliath Jr
# *Tots
# Aspine
# *Walton
# Mileena
# *Dutchie
# Nefera
# *Yennifer
# Cerce
# *Cassarillo
# *Angel Baby
# *Cotton Ball
# *Zuma
# *Satchel Redman
# *Maggie Pie
# *Mcclane
# *Thresh
# *Mr. Natural
# La Rocka
# Littels
# Gyoza
# *Cassburger 'N Fries
# *Punkin Pie
# Pink Nose 179G
# Grey Nose 186G
# 166G
# Cakepop
# Caliope
# Diasy
# Scrappi
# Mish Mish
# Ghoul
# (Orange)
# Shoe
# *Zen
# Behbs
# Mamoru
# Manji
# *Pastel
# Tiara
# *Bertie Bott
# Dimimunto
# Orchid
# Creek
# *Turducken
# *Mr. President
# *Harlequin
# *Oreo Jack
# Winter Star
# *Cassgarita
# Sonya Meow Meow Martinez
# Solaire
# *Jolly Jelly
# Crochet
# Unknonw
# *Stormy Junior
# *Voidkit
# *Castillo
# *Caprice
# *Coaster
# *Scrambler
# *Tilt-A-Whirl
# *Carousel
# *Lorena
# *Bauble
# Ravel
# Burger Bun
# Cheesecake
# *Summit
# Ver
# *Cassiday
# *Fraser
# *Lacebark
# Bella Nova
# *Iced Tea
# *Toaster
# *Dewdrop
# *Elphaba
# *Fowler
# *Casstronaut
# Jem
# Ohmara
# *Aja
# *Shana
# Copita
# Mister Cat
# Dontez
# Bou
# Rayito
# *Yuletide
# *Frostbite
# Snowdrift
# *Flurry
# *Evergreen
# *Mags
# Kimbap
# Cerby
# *Buddy Bucks
# *Nine
# *Luna Azul
# Babas
# Hua
# Bodeen
# *Nutcracker
# *Fiyero
# Zemya
# *Poinsetta
# *Merrybell
# *Parka
# Tio
# Eclypse
# *Bobsled
# Badshah
# *Blessica
# K.K.
# Runi
# Repete
# *Sabina
# *Wolfina
# Salma
# Bellamy
# *Pepinillo
# Imzadi
# Mrs. Blackpantherman
# *Mama Jade
# Antoni
# Thaigo
# Nisha
# Baggs
# Solstice
# Kaspa
# Olive Rae
# Mr. Mr
# *Mrs. Howell
# Fritzel
# *Kenai
# *Peppermint Patty
# Clayton Felipe
# *Ms.Klaus
# Marci-Lyn
# Sanjii
# *Lil Smokey
# *Pebble
# *Spinkle
# *Frostnip
# *Iceburg
# *Burrr
# *Calum
# Saige
# *Anginetti
# *Flibbertigibbet
# Bing Bong
# *Shiver
# *Gwyn
# *Marshamallow
# *Ridgeley
# Zell
# *Wendy O
# *The Mouse King
# Betty *Boop*
# Suzume
# *And Kisses
# *Komet
# *Costco
# *Christmas Pudding
# *Elvy
# *Baby Bell
# Natalie
# Chappy
# *Blasen
# *Nat King Cole
# *Graham Cracker
# Chein Chein
# *Sir Ham Sammich
# Glorp
# Gummy
# *Thierry
# *Kazoo
# *Rosalynn
# Chi-Chi
# Clicquot
# *The Count
# *Gungi
# *Rhysand
# Pharoah
# *Vera Verto
# *Newlyn
# Rivia
# *Halle Berry
# Helo
# *Snakey Jakey
# Tyche
# Convict
# *Stonekit
# *Celadon
# *Et
# *Bonsai
# *Lita
# Alamo
# Dj Meow Meow
# Woodrow (Woodie)
# Bobax
# A.C. Slater
# *Mononoke
# *Eight Track
# Junk Rat
# *Moo Deng
# Attitude
# Thug
# *Jinxy
# Ether
# Waco
# *Sims
# *Ziggie
# Catero
# *Pepe Le Pew
# *Elmer Fudd
# *Tweety Bird
# *Marvin The Martian
# *Wile E. Coyote
# Marcelous
# Mr. Peanutbutter
# Ayah
# *Magnificat
# Buffey
# *Chilis
# *Dango
# Abracatdabra 10
# Rangi
# *Bella Boo
# Midra
# *Cheetoh
# *Duckie
# *Bark Twain
# Virgo
# *Hachi
# Darchy
# Penny The Food Slayer
# Pam
# Moon Light
# Houlihan
# Marley Ramirez-Pietila
# Alibi
# 523 Grams
# 493 Grams
# 450 Grams
# 410 Grams
# 447 Grams
# Valetine
# *L.A.A.N.I.H.Y
# Meany
# Chonks
# High Class
# Shinzo
# Gravy Boat
# Bono
# *Jacky
# Pom
# Minette
# *Toodle
# Juna Ivy
# *Lago
# 468 Grams
# 480 Grams
# 561 Grams
# 396 Grams
# 433 Grams
# *Sugar Baby
# Jiyu
# *Snookums
# Muñeco
# *Daisey
# Maelys
# *Mei Mei
# 2-Lo
# Corn Muffin
# Yilo
# Kyle Maclachlan
# Ghosty Cantu
# Yuritza
# *Hazelnut
# Vampire
# Joleen
# Oak
# Sloane
# Blackfoot
# Shugga
# *Thatch
# *Jack Sparrow
# Neddie
# *Princess Donut
# Girly Pop
# Cilffort
# Hams
# *Svanna
# Zilly
# *Babes
# *Amour
# *Goldy
# *De Beauvoir
# *Honey Boy
# Cawsmuk
# Mogly
# *Amy Lee
# Yuji
# Kush Devil
# *Amalie
# Bubber Jr
# *Treacle Tart
# *Aniston
# Deava
# *Leonardo Dicatrio
# Odyn
# Dudey
# *Chappell
# Renisha
# Baltazar
# *Noir
# *Shotzey
# *Beanie Baby
# *Francisco
# Cabo
# Sabor
# Mici
# *Snowy
# Sugar Snap
# Jalepeno
# Lasso
# Borrez "Bo"
# Pavlova
# Noele
# Azra
# Bengali
# *Xayden
# Ria
# Olso
# *James Earl Bones
# *Khione
# D - Betta - 1
# D - Betta - 2
# D - Betta - 3
# D - Betta - 4
# L - Betta - 1
# L - Betta - 2
# Jennifer
# *Lt Winters
# Kit 1
# Kit 2
# Kit 3
# Kit 4
# *Thousand Sunny
# Banjamin
# Ghostface
# *Chiqui
# *Queen Iduna
# Cappucino
# Dew Drop
# Calzone
# Big Papa
# *Yellow Submarine
# *Strawberry Fields
# *Sgt Pepper
# Trueno
# *Rocky Raccoon
# *Good Day Sunshine
# Lenora
# *Corazon
# *Schnucki
# Blach
# Maple Donut
# Toochka
# Rouje
# Sol Perez
# Baby Charles
# Benjamin Cheeto
# Kaisa
# Princess Charlotte
# *Yazmin
# *Dutton
# Twoof
# *Squabbles
# *Hazey
# Blinks
# *Murdock
# Count Dooku
# *Hazen Audel
# Oli
# *Princess Vivi
# *Piggle
# Tabi
# Pyro
# *Dawg
# Princess Kitty
# *Jane Austen
# Bub The Chub
# Sarobie
# Joselyn
# *Mr Snoot
# *Garbonzo
# Drusky
# *Pua
# Tapioca
# *Velour
# Shey
# Lazaro
# *Ukelele
# Jaspar
# Plushkin
# *Kiva
# *Dole Whip
# Psalm
# *Gerry
# *Lady Jessica
# *Anna Banana
# Sir Didymus
# *Choco-Cat
# *Potpie
# *Missy Elliott
# * Lil’ Kim
# *Slim Shady
# *Doechii
# Pride
# Arjuna
# *Bippidy
# Dusty Rhodes
# Azalia
# *Woozy
# *Shaboozey
# Sharlotte
# *Shadowy
# *Boppity
# Beard
# Kealy
# *Sally Sue
# *Lady Wigglebottom
# *Arun
# *Lucy Dacus
# *Julien Baker
# *Phoebe Bridgers
# Skay
# *Pepper Ann
# Chief Madrid
# Mr. Scrungles
# Miss Meow
# Akima
# 24-1809C Snowball
# *Mazzy Star
# Bluie
# *Nutty
# Hedwig
# *Brindle Bob
# Drew Carey
# Bonito
# Dado
# *Homeboy
# *Karlie
# Pickles Lee
# *Satsuma
# *Xia
# Wari
# *Kailani
# Akame
# Mr.Stinky
# Tiny Clyde
# Facudo
# *Pokyo
# Peepaw
# *Hen
# *Armstrong
# Austin Powers
# Nicholai
# *Donatella
# *Honolulu
# *Mon Cheri
# *Ravi
# Akxel
# Cugo
# Nour
# *Fawn Frances
# *Red Rachel
# *Brindle Bridget
# *Brown Betty
# Borrachito
# N'Sicha
# *Dunkerley
# Fizbit
# *Tweedle Dum
# A K
# *Pistacchio
# *Bookworm
# Arista Rain
# *Thai Iced Tea
# *Lizard
# *Cheaddy
# Minsk
# *Baby Shark Do Do Do
# Dee Oh Gee
# *Ponzu
# *Takoyaki
# *Shumai
# *Fluffstur
# Billy Girl
# *Teddy Jo
# Fae Shadow
# *Blackbeard
# Schmoo Moo
# Gee Gee
# Driskill
# Kidd
# Hancho
# Lucha
# Zeuz
# Alastor
# *Sunita
# Bagg
# *Mazow
# Saya
# *Sargeant
# Hawkins
# *Stinker
# *Bonnie Mae
# Simba Duarte Colin
# Ashlee
# *Stacie
# Caprico
# *Pearlina
# *Pinot Grigio
# *Mr. Bing
# Shea
# Major Lilly
# Seraphine
# *Corncob
# *Pizazz
# *Jay Jay
# Pewee
# *Vaeda
# *Laszlo/Goose
# Petee
# *Buns
# Ranch
# *Faygo
# *Chipperoni
# Payasa
# Axel Reid
# Zeus H5
# *Miss Magoo
# Mr. Squibbles
# *Panther Pete
# *Dimple
# Omen
# Fable
# Bandee
# *Abby Jane
# Drakey
# *Lagatha
# Dilly Doodle
# Hermini
# Pizza
# Rayita
# *Galaxy Destroyer
# *Duckling
# Obito
# *Lil Luna
# *Tsunade
# *Naruto
# *Ino
# *Temari
# *Hinata
# *Rock Lee
# *Sasuke
# *Kosa
# *Malorie
# Pumara
# *Mr. Tangerine Man
# *Siara
# *Cookies And Cream
# Yellow Atlas
# *Key West
# *Paulo
# *Ferris Bueller
# Pao
# Good Boy
# Payne
# Zariah
# *Abby The Tabby

# %% [markdown]
# I've noticed lots of asterisks (*), and am wary also of things such as leading and trailing spaces, so let's remove those

# %%
# I will keep most punctuation, for names like Mr. Dog or O'Malley

aacIn['Name'] = aacIn['Name'].astype(str)
aacIn['Name'] = aacIn['Name'].apply(lambda x: re.sub(r"[^\w\s\.\'\-]", '', x).strip())

# %%
# Check if that worked...

names_new = aacIn['Name'].unique().tolist()
for name in names_new[0:20]:
    print(name)
# Out:
# Nina
# nan
# Stevie
# Donnie
# Pippin
# Sylvio
# Claire
# Heather
# Petunia
# Bismark
# Mason
# Dixon
# Asti
# Kochka
# Grace
# Buffy
# Cate
# Moose
# Estrella
# Lucio

# %%
# Which names are most common?

print(aacIn['Name'].value_counts()[aacIn['Name'].value_counts() > 200])
# Out:
# Name
# nan         49740
# Luna          812
# Max           792
# Bella         723
# Daisy         575
# Charlie       550
# Rocky         528
# Coco          463
# Lucy          456
# Blue          438
# Buddy         429
# Lola          417
# Princess      417
# Milo          338
# Oreo          336
# Zeus          333
# Jack          328
# Cookie        307
# Shadow        304
# Bear          295
# Lily          290
# Molly         289
# Sadie         283
# Toby          279
# Lucky         271
# Mia           267
# Duke          261
# Pepper        260
# Nala          259
# Ginger        246
# Chloe         241
# Leo           239
# Penny         234
# Chico         232
# Oliver        232
# Rosie         227
# Maggie        227
# King          224
# Ruby          220
# Lady          216
# Honey         216
# Bailey        215
# Smokey        212
# Stella        211
# Marley        205
# Name: count, dtype: int64

# %% [markdown]
# I think that will do, for now. Names likely will not be a much of an analytical aspect of the project; they are just fun ways to show the stories of these animals when it comes to my finishing presentation and write-up.

# %% [markdown]
# #### Outcomes

# %%
# Doing the same thing as above with Outcome names: stripping white space, asterisks, and other unusual characters, while leaving certain punctuation

aacOut['Name'] = aacOut['Name'].astype(str)
aacOut['Name'] = aacOut['Name'].apply(lambda x: re.sub(r"[^\w\s\.\'\-]", '', x).strip())

# %%
# And previewing the top values

print(aacOut['Name'].value_counts()[aacOut['Name'].value_counts() > 200])
# Out:
# Name
# nan         49533
# Luna          810
# Max           791
# Bella         726
# Daisy         574
# Charlie       554
# Rocky         533
# Coco          464
# Lucy          456
# Blue          438
# Buddy         426
# Princess      421
# Lola          415
# Oreo          336
# Milo          334
# Zeus          333
# Jack          326
# Cookie        310
# Shadow        303
# Bear          294
# Molly         293
# Lily          289
# Sadie         285
# Toby          281
# Lucky         271
# Mia           267
# Nala          261
# Duke          260
# Pepper        257
# Ginger        247
# Chloe         241
# Leo           239
# Oliver        232
# Penny         232
# Chico         232
# Maggie        230
# Rosie         227
# King          222
# Ruby          221
# Bailey        216
# Lady          214
# Honey         214
# Smokey        211
# Stella        211
# Marley        205
# Name: count, dtype: int64

# %% [markdown]
# I'm happy to leave the names alone, otherwise. Moving on!

# %% [markdown]
# ### AnimalType

# %% [markdown]
# #### Intakes

# %%
# Check out our categories

print(aacIn['AnimalType'].value_counts())
# Out:
# AnimalType
# Dog          94406
# Cat          69009
# Other         8933
# Bird           876
# Livestock       33
# Name: count, dtype: int64

# %% [markdown]
# Those categories are probably fine, although I wonder about "Other" and would love to add in a "Wildlife" category, if possible.

# %%
# What breeds is "Other" comprised of?

other_breeds = aacIn.loc[aacIn['AnimalType'] == 'Other', 'Breed'].unique()
pprint(other_breeds)
# Out:
# array(['Bat Mix', 'Rabbit Sh Mix', 'Raccoon Mix', 'Skunk', 'Raccoon',
#        'Opossum Mix', 'Bat', 'Ferret', 'Californian Mix', 'Skunk Mix',
#        'Rabbit Sh', 'Fox Mix', 'Opossum', 'Armadillo Mix', 'Squirrel Mix',
#        'Guinea Pig Mix', 'Rabbit Sh/Lop-Mini', 'Fox', 'Turtle Mix',
#        'Rex Mix', 'Guinea Pig', 'Squirrel', 'Rat', 'Rat Mix',
#        'Californian', 'Coyote Mix', 'Hamster Mix', 'English Spot Mix',
#        'Lionhead Mix', 'Ferret Mix', 'Silver Mix', 'Tortoise Mix',
#        'Sugar Glider', 'Dutch Mix', 'Jersey Wooly Mix', 'Cottontail Mix',
#        'Lop-English Mix', 'Armadillo', 'Cold Water', 'American Mix',
#        'Lop-Holland Mix', 'Lionhead', 'Rabbit Lh Mix', 'Snake',
#        'Dutch/Rabbit Sh', 'Snake Mix', 'Lizard Mix', 'American Sable',
#        'New Zealand Wht Mix', 'Lop-Mini Mix', 'Mouse Mix', 'Hotot Mix',
#        'Hamster', 'Cinnamon', 'Rabbit Lh', 'American Sable Mix',
#        'Gerbil Mix', 'Angora-French Mix', 'Dutch', 'Tarantula', 'Turtle',
#        'Frog', 'Snake/Snake', 'Ringtail Mix', 'Lizard',
#        'Netherlnd Dwarf Mix', 'Coyote', 'Rex-Mini', 'Bobcat Mix',
#        'Lop-Holland', 'Checkered Giant Mix', 'Lop-Mini', 'Havana Mix',
#        'Hedgehog', 'Chinchilla-Amer Mix', 'Chinchilla-Stnd Mix',
#        'Polish Mix', 'Otter Mix', 'English Spot', 'Harlequin Mix',
#        'Netherlnd Dwarf', 'Chinchilla Mix', 'Tortoise',
#        'Rex-Mini/Lop-English', 'Angora-English Mix', 'Cinnamon Mix',
#        'Rex', 'Lop-Amer Fuzzy Mix', 'Rex-Mini Mix', 'Dutch/Angora-Satin',
#        'Tropical Mix', 'Flemish Giant', 'Deer Mix', 'American',
#        'Belgian Hare', 'Britannia Petit Mix', 'Himalayan Mix',
#        'Cold Water Mix', 'Prairie Dog Mix', 'Lop-Amer Fuzzy',
#        'Rhinelander Mix', 'Belgian Hare Mix', 'Flemish Giant Mix',
#        'Lop-Mini/Lop-Holland', 'Hermit Crab Mix', 'Beveren Mix',
#        'Angora-Satin Mix', 'Snake/Python', 'Rex/Lop-English', 'Havana',
#        'Polish', 'Chinchilla-Amer', 'Gerbil', 'New Zealand Wht',
#        'Chinchilla', 'Hotot', 'Mouse', 'Dwarf Hotot', 'Otter',
#        'Angora-Satin', 'Cottontail', 'Lop-English', 'Lop-Mini/Hotot',
#        'Chinchilla-Stnd', 'Jersey Wooly', 'Angora-English',
#        'New Zealand Wht/Lop-Holland', 'Lizard/Bearded Dragon',
#        'Rabbit Sh/Dwarf Hotot', 'Himalayan', 'Florida White',
#        'Bat/Mex Free-Tail', 'Turtle/Redeared Slider', 'Lop-French',
#        'Ringtail', 'Lizard/Gecko', 'Deer', 'Tropical',
#        'Rabbit Sh/Californian'], dtype=object)

# %%
# How many breeds is that?

print(aacIn.loc[aacIn['AnimalType'] == 'Other', 'Breed'].nunique())
# Out:
# 139

# %%
# With only 100-some breed examples, I think I can do this manually and create a list of all wildlife "breeds" that have shown up thus far

wildlife = ['Bat Mix', 'Raccoon Mix', 'Skunk', 'Raccoon', 'Opossum Mix', 'Bat', 'Skunk Mix', 'Fox Mix', 
            'Opossum', 'Armadillo Mix', 'Squirrel Mix', 'Fox', 'Turtle Mix', 'Squirrel', 'Rat', 'Rat Mix', 
            'Coyote Mix', 'Tortoise Mix', 'Cottontail Mix', 'Armadillo', 'Cold Water', 'Snake', 'Snake Mix', 
            'Lizard Mix', 'Mouse Mix', 'Tarantula', 'Turtle', 'Frog', 'Snake/Snake', 'Ringtail Mix', 
            'Lizard', 'Coyote', 'Bobcat Mix', 'Otter Mix', 'Tortoise', 'Deer Mix', 'Cold Water Mix', 
            'Prairie Dog Mix', 'Mouse', 'Otter', 'Cottontail', 'Bat/Mex Free-Tail', 
            'Turtle/Redeared Slider', 'Ringtail', 'Lizard/Gecko', 'Deer']

# There are some that I suspect could be wildlife, but am not fully certain of, so I will check those out

suspects = ['Turtle Mix', 'Rat', 'Rat Mix', 'Coyote Mix', 'Tortoise Mix', 'Cottontail Mix', 'Cold Water', 'Snake', 'Snake Mix',
            'Lizard Mix', 'Mouse Mix', 'Tarantula', 'Turtle', 'Frog', 'Snake/Snake', 'Lizard', 'Tortoise',
            'Turtle/Redeared Slider', 'Lizard/Gecko']

aacIn.loc[aacIn["Breed"].isin(suspects), ['Name', 'IntakeType', 'Breed', 'Color']]
# Out:
#        Name       IntakeType       Breed         Color
# 2941    nan         Wildlife  Turtle Mix  Brown/Yellow
# 4468    nan  Owner Surrender         Rat     Tan/White
# 4469    nan  Owner Surrender         Rat   Black/White
# 4705    nan            Stray     Rat Mix         White
# 5476    nan         Wildlife  Coyote Mix           Red
# ...     ...              ...         ...           ...
# 172292  nan    Public Assist      Lizard  Yellow/Black
# 172293  nan    Public Assist      Lizard  Yellow/Black
# 172633  nan            Stray      Turtle  Brown/Orange
# 172993  nan    Public Assist   Tarantula         Brown
# 172994  nan    Public Assist   Tarantula         Brown
#
# [354 rows x 4 columns]

# %%
# Hm, 363 is a low of rows to go through manually. To narrow it down, I will find which entries have a "Wildlife" intake type first

suspects_df = aacIn.loc[
    (aacIn["Breed"].isin(suspects)) &
    (aacIn["IntakeType"] == "Wildlife")
]

# Show the matching breeds

pprint(list(suspects_df["Breed"].unique()))
# Out:
# ['Turtle Mix',
#  'Coyote Mix',
#  'Tortoise Mix',
#  'Mouse Mix',
#  'Cottontail Mix',
#  'Snake',
#  'Rat Mix',
#  'Rat',
#  'Snake Mix',
#  'Turtle',
#  'Tortoise',
#  'Lizard']

# %%
# Add those names to our wildlife "breed" list

wildlife.extend(suspects_df["Breed"].unique().tolist())

# %%
# Now for the rest, breeds that I will need to investigate manually.

remaining_suspects = [breed for breed in suspects if breed not in suspects_df["Breed"].unique()]

# Let's print those rows

aacIn.loc[aacIn["Breed"].isin(remaining_suspects), ['Name', 'IntakeType', 'Breed', 'Color']]
# Out:
#                Name       IntakeType                   Breed         Color
# 11703   Plecostomus    Public Assist              Cold Water    Black/Gray
# 11704         Oscar    Public Assist              Cold Water   Gray/Orange
# 11705         Oscar    Public Assist              Cold Water  White/Orange
# 11708           Koi    Public Assist              Cold Water  Orange/White
# 11709   Plecostomus    Public Assist              Cold Water    Black/Gray
# 15294           nan            Stray              Lizard Mix           Tan
# 24402           nan    Public Assist              Lizard Mix           Tan
# 26912           nan    Public Assist              Lizard Mix  Black/Yellow
# 32482           nan  Owner Surrender               Tarantula     Brown/Red
# 33074           nan    Public Assist                    Frog         Brown
# 33075           nan    Public Assist               Tarantula         Brown
# 33076           nan    Public Assist               Tarantula         Brown
# 33077           nan    Public Assist               Tarantula         Brown
# 33078           nan    Public Assist               Tarantula         Brown
# 33079           nan    Public Assist               Tarantula         Brown
# 33080           nan    Public Assist             Snake/Snake     Tan/Brown
# 38017           nan            Stray              Lizard Mix         Green
# 38018           nan            Stray              Lizard Mix         Green
# 38019           nan            Stray              Lizard Mix         Green
# 41730           nan            Stray              Lizard Mix         Green
# 52667           nan            Stray              Lizard Mix         Brown
# 56219           nan            Stray              Lizard Mix           Tan
# 74843           nan            Stray              Lizard Mix      Tricolor
# 77896           nan    Public Assist              Cold Water         Black
# 77897           nan    Public Assist              Cold Water         Black
# 77898           nan    Public Assist              Cold Water         Black
# 77899           nan    Public Assist              Cold Water         Black
# 86596           nan            Stray              Lizard Mix   Green/Brown
# 104527          nan    Public Assist              Cold Water         Black
# 104528          nan    Public Assist              Cold Water         Black
# 104529          nan    Public Assist              Cold Water         Black
# 104530          nan    Public Assist              Cold Water         Black
# 104531          nan    Public Assist              Cold Water         Black
# 104532          nan    Public Assist              Cold Water         Black
# 104533          nan    Public Assist              Cold Water         Black
# 104534          nan    Public Assist              Cold Water         Black
# 104535          nan    Public Assist              Cold Water         Black
# 104536          nan    Public Assist              Cold Water         Black
# 104537          nan    Public Assist              Cold Water         Black
# 104538          nan    Public Assist              Cold Water         Black
# 104539          nan    Public Assist              Cold Water         Black
# 141488          nan    Public Assist              Cold Water          Gray
# 141489          nan    Public Assist              Cold Water          Gray
# 141490          nan    Public Assist              Cold Water          Gray
# 141491          nan    Public Assist              Cold Water          Gray
# 141492          nan    Public Assist              Cold Water          Gray
# 160647          nan            Stray  Turtle/Redeared Slider   Green/Black
# 165721          nan    Public Assist            Lizard/Gecko  Yellow/Brown
# 166427          nan            Stray            Lizard/Gecko   Brown/Black
# 166428          nan            Stray            Lizard/Gecko   Brown/Black
# 172993          nan    Public Assist               Tarantula         Brown
# 172994          nan    Public Assist               Tarantula         Brown

# %%
# 61 isn't too bad. Let's make a mini dataframe of these to work with.

sus_manual = aacIn.loc[aacIn["Breed"].isin(remaining_suspects), ['Name', 'IntakeType', 'Breed', 'Color']]
print(sus_manual['Breed'].value_counts())
# Out:
# Breed
# Cold Water                27
# Lizard Mix                11
# Tarantula                  8
# Lizard/Gecko               3
# Frog                       1
# Snake/Snake                1
# Turtle/Redeared Slider     1
# Name: count, dtype: int64

# %%
# Start with the most common, "Cold Water"

sus_manual.loc[sus_manual['Breed'] == 'Cold Water', :]
# Out:
#                Name     IntakeType       Breed         Color
# 11703   Plecostomus  Public Assist  Cold Water    Black/Gray
# 11704         Oscar  Public Assist  Cold Water   Gray/Orange
# 11705         Oscar  Public Assist  Cold Water  White/Orange
# 11708           Koi  Public Assist  Cold Water  Orange/White
# 11709   Plecostomus  Public Assist  Cold Water    Black/Gray
# 77896           nan  Public Assist  Cold Water         Black
# 77897           nan  Public Assist  Cold Water         Black
# 77898           nan  Public Assist  Cold Water         Black
# 77899           nan  Public Assist  Cold Water         Black
# 104527          nan  Public Assist  Cold Water         Black
# 104528          nan  Public Assist  Cold Water         Black
# 104529          nan  Public Assist  Cold Water         Black
# 104530          nan  Public Assist  Cold Water         Black
# 104531          nan  Public Assist  Cold Water         Black
# 104532          nan  Public Assist  Cold Water         Black
# 104533          nan  Public Assist  Cold Water         Black
# 104534          nan  Public Assist  Cold Water         Black
# 104535          nan  Public Assist  Cold Water         Black
# 104536          nan  Public Assist  Cold Water         Black
# 104537          nan  Public Assist  Cold Water         Black
# 104538          nan  Public Assist  Cold Water         Black
# 104539          nan  Public Assist  Cold Water         Black
# 141488          nan  Public Assist  Cold Water          Gray
# 141489          nan  Public Assist  Cold Water          Gray
# 141490          nan  Public Assist  Cold Water          Gray
# 141491          nan  Public Assist  Cold Water          Gray
# 141492          nan  Public Assist  Cold Water          Gray

# %% [markdown]
# From the names that are present, these look like pets, so I am going to omit that from our wildlife list.

# %%
# Next, "Lizard Mix"

sus_manual.loc[sus_manual['Breed'] == 'Lizard Mix', :]
# Out:
#       Name     IntakeType       Breed         Color
# 15294  nan          Stray  Lizard Mix           Tan
# 24402  nan  Public Assist  Lizard Mix           Tan
# 26912  nan  Public Assist  Lizard Mix  Black/Yellow
# 38017  nan          Stray  Lizard Mix         Green
# 38018  nan          Stray  Lizard Mix         Green
# 38019  nan          Stray  Lizard Mix         Green
# 41730  nan          Stray  Lizard Mix         Green
# 52667  nan          Stray  Lizard Mix         Brown
# 56219  nan          Stray  Lizard Mix           Tan
# 74843  nan          Stray  Lizard Mix      Tricolor
# 86596  nan          Stray  Lizard Mix   Green/Brown

# %% [markdown]
# This is less straightforward, so I will have to use my judgement. "Stray" insinuates that these may be domestic animals, so I will omit this category from the wildlife list as well.

# %%
# I will do the rest all at once

sus_manual.loc[aacIn["Breed"].isin(['Tarantula', 'American', 'Lizard/Gecko',
                                    'Frog', 'Snake/Snake', 'Turtle/Redeared Slider']), :]
# Out:
#        Name       IntakeType                   Breed         Color
# 32482   nan  Owner Surrender               Tarantula     Brown/Red
# 33074   nan    Public Assist                    Frog         Brown
# 33075   nan    Public Assist               Tarantula         Brown
# 33076   nan    Public Assist               Tarantula         Brown
# 33077   nan    Public Assist               Tarantula         Brown
# 33078   nan    Public Assist               Tarantula         Brown
# 33079   nan    Public Assist               Tarantula         Brown
# 33080   nan    Public Assist             Snake/Snake     Tan/Brown
# 160647  nan            Stray  Turtle/Redeared Slider   Green/Black
# 165721  nan    Public Assist            Lizard/Gecko  Yellow/Brown
# 166427  nan            Stray            Lizard/Gecko   Brown/Black
# 166428  nan            Stray            Lizard/Gecko   Brown/Black
# 172993  nan    Public Assist               Tarantula         Brown
# 172994  nan    Public Assist               Tarantula         Brown

# %% [markdown]
# I'm going to have to intuit here a few things:
# * Names mean they are not a wild animal
# * "Owner Surrender" also means not wild
# * "Public Assist" leans toward wildlife
# * This leaves "Frog", "Snake/Snake", "Turtle/Redeared Slider", "Tarantula", and "Lizard/Gecko" as likely wildlife.

# %%
# Add them to our wildlife list

wildlife.extend(["Frog", "Snake/Snake", "Turtle/Redeared Slider", "Lizard/Gecko", "Tarantula"])

# And now we see how many entries can be labeled "AnimalType" = "Wildlife"

aacIn.loc[aacIn["Breed"].isin(wildlife), ['Name', 'IntakeType', 'Breed', 'Color']]
# Out:
#            Name IntakeType        Breed        Color
# 78          nan   Wildlife      Bat Mix        Brown
# 122         nan   Wildlife  Raccoon Mix        Brown
# 137         nan   Wildlife        Skunk  Black/White
# 142         nan   Wildlife  Raccoon Mix  Black/White
# 218         nan   Wildlife      Bat Mix  Brown/Brown
# ...         ...        ...          ...          ...
# 173180      nan   Wildlife      Raccoon   Gray/Black
# 173197      nan   Wildlife          Bat  Brown/Brown
# 173208      nan   Wildlife          Fox          Red
# 173209      nan   Wildlife      Raccoon   Black/Gray
# 173232  Unknown   Wildlife          Bat        Brown
#
# [6948 rows x 4 columns]

# %%
# And change their AnimalType "Other" label to "Wildlife"

aacIn.loc[aacIn["Breed"].isin(wildlife) & (aacIn["AnimalType"] == "Other"), "AnimalType"] = "Wildlife"

# Check it worked
aacIn.loc[aacIn["Breed"].isin(wildlife), ['Name', 'IntakeType', 'Breed', 'AnimalType']]
# Out:
#            Name IntakeType        Breed AnimalType
# 78          nan   Wildlife      Bat Mix   Wildlife
# 122         nan   Wildlife  Raccoon Mix   Wildlife
# 137         nan   Wildlife        Skunk   Wildlife
# 142         nan   Wildlife  Raccoon Mix   Wildlife
# 218         nan   Wildlife      Bat Mix   Wildlife
# ...         ...        ...          ...        ...
# 173180      nan   Wildlife      Raccoon   Wildlife
# 173197      nan   Wildlife          Bat   Wildlife
# 173208      nan   Wildlife          Fox   Wildlife
# 173209      nan   Wildlife      Raccoon   Wildlife
# 173232  Unknown   Wildlife          Bat   Wildlife
#
# [6948 rows x 4 columns]

# %%
# There seemed to be a lot of rabbit breeds. Let's see if it is worth changing their category.

rabbits = [
    'Rabbit Sh Mix', 'Rabbit Sh', 'Californian Mix', 'Californian',
    'Rabbit Sh/Lop-Mini', 'Rex Mix', 'Jersey Wooly Mix', 'Cottontail Mix',
    'Lop-English Mix', 'American Mix', 'Lop-Holland Mix', 'Lionhead',
    'Rabbit Lh Mix', 'Dutch/Rabbit Sh', 'Hotot Mix', 'Rabbit Lh',
    'American Sable Mix', 'Angora-French Mix', 'Dutch', 'Netherlnd Dwarf Mix',
    'Checkered Giant Mix', 'Lop-Mini', 'Havana Mix', 'Chinchilla-Amer Mix',
    'Chinchilla-Stnd Mix', 'Polish Mix', 'English Spot', 'Harlequin Mix',
    'Netherlnd Dwarf', 'Chinchilla Mix', 'Rex-Mini', 'Rex',
    'Lop-Amer Fuzzy Mix', 'Rex-Mini Mix', 'Dutch/Angora-Satin',
    'Flemish Giant', 'Belgian Hare', 'Britannia Petit Mix',
    'Himalayan Mix', 'Flemish Giant Mix', 'Lop-Amer Fuzzy', 'Rhinelander Mix',
    'Belgian Hare Mix', 'Lop-Mini/Lop-Holland', 'Beveren Mix',
    'Angora-Satin Mix', 'Rex/Lop-English', 'Havana', 'Polish',
    'Chinchilla-Amer', 'Dwarf Hotot', 'Angora-Satin', 'Cottontail',
    'Lop-English', 'Lop-Mini/Hotot', 'Chinchilla-Stnd', 'Jersey Wooly',
    'Angora-English', 'New Zealand Wht/Lop-Holland', 'Rabbit Sh/Dwarf Hotot',
    'Himalayan', 'Florida White', 'Lop-French', 'New Zealand Wht', 'American',
    'Cinnamon', 'Cinnamon Mix'
]

aacIn.loc[aacIn["Breed"].isin(rabbits), ['Name', 'IntakeType', 'Breed', 'AnimalType']]
# Out:
#             Name       IntakeType            Breed AnimalType
# 112        Birch            Stray    Rabbit Sh Mix      Other
# 237        Dante  Owner Surrender    Rabbit Sh Mix      Other
# 350          nan            Stray    Himalayan Mix        Cat
# 518          nan            Stray  Californian Mix      Other
# 519          nan            Stray  Californian Mix      Other
# ...          ...              ...              ...        ...
# 172248       nan            Stray        Rabbit Sh      Other
# 172506    Lottie  Owner Surrender        Rabbit Sh      Other
# 172507      Lola  Owner Surrender        Rabbit Sh      Other
# 172537  Napoleon            Stray        Rabbit Sh      Other
# 173147       nan            Stray        Rabbit Sh      Other
#
# [1061 rows x 4 columns]

# %% [markdown]
# Out of 170,000 entries, I don't think 1000 is hugely significant; however, the number of breeds which are rabbits is relatively long (compared to the other creatures in "Other"). I believe I will give them their own category anyway.

# %%
# Let's find some rabbits

other_breeds = aacIn.loc[aacIn['AnimalType'] == 'Other', 'Breed'].unique()
pprint(other_breeds)
# Out:
# array(['Rabbit Sh Mix', 'Ferret', 'Californian Mix', 'Rabbit Sh',
#        'Guinea Pig Mix', 'Rabbit Sh/Lop-Mini', 'Rex Mix', 'Guinea Pig',
#        'Californian', 'Hamster Mix', 'English Spot Mix', 'Lionhead Mix',
#        'Ferret Mix', 'Silver Mix', 'Sugar Glider', 'Dutch Mix',
#        'Jersey Wooly Mix', 'Lop-English Mix', 'American Mix',
#        'Lop-Holland Mix', 'Lionhead', 'Rabbit Lh Mix', 'Dutch/Rabbit Sh',
#        'American Sable', 'New Zealand Wht Mix', 'Lop-Mini Mix',
#        'Hotot Mix', 'Hamster', 'Cinnamon', 'Rabbit Lh',
#        'American Sable Mix', 'Gerbil Mix', 'Angora-French Mix', 'Dutch',
#        'Netherlnd Dwarf Mix', 'Rex-Mini', 'Lop-Holland',
#        'Checkered Giant Mix', 'Lop-Mini', 'Havana Mix', 'Hedgehog',
#        'Chinchilla-Amer Mix', 'Chinchilla-Stnd Mix', 'Polish Mix',
#        'English Spot', 'Harlequin Mix', 'Netherlnd Dwarf',
#        'Chinchilla Mix', 'Rex-Mini/Lop-English', 'Angora-English Mix',
#        'Cinnamon Mix', 'Rex', 'Lop-Amer Fuzzy Mix', 'Rex-Mini Mix',
#        'Dutch/Angora-Satin', 'Tropical Mix', 'Flemish Giant', 'American',
#        'Belgian Hare', 'Britannia Petit Mix', 'Himalayan Mix',
#        'Lop-Amer Fuzzy', 'Rhinelander Mix', 'Belgian Hare Mix',
#        'Flemish Giant Mix', 'Lop-Mini/Lop-Holland', 'Hermit Crab Mix',
#        'Beveren Mix', 'Angora-Satin Mix', 'Snake/Python',
#        'Rex/Lop-English', 'Havana', 'Polish', 'Chinchilla-Amer', 'Gerbil',
#        'New Zealand Wht', 'Chinchilla', 'Hotot', 'Dwarf Hotot',
#        'Angora-Satin', 'Lop-English', 'Lop-Mini/Hotot', 'Chinchilla-Stnd',
#        'Jersey Wooly', 'Angora-English', 'New Zealand Wht/Lop-Holland',
#        'Lizard/Bearded Dragon', 'Rabbit Sh/Dwarf Hotot', 'Himalayan',
#        'Florida White', 'Lop-French', 'Tropical', 'Rabbit Sh/Californian'],
#       dtype=object)

# %% [markdown]
# Manually picking out the rabbit breeds, I see there is a lot of shorthand, some misspellings, and a lot of inconsistency in how they are written. The breeds will require some significant cleaning and processing soon, I can already tell.

# %%
# For now, we compile what I can identify as rabbit breeds

bun_breeds = ['Rabbit Sh Mix', 'Californian Mix', 'Rabbit Sh', 'Rabbit Sh/Lop-Mini', 'Rex Mix', 
        'Californian', 'English Spot Mix', 'Lionhead Mix', 'Silver Mix', 'Dutch Mix', 
        'Jersey Wooly Mix', 'Lop-English Mix', 'American Mix', 'Lop-Holland Mix', 'Lionhead', 
        'Rabbit Lh Mix', 'Dutch/Rabbit Sh', 'American Sable', 'New Zealand Wht Mix', 'Lop-Mini Mix', 
        'Hotot Mix', 'Rabbit Lh', 'American Sable Mix', 'Angora-French Mix', 'Dutch', 'Netherlnd Dwarf Mix', 
        'Rex-Mini', 'Lop-Holland', 'Checkered Giant Mix', 'Lop-Mini', 'Havana Mix', 'Polish Mix', 
        'English Spot', 'Harlequin Mix', 'Netherlnd Dwarf', 'Rex-Mini/Lop-English', 'Angora-English Mix', 
        'Rex', 'Lop-Amer Fuzzy Mix', 'Rex-Mini Mix', 'Dutch/Angora-Satin', 'Flemish Giant', 'Belgian Hare', 
        'Britannia Petit Mix', 'Himalayan Mix', 'Lop-Amer Fuzzy', 'Rhinelander Mix', 'Belgian Hare Mix', 
        'Flemish Giant Mix', 'Lop-Mini/Lop-Holland', 'Beveren Mix', 'Angora-Satin Mix', 'Rex/Lop-English', 
        'Havana', 'Polish', 'New Zealand Wht', 'Hotot', 'Dwarf Hotot', 'Angora-Satin', 'Lop-English', 
        'Lop-Mini/Hotot', 'Jersey Wooly', 'Angora-English', 'New Zealand Wht/Lop-Holland', 
        'Rabbit Sh/Dwarf Hotot', 'Himalayan', 'Florida White', 'Lop-French', 'Rabbit Sh/Californian', 
       'American', 'American Mix', 'Cinnamon', 'Cinnamon Mix']

# %%
# Give them their new category!

aacIn.loc[aacIn["Breed"].isin(bun_breeds) & (aacIn["AnimalType"] == "Other"), "AnimalType"] = "Rabbit"

# Check it worked

aacIn.loc[aacIn["Breed"].isin(bun_breeds), ['Name', 'IntakeType', 'Breed', 'AnimalType']]
# Out:
#             Name       IntakeType                  Breed AnimalType
# 112        Birch            Stray          Rabbit Sh Mix     Rabbit
# 237        Dante  Owner Surrender          Rabbit Sh Mix     Rabbit
# 350          nan            Stray          Himalayan Mix        Cat
# 518          nan            Stray        Californian Mix     Rabbit
# 519          nan            Stray        Californian Mix     Rabbit
# ...          ...              ...                    ...        ...
# 172506    Lottie  Owner Surrender              Rabbit Sh     Rabbit
# 172507      Lola  Owner Surrender              Rabbit Sh     Rabbit
# 172537  Napoleon            Stray              Rabbit Sh     Rabbit
# 172794       nan            Stray  Rabbit Sh/Californian     Rabbit
# 173147       nan            Stray              Rabbit Sh     Rabbit
#
# [1136 rows x 4 columns]

# %%
# Let's double-check our work here:

print(aacIn['AnimalType'].value_counts())
# Out:
# AnimalType
# Dog          94406
# Cat          69009
# Wildlife      6948
# Rabbit        1071
# Other          914
# Bird           876
# Livestock       33
# Name: count, dtype: int64

# %% [markdown]
# Out of originally 9000 "Other" entries, 7000 were wildlife, so I believe separating them was a good decision. The rabbits are more debatable, but it makes the list of "Other" breeds much more distinct and consistent.

# %% [markdown]
# #### Outcomes

# %%
# Are these the same as the intake categories?

print(aacOut['AnimalType'].value_counts())
# Out:
# AnimalType
# Dog          94188
# Cat          69047
# Other         8909
# Bird           874
# Livestock       34
# Name: count, dtype: int64

# %%
# They are. So, let's do the same things we did earlier
# First for wildlife...

aacOut.loc[aacOut["Breed"].isin(wildlife) & (aacOut["AnimalType"] == "Other"), "AnimalType"] = "Wildlife"

# Check it worked
aacOut.loc[aacOut["Breed"].isin(wildlife), ['Name', 'OutcomeType', 'Breed', 'AnimalType']]
# Out:
#        Name OutcomeType    Breed AnimalType
# 3       nan  Euthanasia  Raccoon   Wildlife
# 24      nan  Euthanasia  Raccoon   Wildlife
# 29      nan  Euthanasia  Opossum   Wildlife
# 41      nan  Euthanasia  Bat Mix   Wildlife
# 47      nan  Euthanasia  Bat Mix   Wildlife
# ...     ...         ...      ...        ...
# 172831  nan  Euthanasia  Bat Mix   Wildlife
# 172885  nan  Euthanasia  Raccoon   Wildlife
# 173064  nan  Euthanasia  Raccoon   Wildlife
# 173065  nan  Euthanasia      Bat   Wildlife
# 173066  nan  Euthanasia      Bat   Wildlife
#
# [6930 rows x 4 columns]

# %%
# Now let's help out the rabbits...

aacOut.loc[aacOut["Breed"].isin(bun_breeds) & (aacOut["AnimalType"] == "Other"), "AnimalType"] = "Rabbit"

# Check it worked
aacOut.loc[aacOut["Breed"].isin(bun_breeds), ['Name', 'OutcomeType', 'Breed', 'AnimalType']]
# Out:
#                 Name OutcomeType                  Breed AnimalType
# 60               Moo    Adoption                 Polish     Rabbit
# 243              nan    Transfer          Rabbit Sh Mix     Rabbit
# 540              nan    Transfer          Rabbit Sh Mix     Rabbit
# 698            Peter    Adoption              Rabbit Sh     Rabbit
# 1395             nan  Euthanasia              Rabbit Sh     Rabbit
# ...              ...         ...                    ...        ...
# 172475  Sweet Potato    Adoption              Rabbit Sh     Rabbit
# 172487           nan    Transfer              Rabbit Sh     Rabbit
# 172805        Floppy    Transfer          Rabbit Sh Mix     Rabbit
# 172975           nan    Transfer  Rabbit Sh/Californian     Rabbit
# 173058      Napoleon    Adoption              Rabbit Sh     Rabbit
#
# [1138 rows x 4 columns]

# %%
# Let's see what we're looking at now

print(aacIn['AnimalType'].value_counts())
# Out:
# AnimalType
# Dog          94406
# Cat          69009
# Wildlife      6948
# Rabbit        1071
# Other          914
# Bird           876
# Livestock       33
# Name: count, dtype: int64

# %%
# Since I didn't manually check the "Other" category for this dataset, I want to now,
    # in case any breed values are different or new

aacOut.loc[(aacOut['AnimalType'] == 'Other'), 'Breed'].unique()
# Out:
# array(['Guinea Pig Mix', 'Guinea Pig', 'Ferret Mix', 'Chinchilla',
#        'Hamster', 'Ferret', 'Chinchilla Mix', 'Hamster Mix', 'Hedgehog',
#        'Snake/Python', 'Chinchilla-Stnd', 'Gerbil', 'Tropical',
#        'Gerbil Mix', 'Lizard/Bearded Dragon', 'Tropical Mix',
#        'Chinchilla-Amer', 'Hermit Crab Mix', 'Chinchilla-Stnd Mix',
#        'Sugar Glider', 'Chinchilla-Amer Mix'], dtype=object)

# %% [markdown]
# Looks like there are no missed wildlife or rabbits; onward!

# %% [markdown]
# ### Sex

# %% [markdown]
# #### IntakeSex

# %%
print(aacIn['IntakeSex'].value_counts())
# Out:
# IntakeSex
# Intact Male      58813
# Intact Female    56512
# Neutered Male    24190
# Spayed Female    20280
# Unknown          13460
# Name: count, dtype: int64

# %% [markdown]
# These categories look fine to me.

# %% [markdown]
# #### OutcomeSex

# %%
print(aacOut['OutcomeSex'].value_counts())
# Out:
# OutcomeSex
# Neutered Male    60681
# Spayed Female    55062
# Intact Male      22167
# Intact Female    21731
# Unknown          13409
# Name: count, dtype: int64

# %% [markdown]
# The value counts have more or less reversed compared to the IntakeSex category, which is good! That just means many animals were fixed while in shelter. I suspect most of these are cats and dogs.

# %% [markdown]
# ### Age

# %% [markdown]
# #### IntakeAge

# %%
print(aacIn['IntakeAge'].value_counts())
# Out:
# IntakeAge
# 1 year       28202
# 2 years      27951
# 1 month      18148
# 2 months     10409
# 3 years       9579
# 4 weeks       6295
# 4 years       5826
# 5 years       5177
# 3 weeks       5101
# 3 months      4900
# 4 months      4773
# 5 months      4368
# 2 weeks       3650
# 6 years       3421
# 6 months      3325
# 7 years       3001
# 8 years       2829
# 7 months      2585
# 9 months      2487
# 10 years      2288
# 8 months      2025
# 9 years       1670
# 1 week        1469
# 1 weeks       1413
# 10 months     1383
# 0 years       1247
# 11 months     1137
# 12 years      1116
# 1 day         1009
# 11 years       923
# 3 days         920
# 2 days         768
# 13 years       715
# 6 days         532
# 14 years       523
# 4 days         497
# 15 years       451
# 5 weeks        444
# 5 days         263
# 16 years       192
# 17 years       104
# 18 years        62
# 19 years        29
# 20 years        26
# 22 years         6
# -1 years         6
# 25 years         2
# -3 years         2
# -2 years         1
# 24 years         1
# -4 years         1
# 21 years         1
# 23 years         1
# 30 years         1
# 28 years         1
# Name: count, dtype: int64

# %% [markdown]
# The negative ages seem probably incorrect, and I think age bins could be helpful for graphing and modeling.

# %%
# Remove leading/trailing white spaces and those negatives

aacIn["IntakeAge"] = aacIn["IntakeAge"].str.replace(r"^-", "", regex=True)

# %% [markdown]
# Making that binned column will take a few steps here.

# %%
# Convert age string to years; making this a function for use on the Outcomes dataset as well

def age_to_years(age_str):
    """
    Converts age strings to numerical years as floats.
    
    Args:
        age_str (str): String representing an age ("3 weeks", "4 months", "2 years"...).

    Returns:
        float: Float value representing that age in years.
    """
    match = re.match(r"(-?\d+)\s*(\w+)", str(age_str).lower())
    if not match:
        return np.nan
    value, unit = int(match.group(1)), match.group(2)

    if "year" in unit:
        return abs(value)
    elif "month" in unit:
        return abs(value) / 12
    elif "week" in unit:
        return abs(value) / 52
    elif "day" in unit:
        return abs(value) / 365
    else:
        return np.nan

# %%
# Convert intake age to numeric years to calculate bins

aacIn['AgeYears'] = aacIn['IntakeAge'].apply(age_to_years)

# %%
# Bin into age categories, again creating a function

def age_bins(age):
    """
    Converts float- or integer-form ages into age categories.
    
    Args:
        age (float/int): Numerical representation of age in years.

    Returns:
        str: Corresponding age category ("Unknown", "Infant", "Young", "Adult", "Senior").
    """
    if pd.isna(age):
        return "Unknown"
    elif age < 1:
        return "Infant"
    elif 1 <= age <= 2:
        return "Young"
    elif 3 <= age <= 7:
        return "Adult"
    else:
        return "Senior"

# %%
# Execute function to create a column of age categories

aacIn["AgeCategory"] = aacIn["AgeYears"].apply(age_bins)

# %%
# Round the AgeYears column so that it can be an integer for simplicity

aacIn['AgeYears'] = aacIn['AgeYears'].round().astype('Int64')

# %%
# Check that this worked

print(aacIn['AgeCategory'].value_counts())
# Out:
# AgeCategory
# Infant     79148
# Young      56160
# Adult      27007
# Senior     10941
# Unknown        1
# Name: count, dtype: int64

# %%
# For now, I'll keep that intermediary column--it likely will be more helpful than the original age category 
# (even if it loses some information through rounding)

print(aacIn['AgeYears'].value_counts())
# Out:
# AgeYears
# 0     69531
# 1     37825
# 2     27952
# 3      9581
# 4      5827
# 5      5177
# 6      3421
# 7      3001
# 8      2829
# 10     2288
# 9      1670
# 12     1116
# 11      923
# 13      715
# 14      523
# 15      451
# 16      192
# 17      104
# 18       62
# 19       29
# 20       26
# 22        6
# 25        2
# 24        1
# 21        1
# 23        1
# 30        1
# 28        1
# Name: count, dtype: Int64

# %% [markdown]
# #### OutcomeAge

# %%
# Preview what this category looks like

print(aacOut['OutcomeAge'].value_counts())
# Out:
# OutcomeAge
# 1 year       28667
# 2 years      27793
# 2 months     23182
# 3 years       9758
# 3 months      9174
# 1 month       7378
# 4 months      6037
# 4 years       5797
# 5 years       5249
# 5 months      4429
# 6 months      4184
# 6 years       3416
# 7 years       3009
# 8 years       2950
# 3 weeks       2885
# 2 weeks       2877
# 8 months      2706
# 4 weeks       2407
# 10 months     2392
# 10 years      2382
# 7 months      2269
# 9 months      1763
# 9 years       1656
# 1 weeks       1345
# 12 years      1161
# 11 months     1099
# 1 week         961
# 11 years       922
# 13 years       743
# 3 days         567
# 14 years       535
# 2 days         526
# 1 day          506
# 15 years       462
# 4 days         357
# 6 days         341
# 0 years        272
# 5 days         235
# 5 weeks        202
# 16 years       200
# 17 years       107
# 18 years        64
# 19 years        29
# 20 years        26
# 22 years         6
# -1 years         6
# -3 years         2
# 25 years         2
# -2 years         1
# 28 years         1
# 23 years         1
# 30 years         1
# 24 years         1
# 21 years         1
# -4 years         1
# Name: count, dtype: int64

# %%
# Remove those negatives and other irregularities

aacOut["OutcomeAge"] = aacOut["OutcomeAge"].str.replace(r"^-", "", regex=True)

# %%
# Convert age to numeric years for calculating bins and other evaluations

aacOut['AgeYears'] = aacOut['OutcomeAge'].apply(age_to_years)

# %%
# Create a column of age categories

aacOut["AgeCategory"] = aacOut["AgeYears"].apply(age_bins)

# %%
# Round AgeYears to integer

aacOut['AgeYears'] = aacOut['AgeYears'].round().astype('Int64')

# %%
# Check the new columns

print(aacOut['AgeCategory'].value_counts())
# Out:
# AgeCategory
# Infant     78094
# Young      56467
# Adult      27232
# Senior     11250
# Unknown        9
# Name: count, dtype: int64

# %%
# Also AgeYears

print(aacOut['AgeYears'].value_counts())
# Out:
# AgeYears
# 0     67865
# 1     38902
# 2     27794
# 3      9760
# 4      5798
# 5      5249
# 6      3416
# 7      3009
# 8      2950
# 10     2382
# 9      1656
# 12     1161
# 11      922
# 13      743
# 14      535
# 15      462
# 16      200
# 17      107
# 18       64
# 19       29
# 20       26
# 22        6
# 25        2
# 28        1
# 23        1
# 30        1
# 24        1
# 21        1
# Name: count, dtype: Int64

# %% [markdown]
# It is slightly odd that there are more Unknowns in the Outcome dataset than Intake, but not enough to be worrying Intake ages are likely a guess, anyway.

# %% [markdown]
# ### Breed

# %% [markdown]
# #### Intakes

# %% [markdown]
# ##### Preliminary Cleaning

# %%
# What does it look like right now?

print(aacIn['Breed'].value_counts())
# Out:
# Breed
# Domestic Shorthair Mix                    33653
# Domestic Shorthair                        23903
# Pit Bull Mix                              10084
# Labrador Retriever Mix                     8802
# Chihuahua Shorthair Mix                    6880
#                                           ...
# Queensland Heeler/Border Collie               1
# Queensland Heeler/Cardigan Welsh Corgi        1
# Manchester Terrier/Basenji                    1
# Border Collie/Miniature Pinscher              1
# Dachshund Longhair/Border Collie              1
# Name: count, Length: 3003, dtype: int64

# %% [markdown]
# This is a lot of unique breeds. 3003 is too much for using in much of anything. My thought is to make a category, "Mix", which specifies whether the animal is a mixed-breed, and another column that specifies a primary breed. I would like to keep secondary breeds as well, but suspect there will be too many nulls to justify keeping.

# %%
# Strip capitals first, to make sure there are no case-related misspellings

aacIn['Breed'] = aacIn['Breed'].str.lower().str.strip()

print(aacIn['Breed'].value_counts())
print('\n')

# And return those capitals

aacIn['Breed'] = aacIn['Breed'].str.title()

print(aacIn['Breed'].value_counts())
# Out:
# Breed
# domestic shorthair mix                    33653
# domestic shorthair                        23903
# pit bull mix                              10084
# labrador retriever mix                     8802
# chihuahua shorthair mix                    6880
#                                           ...
# queensland heeler/border collie               1
# queensland heeler/cardigan welsh corgi        1
# manchester terrier/basenji                    1
# border collie/miniature pinscher              1
# dachshund longhair/border collie              1
# Name: count, Length: 3003, dtype: int64
#
#
# Breed
# Domestic Shorthair Mix                    33653
# Domestic Shorthair                        23903
# Pit Bull Mix                              10084
# Labrador Retriever Mix                     8802
# Chihuahua Shorthair Mix                    6880
#                                           ...
# Queensland Heeler/Border Collie               1
# Queensland Heeler/Cardigan Welsh Corgi        1
# Manchester Terrier/Basenji                    1
# Border Collie/Miniature Pinscher              1
# Dachshund Longhair/Border Collie              1
# Name: count, Length: 3003, dtype: int64

# %%
# Now to process this chaos

def parse_breeds(breed):
    """
    Cleans breed entries to separate, easier-to-handle columns.

    Removes "Mix" and creates Boolean column representing whether or not the animal is a mixed-breed; 
    splits entries along "/", and separates breeds into Primary and Secondary columns.
        
    Args:
        breed (str): String representing a breed or combination of breeds. Can include "Mix" or a combination of breeds, separated by "/".

    Returns:
        Series: Three (3) columns representing whether the animal is mixed-breed, as well as its primary and secondary breeds
        (by default: "is_mix", "primary", "secondary").
    """
    # Create "is_mix" Boolean column
    
    is_mix = 'Mix' in breed or '/' in breed

    # Remove "Mix"
    
    breed_clean = breed.replace(' Mix', '').strip()
    
    # Handle slashes and separate primary from secondary breeds
    
    if '/' in breed_clean:
        parts = breed_clean.split('/')
        primary = parts[0].strip()
        secondary = parts[1].strip() if len(parts) > 1 else None
    else:
        primary = breed_clean
        secondary = None

    # Return pandas Series with 3 columns

    return pd.Series([is_mix, primary, secondary])

# %%
# Apply to dataframe

aacIn[['IsMix', 'PrimaryBreed', 'SecondaryBreed']] = aacIn['Breed'].apply(parse_breeds)

# %%
aacIn[['AnimalType', 'Breed', 'IsMix', 'PrimaryBreed', 'SecondaryBreed']].head(10)
# Out:
#   AnimalType                         Breed  IsMix         PrimaryBreed  \
# 0        Dog  Border Terrier/Border Collie   True       Border Terrier
# 1        Cat        Domestic Shorthair Mix   True   Domestic Shorthair
# 2        Cat        Domestic Shorthair Mix   True   Domestic Shorthair
# 3        Cat        Domestic Shorthair Mix   True   Domestic Shorthair
# 4        Dog                  Pit Bull Mix   True             Pit Bull
# 5        Cat        American Shorthair Mix   True   American Shorthair
# 6        Dog             Border Collie Mix   True        Border Collie
# 7        Cat        Domestic Shorthair Mix   True   Domestic Shorthair
# 8        Dog           Podengo Pequeno Mix   True      Podengo Pequeno
# 9        Dog       Chihuahua Shorthair Mix   True  Chihuahua Shorthair
#
#   SecondaryBreed
# 0  Border Collie
# 1           None
# 2           None
# 3           None
# 4           None
# 5           None
# 6           None
# 7           None
# 8           None
# 9           None

# %% [markdown]
# Seems to have worked. Let's look at those new breed categories now.

# %%
print(aacIn['PrimaryBreed'].value_counts())
print("Primary breed null values: " + str(aacIn['PrimaryBreed'].isnull().sum()))
print('\n')
print(aacIn['SecondaryBreed'].value_counts())
print('Secondary breed null values: ' + str(aacIn['SecondaryBreed'].isnull().sum()))
# Out:
# PrimaryBreed
# Domestic Shorthair     57573
# Pit Bull               14494
# Labrador Retriever     13530
# Chihuahua Shorthair    10068
# German Shepherd         6997
#                        ...
# Rhinelander                1
# Other Bird                 1
# Hermit Crab                1
# Beveren                    1
# Pelican                    1
# Name: count, Length: 385, dtype: int64
# Primary breed null values: 0
#
#
# SecondaryBreed
# Labrador Retriever     2297
# Pit Bull               1188
# Chihuahua Shorthair    1080
# German Shepherd        1041
# Dachshund               725
#                        ...
# Bengal                    1
# Dandie Dinmont            1
# Yorkshire                 1
# British Shorthair         1
# Californian               1
# Name: count, Length: 211, dtype: int64
# Secondary breed null values: 157661

# %% [markdown]
# 385 primary breeds and 211 secondary breeds is far better than the 3000 we started with. However, I suspect there are still far too many categories with very few entries. Also looking at the number of null entries in "SecondaryBreed", I suspect there are just too many nulls to work with. This is ultimately an adoption-oriented project, and breed plays a huge part in that; however, there just is not enough information in that column to warrant keeping. Further, there are SecondaryBreeds for creatures such as wildlife which don't make sense and would also have to be removed, creating even more nulls.

# %%
# Drop that SecondaryBreed column

aacIn.drop(columns = 'SecondaryBreed', inplace = True)

# Check the dataset, as always

aacIn.head()
# Out:
#   AnimalID    Name            IntakeDT IntakeType IntakeCondition AnimalType  \
# 0  A521520    Nina 2013-10-01 07:51:00      Stray          Normal        Dog
# 1  A664235     nan 2013-10-01 08:33:00      Stray          Normal        Cat
# 2  A664236     nan 2013-10-01 08:33:00      Stray          Normal        Cat
# 3  A664237     nan 2013-10-01 08:33:00      Stray          Normal        Cat
# 4  A664233  Stevie 2013-10-01 08:53:00      Stray         Injured        Dog
#
#        IntakeSex IntakeAge                         Breed         Color  \
# 0  Spayed Female   7 years  Border Terrier/Border Collie     White/Tan
# 1        Unknown    1 week        Domestic Shorthair Mix  Orange/White
# 2        Unknown    1 week        Domestic Shorthair Mix  Orange/White
# 3        Unknown    1 week        Domestic Shorthair Mix  Orange/White
# 4  Intact Female   3 years                  Pit Bull Mix    Blue/White
#
#    AgeYears AgeCategory  IsMix        PrimaryBreed
# 0         7       Adult   True      Border Terrier
# 1         0      Infant   True  Domestic Shorthair
# 2         0      Infant   True  Domestic Shorthair
# 3         0      Infant   True  Domestic Shorthair
# 4         3       Adult   True            Pit Bull

# %% [markdown]
# Now for the hard part: finding misspellings, shorthand notations, and other general inconsistencies in these breeds. To do so, I am going to first divide the breeds into animal types, and work through each one at a time.

# %% [markdown]
# ##### Manually Checking and Replacing Breeds

# %%
# Starting with the dogs, of course

print(aacIn.loc[aacIn['AnimalType'] == 'Dog', 'PrimaryBreed'].nunique())
# Out:
# 211

# %%
# I will go through this list manually, and then use ChatGPT for a sanity check

pprint(aacIn.loc[aacIn['AnimalType'] == 'Dog', 'PrimaryBreed'].unique().tolist())
# Out:
# ['Border Terrier',
#  'Pit Bull',
#  'Border Collie',
#  'Podengo Pequeno',
#  'Chihuahua Shorthair',
#  'Weimaraner',
#  'Anatol Shepherd',
#  'Labrador Retriever',
#  'Great Pyrenees',
#  'Cairn Terrier',
#  'Dachshund',
#  'German Shepherd',
#  'Black',
#  'Siberian Husky',
#  'Miniature Poodle',
#  'Yorkshire Terrier',
#  'Norfolk Terrier',
#  'Australian Shepherd',
#  'Australian Cattle Dog',
#  'Belgian Malinois',
#  'Jack Russell Terrier',
#  'Doberman Pinsch',
#  'Japanese Chin',
#  'Staffordshire',
#  'Welsh Terrier',
#  'Shetland Sheepdog',
#  'Vizsla',
#  'Rottweiler',
#  'American Staffordshire Terrier',
#  'American Bulldog',
#  'Chinese Sharpei',
#  'Great Dane',
#  'Harrier',
#  'Flat Coat Retriever',
#  'Dachshund Wirehair',
#  'Leonberger',
#  'Dachshund Longhair',
#  'Chesa Bay Retr',
#  'Mastiff',
#  'Chihuahua Longhair',
#  'Rat Terrier',
#  'Greyhound',
#  'Boxer',
#  'Bulldog',
#  'Miniature Pinscher',
#  'Carolina Dog',
#  'Toy Poodle',
#  'Pointer',
#  'Queensland Heeler',
#  'American Pit Bull Terrier',
#  'Miniature Schnauzer',
#  'Beagle',
#  'Kuvasz',
#  'Shih Tzu',
#  'Pekingese',
#  'Catahoula',
#  'Maltese',
#  'Australian Kelpie',
#  'Basset Hound',
#  'Treeing Walker Coonhound',
#  'Bull Terrier',
#  'American Foxhound',
#  'Chow Chow',
#  'Italian Greyhound',
#  'Boston Terrier',
#  'Blue Lacy',
#  'Golden Retriever',
#  'Collie Rough',
#  'Plott Hound',
#  'Redbone Hound',
#  'Cocker Spaniel',
#  'English Springer Spaniel',
#  'Black Mouth Cur',
#  'Basenji',
#  'Pug',
#  'Parson Russell Terrier',
#  'English Pointer',
#  'Skye Terrier',
#  'Airedale Terrier',
#  'Cardigan Welsh Corgi',
#  'Finnish Spitz',
#  'English Setter',
#  'Alaskan Husky',
#  'Rhod Ridgeback',
#  'Newfoundland',
#  'Brittany',
#  'Collie Smooth',
#  'Port Water Dog',
#  'Bull Terrier Miniature',
#  'Lhasa Apso',
#  'Norwich Terrier',
#  'Whippet',
#  'Old English Sheepdog',
#  'Shiba Inu',
#  'Bullmastiff',
#  'Ibizan Hound',
#  'Scottish Terrier',
#  'English Foxhound',
#  'Silky Terrier',
#  'Keeshond',
#  'English Bulldog',
#  'Pomeranian',
#  'Havanese',
#  'Cane Corso',
#  'Soft Coated Wheaten Terrier',
#  'Schipperke',
#  'Pharaoh Hound',
#  'American Eskimo',
#  'Pembroke Welsh Corgi',
#  'Eng Toy Spaniel',
#  'Wire Hair Fox Terrier',
#  'Standard Schnauzer',
#  'West Highland',
#  'Bruss Griffon',
#  'Pbgv',
#  'Entlebucher',
#  'German Shorthair Pointer',
#  'Picardy Sheepdog',
#  'Beauceron',
#  'Standard Poodle',
#  'Bearded Collie',
#  'Papillon',
#  'Bichon Frise',
#  'Cavalier Span',
#  'French Bulldog',
#  'St. Bernard Rough Coat',
#  'Alaskan Malamute',
#  'Irish Terrier',
#  'Bloodhound',
#  'Akita',
#  'Landseer',
#  'Swedish Vallhund',
#  'Bluetick Hound',
#  'Jindo',
#  'Afghan Hound',
#  'Canaan Dog',
#  'German Pinscher',
#  'Affenpinscher',
#  'Manchester Terrier',
#  'Dogue De Bordeaux',
#  'Tibetan Terrier',
#  'Boerboel',
#  'Irish Wolfhound',
#  'Coton De Tulear',
#  'Dogo Argentino',
#  'German Wirehaired Pointer',
#  'Dutch Shepherd',
#  'Belgian Sheepdog',
#  'Bernese Mountain Dog',
#  'Dalmatian',
#  'Feist',
#  'Old English Bulldog',
#  'Toy Fox Terrier',
#  'Smooth Fox Terrier',
#  'St. Bernard Smooth Coat',
#  'Welsh Springer Spaniel',
#  'Boykin Span',
#  'Nova Scotia Duck Tolling Retriever',
#  'Chinese Crested',
#  'Spinone Italiano',
#  'Samoyed',
#  'English Coonhound',
#  'Presa Canario',
#  'Wirehaired Pointing Griffon',
#  'Australian Terrier',
#  'Greater Swiss Mountain Dog',
#  'Gordon Setter',
#  'Glen Of Imaal',
#  'Otterhound',
#  'Saluki',
#  'Tibetan Spaniel',
#  'Belgian Tervuren',
#  'Field Spaniel',
#  'Patterdale Terr',
#  'Treeing Cur',
#  'Dandie Dinmont',
#  'Schnauzer Giant',
#  'English Cocker Spaniel',
#  'Irish Setter',
#  'Swiss Hound',
#  'English Shepherd',
#  'Sealyham Terr',
#  'Bedlington Terr',
#  'Unknown',
#  'Lowchen',
#  'Spanish Mastiff',
#  'Dachshund Stan',
#  'Mexican Hairless',
#  'Neapolitan Mastiff',
#  'Treeing Tennesse Brindle',
#  'Norwegian Elkhound',
#  'Akbash',
#  'Hovawart',
#  'Sussex Span',
#  'Lakeland Terrier',
#  'Grand Basset Griffon Vendeen',
#  'Bouv Flandres',
#  'Clumber Spaniel',
#  'Tibetan Mastiff',
#  'Briard',
#  'Spanish Water Dog',
#  'Alaskan Klee Kai',
#  'Kangal',
#  'Dutch Sheepdog',
#  'Wolf Hybrid',
#  'Wirehaired Vizsla',
#  'Bernese Hound',
#  'Borzoi',
#  'Scottish Deerhound',
#  'Curly Coat Retriever',
#  'Tosa']

# %% [markdown]
# There are some very unusual breeds in here. However, all or almost all of these are probably guesses from shelter staff. Eventually, I will cull the least common breeds from the dataset; I will leave that until after the join, though.
#
# Using the list of mistypes and standardization errors that I was able to catch manually (with ChatGPT to double-check my work), I will make a dictionary with the breed names that need to be replaced, along with their replacements.

# %%
# Dictionary with breed names that need to be replaced

dog_replacements = {
    'Black' : 'Other', 
    'Doberman Pinsch' : 'Doberman Pinscher', 
    'Chinese Sharpei' : 'Chinese Shar-Pei', 
    'Dachshund Wirehair' : 'Dachshund', 
    'Chihuahua Shorthair' : 'Chihuahua', 
    'Flat Coat Retriever' : 'Flat-Coated Retriever', 
    'Dachshund Longhair' : 'Dachshund', 
    'Chihuahua Longhair' : 'Chihuahua', 
    'Pointer' : 'German Shorthaired Pointer', 
    'Catahoula' : 'Catahoula Leopard Dog',
    'Parson Russell Terrier' : 'Jack Russell Terrier', 
    'Port Water Dog' : 'Portuguese Water Dog', 
    'Miniature Bull Terrier' : 'Bull Terrier', 
    'Bullmastiff' : 'Mastiff', 
    'Eng Toy Spaniel' : 'English Toy Spaniel', 
    'Wire Hair Fox Terrier' : 'Wire Fox Terrier', 
    'West Highland' : 'West Highland White Terrier', 
    'Bruss Griffon' : 'Brussels Griffon', 
    'Petit Basset Griffon Vendéen' : 'Petit Basset Griffon Vendeen', 
    'German Shorthair Pointer' : 'German Shorthaired Pointer', 
    'Cavalier Span' : 'Cavalier King Charles Spaniel', 
    'Bluetick Hound' : 'Bluetick Coonhound', 
    'Boykin Span' : 'Boykin Spaniel', 
    'Chinese Crested' : 'Chinese Crested Dog', 
    'Glen Of Imaal' : 'Glen Of Imaal Terrier', 
    'Patterdale Terr' : 'Patterdale Terrier', 
    'Dandie Dinmont' : 'Dandie Dinmont Terrier', 
    'Schnauzer Giant' : 'Giant Schnauzer', 
    'Sealyham Terr' : 'Sealyham Terrier', 
    'Bedlington Terr' : 'Bedlington Terrier', 
    'Sussex Span' : 'Sussex Spaniel', 
    'Wirehaired Vizsla' : 'Vizsla', 
    'Curly Coat Retriever' : 'Curly-Coated Retriever',
    'Pit Bull': 'American Pit Bull Terrier',
    'Anatol Shepherd': 'Anatolian Shepherd',
    'Staffordshire': 'Staffordshire Bull Terrier',
    'Rhod Ridgeback': 'Rhodesian Ridgeback',
    'Chesa Bay Retr': 'Chesapeake Bay Retriever',
    'Queensland Heeler': 'Australian Cattle Dog',
    'Collie Rough': 'Rough Collie',
    'Collie Smooth': 'Smooth Collie',
    'St. Bernard Rough Coat': 'Saint Bernard',
    'St. Bernard Smooth Coat': 'Saint Bernard',
    'Pbgv': 'Petit Basset Griffon Vendeen',
    'Bull Terrier Miniature': 'Bull Terrier',
    'Mexican Hairless': 'Xoloitzcuintli',
    'Bouv Flandres': 'Bouvier des Flandres',
    'Bernese Hound': 'Bernese Mountain Dog',
    'Silkie': 'Silky Terrier',
    'Dachshund Stan': 'Dachshund',
    'Unknown': 'Other',
    'Yorkshire' : 'Yorkshire Terrier',
    'English Cocker Spaniel' : 'Cocker Spaniel',
    'Papillion' : 'Papillon',
    'Tan Hound': 'Black Mouth Cur'
}

# That's a lot of changes

# %%
# Make a function to replace breeds in the "PrimaryBreed" column, since I will need this for every animal type in both datasets.

def replace_breeds(df, animal_type, replacement_dict):
    """
    Taking a dictionary of current values and desired replacements, 
    replaces designated values in the "PrimaryBreed" column of the specified Dataframe.

    Prints feedback for debugging and monitoring.

    Args:
        df (pd.DataFrame): Dataframe within which the column to edit lies.
        animal_type (str): String representing an animal type found in the "AnimalType" column (a column specific to this project).
        replacement_dict (dict): Dictionary in the form of {"Current Value" : "Replacement Value"}.

    Returns:
        pd.DataFrame: the modified Dataframe (inplace replacements).
    """
    # Initialize total replacements counter
    
    total_replacements = 0  # For monitoring the changes the function made
    
    # Filter for rows where AnimalType matches the provided animal_type
    
    filtered_df = df.loc[df['AnimalType'] == animal_type]  # This way, each animal type can be evaluated individually
    
    # Apply the replacement for each breed in the specified columns
    
    for old_value, new_value in replacement_dict.items():
            
        # Count the occurrences before replacement
            
        old_count = df.loc[(df['AnimalType'] == animal_type) & (df['PrimaryBreed'] == old_value), 'PrimaryBreed'].shape[0]
            
        # Debugging: Check if old_value exists
            
        print(f"Checking for '{old_value}' in 'PrimaryBreed'. Found: {old_count} times.")
        if old_count == 0:
            print()
            
        # Only perform replacement if old_value exists in the dataframe for that animal
            
        if old_count > 0:
            df.loc[(df['AnimalType'] == animal_type) & (df['PrimaryBreed'] == old_value), 'PrimaryBreed'] = new_value  # Actual replacement
            total_replacements += old_count  # Keeping track of how many replacements have been made
            print(f"Replaced {old_count} occurrences of '{old_value}' with '{new_value}'.")  # Debugging and monitoring feedback
            print()

    # Get unique breeds in PrimaryBreed after replacement
        
    unique_breeds = df.loc[df['AnimalType'] == animal_type, 'PrimaryBreed'].nunique()
    print(f"After replacements, the unique breeds in 'PrimaryBreed' for {animal_type} are now: {unique_breeds}")
    
    # Print final feedback
    
    print(f"\nTotal replacements made: {total_replacements}")
    
    # Return the modified dataframe
    
    return df

# %%
# Function made, let's replace some breeds

aacIn = replace_breeds(aacIn, "Dog", dog_replacements)
# Out:
# Checking for 'Black' in 'PrimaryBreed'. Found: 233 times.
# Replaced 233 occurrences of 'Black' with 'Other'.
#
# Checking for 'Doberman Pinsch' in 'PrimaryBreed'. Found: 543 times.
# Replaced 543 occurrences of 'Doberman Pinsch' with 'Doberman Pinscher'.
#
# Checking for 'Chinese Sharpei' in 'PrimaryBreed'. Found: 315 times.
# Replaced 315 occurrences of 'Chinese Sharpei' with 'Chinese Shar-Pei'.
#
# Checking for 'Dachshund Wirehair' in 'PrimaryBreed'. Found: 223 times.
# Replaced 223 occurrences of 'Dachshund Wirehair' with 'Dachshund'.
#
# Checking for 'Chihuahua Shorthair' in 'PrimaryBreed'. Found: 10068 times.
# Replaced 10068 occurrences of 'Chihuahua Shorthair' with 'Chihuahua'.
#
# Checking for 'Flat Coat Retriever' in 'PrimaryBreed'. Found: 159 times.
# Replaced 159 occurrences of 'Flat Coat Retriever' with 'Flat-Coated Retriever'.
#
# Checking for 'Dachshund Longhair' in 'PrimaryBreed'. Found: 258 times.
# Replaced 258 occurrences of 'Dachshund Longhair' with 'Dachshund'.
#
# Checking for 'Chihuahua Longhair' in 'PrimaryBreed'. Found: 853 times.
# Replaced 853 occurrences of 'Chihuahua Longhair' with 'Chihuahua'.
#
# Checking for 'Pointer' in 'PrimaryBreed'. Found: 1029 times.
# Replaced 1029 occurrences of 'Pointer' with 'German Shorthaired Pointer'.
#
# Checking for 'Catahoula' in 'PrimaryBreed'. Found: 1261 times.
# Replaced 1261 occurrences of 'Catahoula' with 'Catahoula Leopard Dog'.
#
# Checking for 'Parson Russell Terrier' in 'PrimaryBreed'. Found: 83 times.
# Replaced 83 occurrences of 'Parson Russell Terrier' with 'Jack Russell Terrier'.
#
# Checking for 'Port Water Dog' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Port Water Dog' with 'Portuguese Water Dog'.
#
# Checking for 'Miniature Bull Terrier' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Bullmastiff' in 'PrimaryBreed'. Found: 60 times.
# Replaced 60 occurrences of 'Bullmastiff' with 'Mastiff'.
#
# Checking for 'Eng Toy Spaniel' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Eng Toy Spaniel' with 'English Toy Spaniel'.
#
# Checking for 'Wire Hair Fox Terrier' in 'PrimaryBreed'. Found: 153 times.
# Replaced 153 occurrences of 'Wire Hair Fox Terrier' with 'Wire Fox Terrier'.
#
# Checking for 'West Highland' in 'PrimaryBreed'. Found: 122 times.
# Replaced 122 occurrences of 'West Highland' with 'West Highland White Terrier'.
#
# Checking for 'Bruss Griffon' in 'PrimaryBreed'. Found: 85 times.
# Replaced 85 occurrences of 'Bruss Griffon' with 'Brussels Griffon'.
#
# Checking for 'Petit Basset Griffon Vendéen' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'German Shorthair Pointer' in 'PrimaryBreed'. Found: 136 times.
# Replaced 136 occurrences of 'German Shorthair Pointer' with 'German Shorthaired Pointer'.
#
# Checking for 'Cavalier Span' in 'PrimaryBreed'. Found: 58 times.
# Replaced 58 occurrences of 'Cavalier Span' with 'Cavalier King Charles Spaniel'.
#
# Checking for 'Bluetick Hound' in 'PrimaryBreed'. Found: 46 times.
# Replaced 46 occurrences of 'Bluetick Hound' with 'Bluetick Coonhound'.
#
# Checking for 'Boykin Span' in 'PrimaryBreed'. Found: 14 times.
# Replaced 14 occurrences of 'Boykin Span' with 'Boykin Spaniel'.
#
# Checking for 'Chinese Crested' in 'PrimaryBreed'. Found: 27 times.
# Replaced 27 occurrences of 'Chinese Crested' with 'Chinese Crested Dog'.
#
# Checking for 'Glen Of Imaal' in 'PrimaryBreed'. Found: 14 times.
# Replaced 14 occurrences of 'Glen Of Imaal' with 'Glen Of Imaal Terrier'.
#
# Checking for 'Patterdale Terr' in 'PrimaryBreed'. Found: 26 times.
# Replaced 26 occurrences of 'Patterdale Terr' with 'Patterdale Terrier'.
#
# Checking for 'Dandie Dinmont' in 'PrimaryBreed'. Found: 8 times.
# Replaced 8 occurrences of 'Dandie Dinmont' with 'Dandie Dinmont Terrier'.
#
# Checking for 'Schnauzer Giant' in 'PrimaryBreed'. Found: 41 times.
# Replaced 41 occurrences of 'Schnauzer Giant' with 'Giant Schnauzer'.
#
# Checking for 'Sealyham Terr' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Sealyham Terr' with 'Sealyham Terrier'.
#
# Checking for 'Bedlington Terr' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Bedlington Terr' with 'Bedlington Terrier'.
#
# Checking for 'Sussex Span' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Sussex Span' with 'Sussex Spaniel'.
#
# Checking for 'Wirehaired Vizsla' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Wirehaired Vizsla' with 'Vizsla'.
#
# Checking for 'Curly Coat Retriever' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Curly Coat Retriever' with 'Curly-Coated Retriever'.
#
# Checking for 'Pit Bull' in 'PrimaryBreed'. Found: 14494 times.
# Replaced 14494 occurrences of 'Pit Bull' with 'American Pit Bull Terrier'.
#
# Checking for 'Anatol Shepherd' in 'PrimaryBreed'. Found: 886 times.
# Replaced 886 occurrences of 'Anatol Shepherd' with 'Anatolian Shepherd'.
#
# Checking for 'Staffordshire' in 'PrimaryBreed'. Found: 1011 times.
# Replaced 1011 occurrences of 'Staffordshire' with 'Staffordshire Bull Terrier'.
#
# Checking for 'Rhod Ridgeback' in 'PrimaryBreed'. Found: 212 times.
# Replaced 212 occurrences of 'Rhod Ridgeback' with 'Rhodesian Ridgeback'.
#
# Checking for 'Chesa Bay Retr' in 'PrimaryBreed'. Found: 35 times.
# Replaced 35 occurrences of 'Chesa Bay Retr' with 'Chesapeake Bay Retriever'.
#
# Checking for 'Queensland Heeler' in 'PrimaryBreed'. Found: 272 times.
# Replaced 272 occurrences of 'Queensland Heeler' with 'Australian Cattle Dog'.
#
# Checking for 'Collie Rough' in 'PrimaryBreed'. Found: 110 times.
# Replaced 110 occurrences of 'Collie Rough' with 'Rough Collie'.
#
# Checking for 'Collie Smooth' in 'PrimaryBreed'. Found: 199 times.
# Replaced 199 occurrences of 'Collie Smooth' with 'Smooth Collie'.
#
# Checking for 'St. Bernard Rough Coat' in 'PrimaryBreed'. Found: 64 times.
# Replaced 64 occurrences of 'St. Bernard Rough Coat' with 'Saint Bernard'.
#
# Checking for 'St. Bernard Smooth Coat' in 'PrimaryBreed'. Found: 38 times.
# Replaced 38 occurrences of 'St. Bernard Smooth Coat' with 'Saint Bernard'.
#
# Checking for 'Pbgv' in 'PrimaryBreed'. Found: 85 times.
# Replaced 85 occurrences of 'Pbgv' with 'Petit Basset Griffon Vendeen'.
#
# Checking for 'Bull Terrier Miniature' in 'PrimaryBreed'. Found: 22 times.
# Replaced 22 occurrences of 'Bull Terrier Miniature' with 'Bull Terrier'.
#
# Checking for 'Mexican Hairless' in 'PrimaryBreed'. Found: 15 times.
# Replaced 15 occurrences of 'Mexican Hairless' with 'Xoloitzcuintli'.
#
# Checking for 'Bouv Flandres' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Bouv Flandres' with 'Bouvier des Flandres'.
#
# Checking for 'Bernese Hound' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Bernese Hound' with 'Bernese Mountain Dog'.
#
# Checking for 'Silkie' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Dachshund Stan' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Dachshund Stan' with 'Dachshund'.
#
# Checking for 'Unknown' in 'PrimaryBreed'. Found: 12 times.
# Replaced 12 occurrences of 'Unknown' with 'Other'.
#
# Checking for 'Yorkshire' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'English Cocker Spaniel' in 'PrimaryBreed'. Found: 9 times.
# Replaced 9 occurrences of 'English Cocker Spaniel' with 'Cocker Spaniel'.
#
# Checking for 'Papillion' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Tan Hound' in 'PrimaryBreed'. Found: 0 times.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Dog are now: 196
#
# Total replacements made: 33304

# %%
# Moving on to the cats

pprint(aacIn.loc[aacIn['AnimalType'] == 'Cat', 'PrimaryBreed'].unique().tolist())
# Out:
# ['Domestic Shorthair',
#  'American Shorthair',
#  'Russian Blue',
#  'Domestic Longhair',
#  'Domestic Medium Hair',
#  'Manx',
#  'Himalayan',
#  'Snowshoe',
#  'Siamese',
#  'Abyssinian',
#  'Maine Coon',
#  'Bengal',
#  'Balinese',
#  'Persian',
#  'Tonkinese',
#  'British Shorthair',
#  'Exotic Shorthair',
#  'Bombay',
#  'Ragdoll',
#  'Burmese',
#  'Angora',
#  'Japanese Bobtail',
#  'Norwegian Forest Cat',
#  'Sphynx',
#  'Cymric',
#  'Pixiebob Shorthair',
#  'Munchkin Shorthair',
#  'Devon Rex',
#  'Chartreux',
#  'Turkish Van',
#  'American Wirehair',
#  'Oriental Sh',
#  'Turkish Angora',
#  'Javanese',
#  'Havana Brown',
#  'Cornish Rex',
#  'Scottish Fold',
#  'Munchkin Longhair',
#  'Ocicat',
#  'American Curl Shorthair',
#  'Birman',
#  'Colorpoint',
#  'Savannah',
#  'Rex']

# %%
# Make our corrections dictionary

cat_replacements = {
    'Oriental Sh' : 'Oriental Shorthair',
    'Angora' : 'Turkish Angora', 
    'Colorpoint' : 'Colorpoint Shorthair', 
    'Rex' : 'Cornish Rex',
}

# %%
# Replacing breeds again

aacIn = replace_breeds(aacIn, "Cat", cat_replacements)
# Out:
# Checking for 'Oriental Sh' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Oriental Sh' with 'Oriental Shorthair'.
#
# Checking for 'Angora' in 'PrimaryBreed'. Found: 13 times.
# Replaced 13 occurrences of 'Angora' with 'Turkish Angora'.
#
# Checking for 'Colorpoint' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Colorpoint' with 'Colorpoint Shorthair'.
#
# Checking for 'Rex' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Rex' with 'Cornish Rex'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Cat are now: 42
#
# Total replacements made: 22

# %%
# Evaluating birds

print(aacIn.loc[aacIn['AnimalType'] == 'Bird', 'PrimaryBreed'].unique().tolist())
# Out:
# ['Pigeon', 'Parakeet', 'Rhode Island', 'Chicken', 'Duck', 'Lark', 'Cockatiel', 'Bantam', 'Lovebird', 'Parrot', 'Sparrow', 'Catbird', 'Grackle', 'Nuthatch', 'Quaker', 'Dove', 'Silkie', 'Finch', 'Turkey', 'Guinea', 'Conure', 'Bluebird', 'Bunting', 'Mockingbird', 'Owl', 'Goose', 'Budgerigar', 'Hawk', 'Wren', 'Peafowl', 'Vulture', 'Heron', 'Cockatoo', 'African', 'Barred Rock', 'Crow', 'Muscovy', 'Song Bird', 'Pheasant', 'Leghorn', 'Chickadee', 'Whimbrel', 'Other Bird', 'Black', 'Waxwing', 'Orpington', 'Warbler', 'Canary', 'Macaw', 'Quail', 'Cardinal', 'Falcon', 'Egyptian', 'Starling', 'Gamefowl', 'Australorp', 'Polish', 'Pelican']

# %%
bird_replacements = {
    'Rhode Island' : 'Chicken',
    'Silkie' : 'Chicken',
    'Guinea' : 'Guinea Fowl',
    'African' : 'African Grey', 
    'Barred Rock' : 'Chicken',
    'Muscovy' : 'Muscovy Duck',
    'Song Bird' : 'Songbird',
    'Leghorn' : 'Chicken', 
    'Other Bird' : 'Other', 
    'Black' : 'Grackle',
    'Orpington' : 'Chicken',
    'Egyptian' : 'Other',
    'Gamefowl' : 'Other',
    'Australorp' : 'Chicken', 
    'Polish' : 'Chicken',
    'American' : 'Chicken',
    'Wyandottes' : 'Chicken',
    'Quaker' : 'Quaker Parrot'
}

# %%
# Replacements

aacIn = replace_breeds(aacIn, "Bird", bird_replacements)
# Out:
# Checking for 'Rhode Island' in 'PrimaryBreed'. Found: 10 times.
# Replaced 10 occurrences of 'Rhode Island' with 'Chicken'.
#
# Checking for 'Silkie' in 'PrimaryBreed'. Found: 6 times.
# Replaced 6 occurrences of 'Silkie' with 'Chicken'.
#
# Checking for 'Guinea' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Guinea' with 'Guinea Fowl'.
#
# Checking for 'African' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'African' with 'African Grey'.
#
# Checking for 'Barred Rock' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Barred Rock' with 'Chicken'.
#
# Checking for 'Muscovy' in 'PrimaryBreed'. Found: 7 times.
# Replaced 7 occurrences of 'Muscovy' with 'Muscovy Duck'.
#
# Checking for 'Song Bird' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Song Bird' with 'Songbird'.
#
# Checking for 'Leghorn' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Leghorn' with 'Chicken'.
#
# Checking for 'Other Bird' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Other Bird' with 'Other'.
#
# Checking for 'Black' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Black' with 'Grackle'.
#
# Checking for 'Orpington' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Orpington' with 'Chicken'.
#
# Checking for 'Egyptian' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Egyptian' with 'Other'.
#
# Checking for 'Gamefowl' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Gamefowl' with 'Other'.
#
# Checking for 'Australorp' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Australorp' with 'Chicken'.
#
# Checking for 'Polish' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Polish' with 'Chicken'.
#
# Checking for 'American' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Wyandottes' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Quaker' in 'PrimaryBreed'. Found: 10 times.
# Replaced 10 occurrences of 'Quaker' with 'Quaker Parrot'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Bird are now: 48
#
# Total replacements made: 55

# %%
# Evaluating Wildlife

print(aacIn.loc[aacIn['AnimalType'] == 'Wildlife', 'PrimaryBreed'].unique().tolist())
# Out:
# ['Bat', 'Raccoon', 'Skunk', 'Opossum', 'Fox', 'Armadillo', 'Squirrel', 'Turtle', 'Rat', 'Coyote', 'Tortoise', 'Cottontail', 'Cold Water', 'Snake', 'Lizard', 'Mouse', 'Tarantula', 'Frog', 'Ringtail', 'Bobcat', 'Otter', 'Deer', 'Prairie Dog']

# %%
wild_replacements = {
    'Cottontail' : 'Cottontail Rabbit',
    'Cold Water' : 'Fish',
    'Mex Free-Tail' : 'Bat'
}

# %%
# Replace

aacIn = replace_breeds(aacIn, "Wildlife", wild_replacements)
# Out:
# Checking for 'Cottontail' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Cottontail' with 'Cottontail Rabbit'.
#
# Checking for 'Cold Water' in 'PrimaryBreed'. Found: 35 times.
# Replaced 35 occurrences of 'Cold Water' with 'Fish'.
#
# Checking for 'Mex Free-Tail' in 'PrimaryBreed'. Found: 0 times.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Wildlife are now: 23
#
# Total replacements made: 40

# %%
# Looking through rabbits

print(aacIn.loc[aacIn['AnimalType'] == 'Rabbit', 'PrimaryBreed'].unique().tolist())
# Out:
# ['Rabbit Sh', 'Californian', 'Rex', 'English Spot', 'Lionhead', 'Silver', 'Dutch', 'Jersey Wooly', 'Lop-English', 'American', 'Lop-Holland', 'Rabbit Lh', 'American Sable', 'New Zealand Wht', 'Lop-Mini', 'Hotot', 'Cinnamon', 'Angora-French', 'Netherlnd Dwarf', 'Rex-Mini', 'Checkered Giant', 'Havana', 'Polish', 'Harlequin', 'Angora-English', 'Lop-Amer Fuzzy', 'Flemish Giant', 'Belgian Hare', 'Britannia Petit', 'Himalayan', 'Rhinelander', 'Beveren', 'Angora-Satin', 'Dwarf Hotot', 'Florida White', 'Lop-French']

# %%
bun_replacements = {
    'Rabbit Sh' : 'Shorthair', 
    'Lop-English' : 'English Lop',
    'Lop-Holland' : 'Holland Lop',
    'Rabbit Lh' : 'Longhair', 
    'New Zealand Wht' : 'New Zealand White',
    'Lop-Mini' : 'Mini Lop',
    'Angora-French' : 'French Angora',
    'Netherlnd Dwarf' : 'Netherland Dwarf',
    'Rex-Mini' : 'Mini Rex', 
    'Angora-English' : 'English Angora',
    'Lop-Amer Fuzzy' : 'American Fuzzy Lop',
    'Angora-Satin' : 'Satin Angora',
    'Lop-French' : 'French Lop',
}

# %%
# Replacing

aacIn = replace_breeds(aacIn, "Rabbit", bun_replacements)
# Out:
# Checking for 'Rabbit Sh' in 'PrimaryBreed'. Found: 660 times.
# Replaced 660 occurrences of 'Rabbit Sh' with 'Shorthair'.
#
# Checking for 'Lop-English' in 'PrimaryBreed'. Found: 15 times.
# Replaced 15 occurrences of 'Lop-English' with 'English Lop'.
#
# Checking for 'Lop-Holland' in 'PrimaryBreed'. Found: 28 times.
# Replaced 28 occurrences of 'Lop-Holland' with 'Holland Lop'.
#
# Checking for 'Rabbit Lh' in 'PrimaryBreed'. Found: 30 times.
# Replaced 30 occurrences of 'Rabbit Lh' with 'Longhair'.
#
# Checking for 'New Zealand Wht' in 'PrimaryBreed'. Found: 21 times.
# Replaced 21 occurrences of 'New Zealand Wht' with 'New Zealand White'.
#
# Checking for 'Lop-Mini' in 'PrimaryBreed'. Found: 15 times.
# Replaced 15 occurrences of 'Lop-Mini' with 'Mini Lop'.
#
# Checking for 'Angora-French' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Angora-French' with 'French Angora'.
#
# Checking for 'Netherlnd Dwarf' in 'PrimaryBreed'. Found: 13 times.
# Replaced 13 occurrences of 'Netherlnd Dwarf' with 'Netherland Dwarf'.
#
# Checking for 'Rex-Mini' in 'PrimaryBreed'. Found: 6 times.
# Replaced 6 occurrences of 'Rex-Mini' with 'Mini Rex'.
#
# Checking for 'Angora-English' in 'PrimaryBreed'. Found: 6 times.
# Replaced 6 occurrences of 'Angora-English' with 'English Angora'.
#
# Checking for 'Lop-Amer Fuzzy' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Lop-Amer Fuzzy' with 'American Fuzzy Lop'.
#
# Checking for 'Angora-Satin' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Angora-Satin' with 'Satin Angora'.
#
# Checking for 'Lop-French' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Lop-French' with 'French Lop'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Rabbit are now: 36
#
# Total replacements made: 807

# %%
# Almost done--Livestock...

print(aacIn.loc[aacIn['AnimalType'] == 'Livestock', 'PrimaryBreed'].unique().tolist())
# Out:
# ['Pig', 'Goat', 'Potbelly Pig', 'Sheep', 'Pygmy', 'Emu']

# %%
live_replacements = {
    'Potbelly Pig' : 'Pig',
    'Pygmy' : 'Goat'
}

# %%
# Just a couple replacements this time

aacIn = replace_breeds(aacIn, "Livestock", live_replacements)
# Out:
# Checking for 'Potbelly Pig' in 'PrimaryBreed'. Found: 4 times.
# Replaced 4 occurrences of 'Potbelly Pig' with 'Pig'.
#
# Checking for 'Pygmy' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Pygmy' with 'Goat'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Livestock are now: 4
#
# Total replacements made: 5

# %%
# Finally, Other...

print(aacIn.loc[aacIn['AnimalType'] == 'Other', 'PrimaryBreed'].unique().tolist())
# Out:
# ['Ferret', 'Guinea Pig', 'Hamster', 'Sugar Glider', 'Gerbil', 'Hedgehog', 'Chinchilla-Amer', 'Chinchilla-Stnd', 'Chinchilla', 'Tropical', 'Hermit Crab', 'Snake', 'Lizard']

# %%
other_replacements = {
    'Chinchilla-Amer' : 'Chinchilla',
    'Chinchilla-Stnd' : 'Chinchilla',
    'Tropical' : 'Fish',
    'Python' : 'Snake',
    'Bearded Dragon' : 'Lizard'
}

# %%
# Last replacements...

aacIn = replace_breeds(aacIn, "Other", other_replacements)
# Out:
# Checking for 'Chinchilla-Amer' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Chinchilla-Amer' with 'Chinchilla'.
#
# Checking for 'Chinchilla-Stnd' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Chinchilla-Stnd' with 'Chinchilla'.
#
# Checking for 'Tropical' in 'PrimaryBreed'. Found: 8 times.
# Replaced 8 occurrences of 'Tropical' with 'Fish'.
#
# Checking for 'Python' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Bearded Dragon' in 'PrimaryBreed'. Found: 0 times.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Other are now: 11
#
# Total replacements made: 13

# %% [markdown]
# I think that's finally it, for aacIn's Breed categories. Now we check our work and move on!

# %% [markdown]
# ##### Last Steps--Checking Our Work

# %%
print(aacIn['PrimaryBreed'].loc[aacIn['AnimalType'] == 'Dog'].value_counts())
# Out:
# PrimaryBreed
# American Pit Bull Terrier    15221
# Labrador Retriever           13530
# Chihuahua                    10921
# German Shepherd               6997
# Australian Cattle Dog         3421
#                              ...
# Dutch Sheepdog                   1
# Wolf Hybrid                      1
# Borzoi                           1
# Scottish Deerhound               1
# Tosa                             1
# Name: count, Length: 196, dtype: int64

# %%
print(aacIn['PrimaryBreed'].loc[aacIn['AnimalType'] == 'Cat'].value_counts())
# Out:
# PrimaryBreed
# Domestic Shorthair         57573
# Domestic Medium Hair        5454
# Domestic Longhair           2479
# Siamese                     2044
# Snowshoe                     285
# American Shorthair           284
# Maine Coon                   162
# Manx                         144
# Russian Blue                 139
# Ragdoll                       76
# Himalayan                     63
# Persian                       43
# Bengal                        31
# Abyssinian                    28
# Turkish Angora                21
# Balinese                      20
# American Curl Shorthair       17
# British Shorthair             16
# Tonkinese                     13
# Devon Rex                     11
# Japanese Bobtail              11
# Bombay                        10
# Burmese                        9
# Turkish Van                    9
# Cymric                         8
# Scottish Fold                  6
# Cornish Rex                    6
# Havana Brown                   6
# Oriental Shorthair             5
# Munchkin Shorthair             5
# Pixiebob Shorthair             5
# Norwegian Forest Cat           4
# Sphynx                         4
# Exotic Shorthair               4
# Colorpoint Shorthair           3
# Chartreux                      2
# Javanese                       2
# Munchkin Longhair              2
# Birman                         2
# American Wirehair              1
# Ocicat                         1
# Savannah                       1
# Name: count, dtype: int64

# %%
print(aacIn['PrimaryBreed'].loc[aacIn['AnimalType'] == 'Bird'].value_counts())
# Out:
# PrimaryBreed
# Chicken          378
# Parakeet         104
# Duck              76
# Pigeon            43
# Dove              35
# Cockatiel         30
# Grackle           24
# Finch             15
# Peafowl           14
# Parrot            12
# Quaker Parrot     10
# Hawk              10
# Sparrow           10
# Bantam            10
# Lovebird           8
# Owl                8
# Muscovy Duck       7
# Turkey             7
# Conure             7
# Vulture            7
# Mockingbird        7
# Heron              5
# Other              4
# Cockatoo           4
# Budgerigar         4
# Bluebird           4
# Guinea Fowl        3
# Pheasant           3
# Macaw              3
# Goose              2
# Waxwing            2
# Crow               2
# Catbird            2
# Quail              2
# Starling           1
# Falcon             1
# Cardinal           1
# Canary             1
# Warbler            1
# Chickadee          1
# Lark               1
# Whimbrel           1
# Wren               1
# Songbird           1
# African Grey       1
# Nuthatch           1
# Bunting            1
# Pelican            1
# Name: count, dtype: int64

# %%
print(aacIn['PrimaryBreed'].loc[aacIn['AnimalType'] == 'Rabbit'].value_counts())
# Out:
# PrimaryBreed
# Shorthair             660
# Californian            71
# Lionhead               46
# Rex                    37
# Longhair               30
# Holland Lop            28
# English Spot           22
# New Zealand White      21
# Havana                 15
# Mini Lop               15
# English Lop            15
# Netherland Dwarf       13
# American               12
# Dutch                  12
# Hotot                   7
# Flemish Giant           7
# English Angora          6
# Mini Rex                6
# Himalayan               6
# French Angora           5
# American Fuzzy Lop      5
# Jersey Wooly            4
# Cinnamon                4
# American Sable          3
# Harlequin               3
# Polish                  3
# Belgian Hare            2
# Checkered Giant         2
# Satin Angora            2
# Dwarf Hotot             2
# Florida White           2
# Silver                  1
# Britannia Petit         1
# Rhinelander             1
# Beveren                 1
# French Lop              1
# Name: count, dtype: int64

# %%
print(aacIn['PrimaryBreed'].loc[aacIn['AnimalType'] == 'Livestock'].value_counts())
# Out:
# PrimaryBreed
# Pig      25
# Goat      5
# Emu       2
# Sheep     1
# Name: count, dtype: int64

# %%
print(aacIn['PrimaryBreed'].loc[aacIn['AnimalType'] == 'Other'].value_counts())
# Out:
# PrimaryBreed
# Guinea Pig      705
# Hamster          80
# Ferret           78
# Chinchilla       15
# Gerbil            9
# Hedgehog          8
# Fish              8
# Sugar Glider      4
# Snake             4
# Lizard            2
# Hermit Crab       1
# Name: count, dtype: int64

# %% [markdown]
# I've noticed something in this process: some wildlife, birds, or other animals have an IsMix entry of True. Since these animals likely aren't actually mixed-breeds, I'm going to remove it from them.

# %%
# Starting with birds

aacIn.loc[aacIn['AnimalType'] == 'Bird', 'IsMix'] = False

# Checking that it worked right

print(aacIn['IsMix'].loc[aacIn['AnimalType'] == 'Bird'].value_counts())
# Out:
# IsMix
# False    876
# Name: count, dtype: int64

# %%
# Now onto Livestock

aacIn.loc[aacIn['AnimalType'] == 'Livestock', 'IsMix'] = False

# Wildlife

aacIn.loc[aacIn['AnimalType'] == 'Wildlife', 'IsMix'] = False

# And Other species

aacIn.loc[aacIn['AnimalType'] == 'Other', 'IsMix'] = False

# %%
# Rabbits and Cats may be suspect...let's check out how many of those animal types are mixes

aacIn.loc[(aacIn['AnimalType'] == 'Cat') & (aacIn['IsMix'] == True), :].shape[0]
# Out:
# 41313

# %% [markdown]
# That's a pretty large number of cats...I'm going to leave them be, for the time being.

# %%
aacIn.loc[(aacIn['AnimalType'] == 'Rabbit') & (aacIn['IsMix'] == True), :].shape[0]
# Out:
# 589

# %% [markdown]
# That's about half of the total rabbits. Since the breeds for rabbits were so specific and numerous, I'm going to let them keep their mixes.

# %%
# Check our work one last time

aacIn.sample(5)
# Out:
#       AnimalID   Name            IntakeDT     IntakeType IntakeCondition  \
# 88384  A779669    nan 2018-09-04 13:02:00  Public Assist          Normal
# 64960  A748953  Sambo 2017-05-09 18:14:00  Public Assist          Normal
# 10554  A678987    nan 2014-05-14 23:57:00          Stray         Nursing
# 10860  A679381   Cola 2014-05-20 11:46:00  Public Assist          Normal
# 31096  A705150    Jax 2015-06-14 01:03:00  Public Assist          Normal
#
#       AnimalType      IntakeSex IntakeAge                          Breed  \
# 88384       Bird    Intact Male    1 year                        Chicken
# 64960        Dog  Neutered Male   2 years             Labrador Retriever
# 10554        Cat  Intact Female    3 days       Domestic Medium Hair Mix
# 10860        Dog    Intact Male    1 year  Chihuahua Shorthair/Dachshund
# 31096        Dog    Intact Male  2 months              Staffordshire Mix
#
#              Color  AgeYears AgeCategory  IsMix                PrimaryBreed
# 88384    Red/White         1       Young  False                     Chicken
# 64960       Yellow         2       Young  False          Labrador Retriever
# 10554       Tortie         0      Infant   True        Domestic Medium Hair
# 10860    Tan/White         1       Young   True                   Chihuahua
# 31096  Brown/Black         0      Infant   True  Staffordshire Bull Terrier

# %% [markdown]
# #### Outcomes

# %% [markdown]
# ##### Preliminary Cleaning (Again)

# %%
# Start with the same steps we used earlier

# Clean the breeds column up first by making sure there are no case-related misspellings

aacOut['Breed'] = aacOut['Breed'].str.lower().str.strip()

print(aacOut['Breed'].value_counts())
# Out:
# Breed
# domestic shorthair mix                34027
# domestic shorthair                    23537
# pit bull mix                          10130
# labrador retriever mix                 8784
# chihuahua shorthair mix                6910
#                                       ...
# labrador retriever/saluki                 1
# cairn terrier/cardigan welsh corgi        1
# siamese/munchkin shorthair                1
# smooth fox terrier/beagle                 1
# dalmatian/english springer spaniel        1
# Name: count, Length: 3002, dtype: int64

# %%
# And add those capitals back

aacOut['Breed'] = aacOut['Breed'].str.title()
print(aacOut['Breed'].value_counts())
# Out:
# Breed
# Domestic Shorthair Mix                34027
# Domestic Shorthair                    23537
# Pit Bull Mix                          10130
# Labrador Retriever Mix                 8784
# Chihuahua Shorthair Mix                6910
#                                       ...
# Labrador Retriever/Saluki                 1
# Cairn Terrier/Cardigan Welsh Corgi        1
# Siamese/Munchkin Shorthair                1
# Smooth Fox Terrier/Beagle                 1
# Dalmatian/English Springer Spaniel        1
# Name: count, Length: 3002, dtype: int64

# %% [markdown]
# 3002 is almost exactly the number of breeds we had in the Intake dataset at this point--perfect.

# %%
# Apply "parse_breeds" to this dataset as well

aacOut[['IsMix', 'PrimaryBreed', 'SecondaryBreed']] = aacOut['Breed'].apply(parse_breeds)

# %%
# Check it

aacOut[['AnimalType', 'Breed', 'IsMix', 'PrimaryBreed', 'SecondaryBreed']].head(15)
# Out:
#    AnimalType                                 Breed  IsMix  \
# 0         Cat                Domestic Shorthair Mix   True
# 1         Cat                Domestic Shorthair Mix   True
# 2         Dog               Chihuahua Shorthair Mix   True
# 3    Wildlife                               Raccoon  False
# 4         Dog    Anatol Shepherd/Labrador Retriever   True
# 5         Cat                Domestic Shorthair Mix   True
# 6         Dog               Chihuahua Shorthair Mix   True
# 7         Dog  American Foxhound/Labrador Retriever   True
# 8         Cat                    Domestic Shorthair  False
# 9         Cat                    Domestic Shorthair  False
# 10        Cat                Domestic Shorthair Mix   True
# 11        Cat                Domestic Shorthair Mix   True
# 12        Dog    Border Collie/Cardigan Welsh Corgi   True
# 13        Cat                  Domestic Medium Hair  False
# 14        Cat                Domestic Shorthair Mix   True
#
#             PrimaryBreed        SecondaryBreed
# 0     Domestic Shorthair                  None
# 1     Domestic Shorthair                  None
# 2    Chihuahua Shorthair                  None
# 3                Raccoon                  None
# 4        Anatol Shepherd    Labrador Retriever
# 5     Domestic Shorthair                  None
# 6    Chihuahua Shorthair                  None
# 7      American Foxhound    Labrador Retriever
# 8     Domestic Shorthair                  None
# 9     Domestic Shorthair                  None
# 10    Domestic Shorthair                  None
# 11    Domestic Shorthair                  None
# 12         Border Collie  Cardigan Welsh Corgi
# 13  Domestic Medium Hair                  None
# 14    Domestic Shorthair                  None

# %%
# Looking at the new categories we have now

print(aacOut['PrimaryBreed'].value_counts())
print("Primary breed null values: " + str(aacOut['PrimaryBreed'].isnull().sum()))
print()
print(aacOut['SecondaryBreed'].value_counts())
print('Secondary breed null values: ' + str(aacOut['SecondaryBreed'].isnull().sum()))
# Out:
# PrimaryBreed
# Domestic Shorthair              57582
# Pit Bull                        14433
# Labrador Retriever              13501
# Chihuahua Shorthair             10089
# German Shepherd                  6968
#                                 ...
# Nuthatch                            1
# Britannia Petit                     1
# Spanish Mastiff                     1
# Grand Basset Griffon Vendeen        1
# Sheep                               1
# Name: count, Length: 386, dtype: int64
# Primary breed null values: 0
#
# SecondaryBreed
# Labrador Retriever     2287
# Pit Bull               1185
# Chihuahua Shorthair    1080
# German Shepherd        1034
# Dachshund               729
#                        ...
# Pygmy                     1
# Angora                    1
# Tibetan Spaniel           1
# Irish Terrier             1
# Californian               1
# Name: count, Length: 211, dtype: int64
# Secondary breed null values: 157483

# %% [markdown]
# Again, almost exactly the same numbers as the Intakes dataset, which bodes well

# %%
# Removing the SecondaryBreed column--too many nulls

aacOut.drop(columns = 'SecondaryBreed', inplace = True)

aacOut.head()
# Out:
#   AnimalID      Name           OutcomeDT  BirthDate      OutcomeType  \
# 0  A882831  Hamilton 2023-07-01 18:12:00 2023-03-25         Adoption
# 1  A794011     Chunk 2019-05-08 18:20:00 2017-05-02  Return to Owner
# 2  A776359     Gizmo 2018-07-18 16:02:00 2017-07-12         Adoption
# 3  A821648       nan 2020-08-16 11:38:00 2019-08-16       Euthanasia
# 4  A720371     Moose 2016-02-13 17:59:00 2015-10-08         Adoption
#
#   OutcomeSubtype AnimalType     OutcomeSex OutcomeAge  \
# 0            NaN        Cat  Neutered Male   3 months
# 1            NaN        Cat  Neutered Male    2 years
# 2            NaN        Dog  Neutered Male     1 year
# 3            NaN   Wildlife        Unknown     1 year
# 4            NaN        Dog  Neutered Male   4 months
#
#                                 Breed              Color  AgeYears  \
# 0              Domestic Shorthair Mix        Black/White         0
# 1              Domestic Shorthair Mix  Brown Tabby/White         2
# 2             Chihuahua Shorthair Mix        White/Brown         1
# 3                             Raccoon               Gray         1
# 4  Anatol Shepherd/Labrador Retriever               Buff         0
#
#   AgeCategory  IsMix         PrimaryBreed
# 0      Infant   True   Domestic Shorthair
# 1       Young   True   Domestic Shorthair
# 2       Young   True  Chihuahua Shorthair
# 3       Young  False              Raccoon
# 4      Infant   True      Anatol Shepherd

# %% [markdown]
# ##### Manually Checking and Replacing Breeds (Again)

# %% [markdown]
# This time (thankfully) this should be easier, since I already have dictionaries to apply (though I may still need to double-check that there are no new messy values in this dataset)

# %%
# Replacements: dogs

aacOut = replace_breeds(aacOut, "Dog", dog_replacements)
# Out:
# Checking for 'Black' in 'PrimaryBreed'. Found: 232 times.
# Replaced 232 occurrences of 'Black' with 'Other'.
#
# Checking for 'Doberman Pinsch' in 'PrimaryBreed'. Found: 533 times.
# Replaced 533 occurrences of 'Doberman Pinsch' with 'Doberman Pinscher'.
#
# Checking for 'Chinese Sharpei' in 'PrimaryBreed'. Found: 316 times.
# Replaced 316 occurrences of 'Chinese Sharpei' with 'Chinese Shar-Pei'.
#
# Checking for 'Dachshund Wirehair' in 'PrimaryBreed'. Found: 223 times.
# Replaced 223 occurrences of 'Dachshund Wirehair' with 'Dachshund'.
#
# Checking for 'Chihuahua Shorthair' in 'PrimaryBreed'. Found: 10089 times.
# Replaced 10089 occurrences of 'Chihuahua Shorthair' with 'Chihuahua'.
#
# Checking for 'Flat Coat Retriever' in 'PrimaryBreed'. Found: 159 times.
# Replaced 159 occurrences of 'Flat Coat Retriever' with 'Flat-Coated Retriever'.
#
# Checking for 'Dachshund Longhair' in 'PrimaryBreed'. Found: 258 times.
# Replaced 258 occurrences of 'Dachshund Longhair' with 'Dachshund'.
#
# Checking for 'Chihuahua Longhair' in 'PrimaryBreed'. Found: 854 times.
# Replaced 854 occurrences of 'Chihuahua Longhair' with 'Chihuahua'.
#
# Checking for 'Pointer' in 'PrimaryBreed'. Found: 1031 times.
# Replaced 1031 occurrences of 'Pointer' with 'German Shorthaired Pointer'.
#
# Checking for 'Catahoula' in 'PrimaryBreed'. Found: 1257 times.
# Replaced 1257 occurrences of 'Catahoula' with 'Catahoula Leopard Dog'.
#
# Checking for 'Parson Russell Terrier' in 'PrimaryBreed'. Found: 83 times.
# Replaced 83 occurrences of 'Parson Russell Terrier' with 'Jack Russell Terrier'.
#
# Checking for 'Port Water Dog' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Port Water Dog' with 'Portuguese Water Dog'.
#
# Checking for 'Miniature Bull Terrier' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Bullmastiff' in 'PrimaryBreed'. Found: 60 times.
# Replaced 60 occurrences of 'Bullmastiff' with 'Mastiff'.
#
# Checking for 'Eng Toy Spaniel' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Eng Toy Spaniel' with 'English Toy Spaniel'.
#
# Checking for 'Wire Hair Fox Terrier' in 'PrimaryBreed'. Found: 153 times.
# Replaced 153 occurrences of 'Wire Hair Fox Terrier' with 'Wire Fox Terrier'.
#
# Checking for 'West Highland' in 'PrimaryBreed'. Found: 122 times.
# Replaced 122 occurrences of 'West Highland' with 'West Highland White Terrier'.
#
# Checking for 'Bruss Griffon' in 'PrimaryBreed'. Found: 83 times.
# Replaced 83 occurrences of 'Bruss Griffon' with 'Brussels Griffon'.
#
# Checking for 'Petit Basset Griffon Vendéen' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'German Shorthair Pointer' in 'PrimaryBreed'. Found: 136 times.
# Replaced 136 occurrences of 'German Shorthair Pointer' with 'German Shorthaired Pointer'.
#
# Checking for 'Cavalier Span' in 'PrimaryBreed'. Found: 59 times.
# Replaced 59 occurrences of 'Cavalier Span' with 'Cavalier King Charles Spaniel'.
#
# Checking for 'Bluetick Hound' in 'PrimaryBreed'. Found: 46 times.
# Replaced 46 occurrences of 'Bluetick Hound' with 'Bluetick Coonhound'.
#
# Checking for 'Boykin Span' in 'PrimaryBreed'. Found: 14 times.
# Replaced 14 occurrences of 'Boykin Span' with 'Boykin Spaniel'.
#
# Checking for 'Chinese Crested' in 'PrimaryBreed'. Found: 27 times.
# Replaced 27 occurrences of 'Chinese Crested' with 'Chinese Crested Dog'.
#
# Checking for 'Glen Of Imaal' in 'PrimaryBreed'. Found: 15 times.
# Replaced 15 occurrences of 'Glen Of Imaal' with 'Glen Of Imaal Terrier'.
#
# Checking for 'Patterdale Terr' in 'PrimaryBreed'. Found: 26 times.
# Replaced 26 occurrences of 'Patterdale Terr' with 'Patterdale Terrier'.
#
# Checking for 'Dandie Dinmont' in 'PrimaryBreed'. Found: 8 times.
# Replaced 8 occurrences of 'Dandie Dinmont' with 'Dandie Dinmont Terrier'.
#
# Checking for 'Schnauzer Giant' in 'PrimaryBreed'. Found: 40 times.
# Replaced 40 occurrences of 'Schnauzer Giant' with 'Giant Schnauzer'.
#
# Checking for 'Sealyham Terr' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Sealyham Terr' with 'Sealyham Terrier'.
#
# Checking for 'Bedlington Terr' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Bedlington Terr' with 'Bedlington Terrier'.
#
# Checking for 'Sussex Span' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Sussex Span' with 'Sussex Spaniel'.
#
# Checking for 'Wirehaired Vizsla' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Wirehaired Vizsla' with 'Vizsla'.
#
# Checking for 'Curly Coat Retriever' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Curly Coat Retriever' with 'Curly-Coated Retriever'.
#
# Checking for 'Pit Bull' in 'PrimaryBreed'. Found: 14433 times.
# Replaced 14433 occurrences of 'Pit Bull' with 'American Pit Bull Terrier'.
#
# Checking for 'Anatol Shepherd' in 'PrimaryBreed'. Found: 882 times.
# Replaced 882 occurrences of 'Anatol Shepherd' with 'Anatolian Shepherd'.
#
# Checking for 'Staffordshire' in 'PrimaryBreed'. Found: 1012 times.
# Replaced 1012 occurrences of 'Staffordshire' with 'Staffordshire Bull Terrier'.
#
# Checking for 'Rhod Ridgeback' in 'PrimaryBreed'. Found: 211 times.
# Replaced 211 occurrences of 'Rhod Ridgeback' with 'Rhodesian Ridgeback'.
#
# Checking for 'Chesa Bay Retr' in 'PrimaryBreed'. Found: 36 times.
# Replaced 36 occurrences of 'Chesa Bay Retr' with 'Chesapeake Bay Retriever'.
#
# Checking for 'Queensland Heeler' in 'PrimaryBreed'. Found: 273 times.
# Replaced 273 occurrences of 'Queensland Heeler' with 'Australian Cattle Dog'.
#
# Checking for 'Collie Rough' in 'PrimaryBreed'. Found: 110 times.
# Replaced 110 occurrences of 'Collie Rough' with 'Rough Collie'.
#
# Checking for 'Collie Smooth' in 'PrimaryBreed'. Found: 198 times.
# Replaced 198 occurrences of 'Collie Smooth' with 'Smooth Collie'.
#
# Checking for 'St. Bernard Rough Coat' in 'PrimaryBreed'. Found: 64 times.
# Replaced 64 occurrences of 'St. Bernard Rough Coat' with 'Saint Bernard'.
#
# Checking for 'St. Bernard Smooth Coat' in 'PrimaryBreed'. Found: 38 times.
# Replaced 38 occurrences of 'St. Bernard Smooth Coat' with 'Saint Bernard'.
#
# Checking for 'Pbgv' in 'PrimaryBreed'. Found: 85 times.
# Replaced 85 occurrences of 'Pbgv' with 'Petit Basset Griffon Vendeen'.
#
# Checking for 'Bull Terrier Miniature' in 'PrimaryBreed'. Found: 22 times.
# Replaced 22 occurrences of 'Bull Terrier Miniature' with 'Bull Terrier'.
#
# Checking for 'Mexican Hairless' in 'PrimaryBreed'. Found: 15 times.
# Replaced 15 occurrences of 'Mexican Hairless' with 'Xoloitzcuintli'.
#
# Checking for 'Bouv Flandres' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Bouv Flandres' with 'Bouvier des Flandres'.
#
# Checking for 'Bernese Hound' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Bernese Hound' with 'Bernese Mountain Dog'.
#
# Checking for 'Silkie' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Dachshund Stan' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Dachshund Stan' with 'Dachshund'.
#
# Checking for 'Unknown' in 'PrimaryBreed'. Found: 6 times.
# Replaced 6 occurrences of 'Unknown' with 'Other'.
#
# Checking for 'Yorkshire' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'English Cocker Spaniel' in 'PrimaryBreed'. Found: 9 times.
# Replaced 9 occurrences of 'English Cocker Spaniel' with 'Cocker Spaniel'.
#
# Checking for 'Papillion' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Tan Hound' in 'PrimaryBreed'. Found: 0 times.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Dog are now: 196
#
# Total replacements made: 33243

# %%
# Go through the remainder for any sneaky weird values

pprint(aacOut['PrimaryBreed'][aacOut['AnimalType'] == 'Dog'].unique().tolist())
# Out:
# ['Chihuahua',
#  'Anatolian Shepherd',
#  'American Foxhound',
#  'Border Collie',
#  'American Pit Bull Terrier',
#  'Labrador Retriever',
#  'Black Mouth Cur',
#  'Weimaraner',
#  'Yorkshire Terrier',
#  'Jack Russell Terrier',
#  'Great Pyrenees',
#  'Australian Cattle Dog',
#  'Beagle',
#  'German Shepherd',
#  'Dogo Argentino',
#  'Cairn Terrier',
#  'Rough Collie',
#  'Rat Terrier',
#  'Doberman Pinscher',
#  'American Bulldog',
#  'American Staffordshire Terrier',
#  'Standard Poodle',
#  'Miniature Poodle',
#  'Dachshund',
#  'Bloodhound',
#  'Standard Schnauzer',
#  'Pug',
#  'Australian Shepherd',
#  'Siberian Husky',
#  'Australian Kelpie',
#  'Miniature Schnauzer',
#  'Miniature Pinscher',
#  'Boxer',
#  'Catahoula Leopard Dog',
#  'Staffordshire Bull Terrier',
#  'Bluetick Coonhound',
#  'Border Terrier',
#  'Flat-Coated Retriever',
#  'Mastiff',
#  'American Eskimo',
#  'Boston Terrier',
#  'Vizsla',
#  'Shiba Inu',
#  'Soft Coated Wheaten Terrier',
#  'German Shorthaired Pointer',
#  'Rottweiler',
#  'Akita',
#  'English Bulldog',
#  'Harrier',
#  'French Bulldog',
#  'Cardigan Welsh Corgi',
#  'Lhasa Apso',
#  'Alaskan Husky',
#  'Havanese',
#  'Golden Retriever',
#  'Wire Fox Terrier',
#  'Chow Chow',
#  'Great Dane',
#  'Greyhound',
#  'Smooth Collie',
#  'Shih Tzu',
#  'Norfolk Terrier',
#  'Cocker Spaniel',
#  'Basset Hound',
#  'Treeing Walker Coonhound',
#  'Tibetan Spaniel',
#  'Bull Terrier',
#  'Bichon Frise',
#  'Giant Schnauzer',
#  'Belgian Malinois',
#  'Maltese',
#  'Landseer',
#  'English Coonhound',
#  'Carolina Dog',
#  'Dalmatian',
#  'Other',
#  'Dogue De Bordeaux',
#  'Blue Lacy',
#  'Schipperke',
#  'Plott Hound',
#  'Welsh Terrier',
#  'Bearded Collie',
#  'Pomeranian',
#  'Italian Greyhound',
#  'Alaskan Malamute',
#  'Whippet',
#  'Pekingese',
#  'Cavalier King Charles Spaniel',
#  'Petit Basset Griffon Vendeen',
#  'Brittany',
#  'Wirehaired Pointing Griffon',
#  'Bernese Mountain Dog',
#  'Toy Poodle',
#  'West Highland White Terrier',
#  'Basenji',
#  'Podengo Pequeno',
#  'Irish Setter',
#  'German Wirehaired Pointer',
#  'Chinese Shar-Pei',
#  'English Shepherd',
#  'Papillon',
#  'Manchester Terrier',
#  'Finnish Spitz',
#  'Pembroke Welsh Corgi',
#  'Bulldog',
#  'Norwegian Elkhound',
#  'Leonberger',
#  'Airedale Terrier',
#  'Tibetan Terrier',
#  'Rhodesian Ridgeback',
#  'English Foxhound',
#  'Brussels Griffon',
#  'Xoloitzcuintli',
#  'Otterhound',
#  'English Pointer',
#  'Saint Bernard',
#  'Nova Scotia Duck Tolling Retriever',
#  'Toy Fox Terrier',
#  'Dutch Shepherd',
#  'Redbone Hound',
#  'Shetland Sheepdog',
#  'Australian Terrier',
#  'Ibizan Hound',
#  'Canaan Dog',
#  'Jindo',
#  'Chesapeake Bay Retriever',
#  'Norwich Terrier',
#  'Greater Swiss Mountain Dog',
#  'Picardy Sheepdog',
#  'Irish Terrier',
#  'Skye Terrier',
#  'Cane Corso',
#  'Belgian Sheepdog',
#  'English Setter',
#  'Newfoundland',
#  'Feist',
#  'Boykin Spaniel',
#  'Field Spaniel',
#  'Hovawart',
#  'Beauceron',
#  'Kangal',
#  'Scottish Terrier',
#  'German Pinscher',
#  'Patterdale Terrier',
#  'Pharaoh Hound',
#  'Smooth Fox Terrier',
#  'Old English Bulldog',
#  'Old English Sheepdog',
#  'English Toy Spaniel',
#  'Akbash',
#  'Boerboel',
#  'Treeing Cur',
#  'Glen Of Imaal Terrier',
#  'English Springer Spaniel',
#  'Chinese Crested Dog',
#  'Kuvasz',
#  'Lowchen',
#  'Belgian Tervuren',
#  'Affenpinscher',
#  'Silky Terrier',
#  'Presa Canario',
#  'Borzoi',
#  'Portuguese Water Dog',
#  'Keeshond',
#  'Coton De Tulear',
#  'Welsh Springer Spaniel',
#  'Irish Wolfhound',
#  'Swedish Vallhund',
#  'Neapolitan Mastiff',
#  'Clumber Spaniel',
#  'Bedlington Terrier',
#  'Saluki',
#  'Samoyed',
#  'Entlebucher',
#  'Wolf Hybrid',
#  'Treeing Tennesse Brindle',
#  'Tibetan Mastiff',
#  'Spanish Water Dog',
#  'Afghan Hound',
#  'Sussex Spaniel',
#  'Swiss Hound',
#  'Japanese Chin',
#  'Dandie Dinmont Terrier',
#  'Lakeland Terrier',
#  'Spanish Mastiff',
#  'Briard',
#  'Alaskan Klee Kai',
#  'Spinone Italiano',
#  'Scottish Deerhound',
#  'Gordon Setter',
#  'Grand Basset Griffon Vendeen',
#  'Dutch Sheepdog',
#  'Tosa',
#  'Sealyham Terrier',
#  'Curly-Coated Retriever',
#  'Bouvier des Flandres']

# %%
aacOut = replace_breeds(aacOut, "Cat", cat_replacements)
# Out:
# Checking for 'Oriental Sh' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Oriental Sh' with 'Oriental Shorthair'.
#
# Checking for 'Angora' in 'PrimaryBreed'. Found: 13 times.
# Replaced 13 occurrences of 'Angora' with 'Turkish Angora'.
#
# Checking for 'Colorpoint' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Colorpoint' with 'Colorpoint Shorthair'.
#
# Checking for 'Rex' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Rex' with 'Cornish Rex'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Cat are now: 42
#
# Total replacements made: 22

# %%
pprint(aacOut['PrimaryBreed'][aacOut['AnimalType'] == 'Cat'].unique().tolist())
# Out:
# ['Domestic Shorthair',
#  'Domestic Medium Hair',
#  'Siamese',
#  'Russian Blue',
#  'Persian',
#  'Domestic Longhair',
#  'Snowshoe',
#  'Bombay',
#  'American Shorthair',
#  'Abyssinian',
#  'Munchkin Shorthair',
#  'Bengal',
#  'Manx',
#  'Turkish Angora',
#  'Maine Coon',
#  'Himalayan',
#  'Japanese Bobtail',
#  'Tonkinese',
#  'Devon Rex',
#  'Ragdoll',
#  'British Shorthair',
#  'Balinese',
#  'Cymric',
#  'Scottish Fold',
#  'Norwegian Forest Cat',
#  'Cornish Rex',
#  'American Curl Shorthair',
#  'Burmese',
#  'Oriental Shorthair',
#  'Birman',
#  'Colorpoint Shorthair',
#  'Turkish Van',
#  'American Wirehair',
#  'Exotic Shorthair',
#  'Savannah',
#  'Sphynx',
#  'Havana Brown',
#  'Chartreux',
#  'Pixiebob Shorthair',
#  'Ocicat',
#  'Munchkin Longhair',
#  'Javanese']

# %%
aacOut = replace_breeds(aacOut, "Bird", bird_replacements)
# Out:
# Checking for 'Rhode Island' in 'PrimaryBreed'. Found: 10 times.
# Replaced 10 occurrences of 'Rhode Island' with 'Chicken'.
#
# Checking for 'Silkie' in 'PrimaryBreed'. Found: 6 times.
# Replaced 6 occurrences of 'Silkie' with 'Chicken'.
#
# Checking for 'Guinea' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Guinea' with 'Guinea Fowl'.
#
# Checking for 'African' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'African' with 'African Grey'.
#
# Checking for 'Barred Rock' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Barred Rock' with 'Chicken'.
#
# Checking for 'Muscovy' in 'PrimaryBreed'. Found: 6 times.
# Replaced 6 occurrences of 'Muscovy' with 'Muscovy Duck'.
#
# Checking for 'Song Bird' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Song Bird' with 'Songbird'.
#
# Checking for 'Leghorn' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Leghorn' with 'Chicken'.
#
# Checking for 'Other Bird' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Other Bird' with 'Other'.
#
# Checking for 'Black' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Black' with 'Grackle'.
#
# Checking for 'Orpington' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Orpington' with 'Chicken'.
#
# Checking for 'Egyptian' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Egyptian' with 'Other'.
#
# Checking for 'Gamefowl' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Gamefowl' with 'Other'.
#
# Checking for 'Australorp' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Australorp' with 'Chicken'.
#
# Checking for 'Polish' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Polish' with 'Chicken'.
#
# Checking for 'American' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Wyandottes' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Quaker' in 'PrimaryBreed'. Found: 10 times.
# Replaced 10 occurrences of 'Quaker' with 'Quaker Parrot'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Bird are now: 48
#
# Total replacements made: 54

# %%
pprint(aacOut['PrimaryBreed'][aacOut['AnimalType'] == 'Bird'].unique().tolist())
# Out:
# ['Parakeet',
#  'Chicken',
#  'Quaker Parrot',
#  'Dove',
#  'Peafowl',
#  'Waxwing',
#  'Duck',
#  'Pigeon',
#  'Hawk',
#  'Vulture',
#  'Heron',
#  'Goose',
#  'Parrot',
#  'Bantam',
#  'Grackle',
#  'Canary',
#  'Falcon',
#  'Lovebird',
#  'Conure',
#  'Owl',
#  'Budgerigar',
#  'Guinea Fowl',
#  'Muscovy Duck',
#  'Cockatiel',
#  'Chickadee',
#  'Macaw',
#  'Finch',
#  'Pheasant',
#  'Other',
#  'Sparrow',
#  'Mockingbird',
#  'Bluebird',
#  'Cardinal',
#  'Bunting',
#  'Turkey',
#  'Starling',
#  'Crow',
#  'Quail',
#  'Pelican',
#  'Nuthatch',
#  'Cockatoo',
#  'Warbler',
#  'Lark',
#  'African Grey',
#  'Songbird',
#  'Wren',
#  'Catbird',
#  'Whimbrel']

# %%
aacOut = replace_breeds(aacOut, "Wildlife", wild_replacements)
# Out:
# Checking for 'Cottontail' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Cottontail' with 'Cottontail Rabbit'.
#
# Checking for 'Cold Water' in 'PrimaryBreed'. Found: 35 times.
# Replaced 35 occurrences of 'Cold Water' with 'Fish'.
#
# Checking for 'Mex Free-Tail' in 'PrimaryBreed'. Found: 0 times.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Wildlife are now: 23
#
# Total replacements made: 40

# %%
pprint(aacOut['PrimaryBreed'][aacOut['AnimalType'] == 'Wildlife'].unique().tolist())
# Out:
# ['Raccoon',
#  'Opossum',
#  'Bat',
#  'Lizard',
#  'Fox',
#  'Snake',
#  'Squirrel',
#  'Skunk',
#  'Ringtail',
#  'Rat',
#  'Turtle',
#  'Mouse',
#  'Fish',
#  'Tortoise',
#  'Coyote',
#  'Armadillo',
#  'Tarantula',
#  'Cottontail Rabbit',
#  'Deer',
#  'Otter',
#  'Prairie Dog',
#  'Bobcat',
#  'Frog']

# %%
aacOut = replace_breeds(aacOut, "Rabbit", bun_replacements)
# Out:
# Checking for 'Rabbit Sh' in 'PrimaryBreed'. Found: 661 times.
# Replaced 661 occurrences of 'Rabbit Sh' with 'Shorthair'.
#
# Checking for 'Lop-English' in 'PrimaryBreed'. Found: 15 times.
# Replaced 15 occurrences of 'Lop-English' with 'English Lop'.
#
# Checking for 'Lop-Holland' in 'PrimaryBreed'. Found: 28 times.
# Replaced 28 occurrences of 'Lop-Holland' with 'Holland Lop'.
#
# Checking for 'Rabbit Lh' in 'PrimaryBreed'. Found: 31 times.
# Replaced 31 occurrences of 'Rabbit Lh' with 'Longhair'.
#
# Checking for 'New Zealand Wht' in 'PrimaryBreed'. Found: 21 times.
# Replaced 21 occurrences of 'New Zealand Wht' with 'New Zealand White'.
#
# Checking for 'Lop-Mini' in 'PrimaryBreed'. Found: 15 times.
# Replaced 15 occurrences of 'Lop-Mini' with 'Mini Lop'.
#
# Checking for 'Angora-French' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Angora-French' with 'French Angora'.
#
# Checking for 'Netherlnd Dwarf' in 'PrimaryBreed'. Found: 13 times.
# Replaced 13 occurrences of 'Netherlnd Dwarf' with 'Netherland Dwarf'.
#
# Checking for 'Rex-Mini' in 'PrimaryBreed'. Found: 6 times.
# Replaced 6 occurrences of 'Rex-Mini' with 'Mini Rex'.
#
# Checking for 'Angora-English' in 'PrimaryBreed'. Found: 6 times.
# Replaced 6 occurrences of 'Angora-English' with 'English Angora'.
#
# Checking for 'Lop-Amer Fuzzy' in 'PrimaryBreed'. Found: 5 times.
# Replaced 5 occurrences of 'Lop-Amer Fuzzy' with 'American Fuzzy Lop'.
#
# Checking for 'Angora-Satin' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Angora-Satin' with 'Satin Angora'.
#
# Checking for 'Lop-French' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Lop-French' with 'French Lop'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Rabbit are now: 36
#
# Total replacements made: 809

# %%
pprint(aacOut['PrimaryBreed'][aacOut['AnimalType'] == 'Rabbit'].unique().tolist())
# Out:
# ['Polish',
#  'Shorthair',
#  'Californian',
#  'Longhair',
#  'Lionhead',
#  'Holland Lop',
#  'Dutch',
#  'French Angora',
#  'English Spot',
#  'Satin Angora',
#  'English Lop',
#  'Rex',
#  'Rhinelander',
#  'Havana',
#  'New Zealand White',
#  'Netherland Dwarf',
#  'Hotot',
#  'Cinnamon',
#  'English Angora',
#  'American',
#  'American Fuzzy Lop',
#  'Mini Lop',
#  'Checkered Giant',
#  'American Sable',
#  'Himalayan',
#  'Flemish Giant',
#  'French Lop',
#  'Harlequin',
#  'Mini Rex',
#  'Florida White',
#  'Jersey Wooly',
#  'Silver',
#  'Britannia Petit',
#  'Beveren',
#  'Dwarf Hotot',
#  'Belgian Hare']

# %%
aacOut = replace_breeds(aacOut, "Livestock", live_replacements)
# Out:
# Checking for 'Potbelly Pig' in 'PrimaryBreed'. Found: 4 times.
# Replaced 4 occurrences of 'Potbelly Pig' with 'Pig'.
#
# Checking for 'Pygmy' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Pygmy' with 'Goat'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Livestock are now: 5
#
# Total replacements made: 5

# %%
pprint(aacOut['PrimaryBreed'][aacOut['AnimalType'] == 'Livestock'].unique().tolist())
# Out:
# ['Pig', 'Goat', 'Emu', 'Miniature', 'Sheep']

# %%
# We do actually have an issue here: what is "Miniature"? Could be a pig, a horse, a goat...
# for us since I have no way of knowing, it will be "Other"

live_replacements_add = {
    'Miniature' : 'Other'
}

aacOut = replace_breeds(aacOut, "Livestock", live_replacements_add)

print()
print(aacOut['PrimaryBreed'][aacOut['AnimalType'] == 'Livestock'].unique().tolist())
# Out:
# Checking for 'Miniature' in 'PrimaryBreed'. Found: 1 times.
# Replaced 1 occurrences of 'Miniature' with 'Other'.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Livestock are now: 5
#
# Total replacements made: 1
#
# ['Pig', 'Goat', 'Emu', 'Other', 'Sheep']

# %%
aacOut = replace_breeds(aacOut, "Other", other_replacements)
# Out:
# Checking for 'Chinchilla-Amer' in 'PrimaryBreed'. Found: 2 times.
# Replaced 2 occurrences of 'Chinchilla-Amer' with 'Chinchilla'.
#
# Checking for 'Chinchilla-Stnd' in 'PrimaryBreed'. Found: 3 times.
# Replaced 3 occurrences of 'Chinchilla-Stnd' with 'Chinchilla'.
#
# Checking for 'Tropical' in 'PrimaryBreed'. Found: 8 times.
# Replaced 8 occurrences of 'Tropical' with 'Fish'.
#
# Checking for 'Python' in 'PrimaryBreed'. Found: 0 times.
#
# Checking for 'Bearded Dragon' in 'PrimaryBreed'. Found: 0 times.
#
# After replacements, the unique breeds in 'PrimaryBreed' for Other are now: 11
#
# Total replacements made: 13

# %%
pprint(aacOut['PrimaryBreed'][aacOut['AnimalType'] == 'Other'].unique().tolist())
# Out:
# ['Guinea Pig',
#  'Ferret',
#  'Chinchilla',
#  'Hamster',
#  'Hedgehog',
#  'Snake',
#  'Gerbil',
#  'Fish',
#  'Lizard',
#  'Hermit Crab',
#  'Sugar Glider']

# %% [markdown]
# Breeds replaced! Let's move on to our final steps again!

# %% [markdown]
# ##### Final Steps (Again)

# %%
# Check our work

print(aacOut['PrimaryBreed'].loc[aacOut['AnimalType'] == 'Dog'].value_counts())
# Out:
# PrimaryBreed
# American Pit Bull Terrier    15138
# Labrador Retriever           13501
# Chihuahua                    10943
# German Shepherd               6968
# Australian Cattle Dog         3416
#                              ...
# Scottish Deerhound               1
# Borzoi                           1
# Spanish Water Dog                1
# Wolf Hybrid                      1
# Bouvier des Flandres             1
# Name: count, Length: 196, dtype: int64

# %%
print(aacOut['PrimaryBreed'].loc[aacOut['AnimalType'] == 'Cat'].value_counts())
# Out:
# PrimaryBreed
# Domestic Shorthair         57582
# Domestic Medium Hair        5478
# Domestic Longhair           2477
# Siamese                     2044
# Snowshoe                     288
# American Shorthair           284
# Maine Coon                   166
# Manx                         144
# Russian Blue                 140
# Ragdoll                       76
# Himalayan                     63
# Persian                       44
# Bengal                        31
# Abyssinian                    28
# Turkish Angora                21
# Balinese                      20
# American Curl Shorthair       17
# British Shorthair             15
# Tonkinese                     13
# Japanese Bobtail              11
# Devon Rex                     11
# Bombay                        10
# Turkish Van                    9
# Burmese                        9
# Cymric                         8
# Havana Brown                   6
# Cornish Rex                    6
# Pixiebob Shorthair             5
# Munchkin Shorthair             5
# Scottish Fold                  5
# Oriental Shorthair             5
# Norwegian Forest Cat           4
# Exotic Shorthair               4
# Sphynx                         4
# Colorpoint Shorthair           3
# Chartreux                      2
# Munchkin Longhair              2
# Birman                         2
# Javanese                       2
# Savannah                       1
# Ocicat                         1
# American Wirehair              1
# Name: count, dtype: int64

# %%
print(aacOut['PrimaryBreed'].loc[aacOut['AnimalType'] == 'Wildlife'].value_counts())
# Out:
# PrimaryBreed
# Bat                  4102
# Raccoon              1358
# Opossum               389
# Skunk                 281
# Fox                   205
# Squirrel              163
# Rat                   141
# Snake                  46
# Turtle                 43
# Lizard                 38
# Coyote                 38
# Fish                   35
# Mouse                  29
# Tortoise               27
# Armadillo              13
# Tarantula               6
# Cottontail Rabbit       5
# Ringtail                3
# Deer                    3
# Otter                   2
# Prairie Dog             1
# Bobcat                  1
# Frog                    1
# Name: count, dtype: int64

# %%
print(aacOut['PrimaryBreed'].loc[aacOut['AnimalType'] == 'Rabbit'].value_counts())
# Out:
# PrimaryBreed
# Shorthair             661
# Californian            71
# Lionhead               46
# Rex                    37
# Longhair               31
# Holland Lop            28
# English Spot           22
# New Zealand White      21
# Mini Lop               15
# English Lop            15
# Havana                 15
# Netherland Dwarf       13
# Dutch                  12
# American               12
# Flemish Giant           7
# Hotot                   7
# English Angora          6
# Himalayan               6
# Mini Rex                6
# American Fuzzy Lop      5
# French Angora           5
# Cinnamon                4
# Jersey Wooly            4
# Harlequin               3
# Polish                  3
# American Sable          3
# Checkered Giant         2
# Florida White           2
# Satin Angora            2
# Dwarf Hotot             2
# Belgian Hare            2
# French Lop              1
# Rhinelander             1
# Silver                  1
# Britannia Petit         1
# Beveren                 1
# Name: count, dtype: int64

# %%
print(aacOut['PrimaryBreed'].loc[aacOut['AnimalType'] == 'Bird'].value_counts())
# Out:
# PrimaryBreed
# Chicken          377
# Parakeet         104
# Duck              76
# Pigeon            43
# Dove              35
# Cockatiel         30
# Grackle           24
# Finch             15
# Peafowl           14
# Parrot            12
# Quaker Parrot     10
# Sparrow           10
# Hawk              10
# Bantam            10
# Lovebird           8
# Owl                8
# Turkey             7
# Vulture            7
# Conure             7
# Mockingbird        7
# Muscovy Duck       6
# Heron              5
# Cockatoo           4
# Budgerigar         4
# Bluebird           4
# Other              4
# Pheasant           3
# Guinea Fowl        3
# Macaw              3
# Catbird            2
# Waxwing            2
# Goose              2
# Quail              2
# Crow               2
# Lark               1
# Wren               1
# African Grey       1
# Songbird           1
# Warbler            1
# Chickadee          1
# Nuthatch           1
# Pelican            1
# Starling           1
# Bunting            1
# Cardinal           1
# Falcon             1
# Canary             1
# Whimbrel           1
# Name: count, dtype: int64

# %%
print(aacOut['PrimaryBreed'].loc[aacOut['AnimalType'] == 'Livestock'].value_counts())
# Out:
# PrimaryBreed
# Pig      25
# Goat      5
# Emu       2
# Other     1
# Sheep     1
# Name: count, dtype: int64

# %%
print(aacOut['PrimaryBreed'].loc[aacOut['AnimalType'] == 'Other'].value_counts())
# Out:
# PrimaryBreed
# Guinea Pig      697
# Hamster          81
# Ferret           78
# Chinchilla       15
# Gerbil            9
# Hedgehog          8
# Fish              8
# Sugar Glider      4
# Snake             3
# Lizard            2
# Hermit Crab       1
# Name: count, dtype: int64

# %%
# Now we fix the IsMix column

aacOut.loc[aacOut['AnimalType'] == 'Bird', 'IsMix'] = False  # Removing it for Birds...
aacOut.loc[aacOut['AnimalType'] == 'Livestock', 'IsMix'] = False  # For Livestock...
aacOut.loc[aacOut['AnimalType'] == 'Wildlife', 'IsMix'] = False  # For Wildlife...
aacOut.loc[aacOut['AnimalType'] == 'Other', 'IsMix'] = False  # And for Others

# %%
# Check them one last time

# Birds

print(aacOut['IsMix'].loc[aacOut['AnimalType'] == 'Bird'].value_counts())
# Out:
# IsMix
# False    874
# Name: count, dtype: int64

# %%
# Wildlife

print(aacOut['IsMix'].loc[aacOut['AnimalType'] == 'Wildlife'].value_counts())
# Out:
# IsMix
# False    6930
# Name: count, dtype: int64

# %%
# Others

print(aacOut['IsMix'].loc[aacOut['AnimalType'] == 'Other'].value_counts())
# Out:
# IsMix
# False    906
# Name: count, dtype: int64

# %%
aacOut.sample(5)
# Out:
#        AnimalID      Name           OutcomeDT  BirthDate OutcomeType  \
# 77949   A685235       nan 2014-08-04 15:07:00 2013-10-04  Euthanasia
# 43933   A807123       nan 2019-10-25 19:40:00 2019-06-21    Adoption
# 149234  A746535   Old Red 2017-04-12 16:37:00 2009-04-04    Transfer
# 61598   A841272  Hermione 2021-09-18 09:46:00 2021-07-14    Adoption
# 44019   A750937  Perpetua 2017-06-09 00:00:00 2017-05-11    Transfer
#
#        OutcomeSubtype AnimalType     OutcomeSex OutcomeAge  \
# 77949       Suffering        Cat    Intact Male   9 months
# 43933             NaN        Dog  Spayed Female   4 months
# 149234        Partner        Dog    Intact Male    8 years
# 61598             NaN        Dog  Spayed Female   2 months
# 44019         Partner        Cat  Intact Female    4 weeks
#
#                             Breed         Color  AgeYears AgeCategory  IsMix  \
# 77949      Domestic Shorthair Mix   Flame Point         1      Infant   True
# 43933             German Shepherd   Black/Cream         0      Infant  False
# 149234        German Shepherd Mix           Red         8      Senior   True
# 61598   Australian Cattle Dog Mix     White/Tan         0      Infant   True
# 44019      Domestic Shorthair Mix  Orange Tabby         0      Infant   True
#
#                  PrimaryBreed
# 77949      Domestic Shorthair
# 43933         German Shepherd
# 149234        German Shepherd
# 61598   Australian Cattle Dog
# 44019      Domestic Shorthair

# %% [markdown]
# And that's all, finally, for the breeds! (It took a very long time.) Onto the last columns that need to be cleaned: Color!

# %% [markdown]
# ### Color

# %% [markdown]
# #### Intakes

# %%
print(aacIn['Color'].value_counts())
# Out:
# Color
# Black/White                 17928
# Black                       14619
# Brown Tabby                 10657
# Brown                        7140
# White                        6120
#                             ...
# Red Merle/Tan                   1
# Brown Brindle/Liver Tick        1
# Green/Silver                    1
# Black Smoke/Brown Tabby         1
# Ruddy/Black                     1
# Name: count, Length: 660, dtype: int64

# %% [markdown]
# 660 is also too many categories to be useful for modeling or graphing. To solve this, I think I need to separate colors which are mixed with "/", much as I did for breeds, and save only the primary color. I can also later consolidate colors with just a few entries into an "Other" category.

# %%
def process_colors(color):
    """
    Split color combinations and keep only the first printed;
    Leave "Black/White" or "White/Black" as "Black/White".

    Args:
        color (str): Color, as a string.

    Returns:
        color (str): "Black/White" or the primary color of the string, minus "/".
    """
    if pd.isna(color):
        return None  # Missing values
    if color in ('Black/White', 'White/Black'):
        return 'Black/White'  # Keep these entries, as they refer to a common color scheme
    if '/' in color:
        return color.split('/')[0]  # Reduce color entries to the first color listed
    return color  # Return the first color

# %%
aacIn['ColorClean'] = aacIn['Color'].apply(process_colors)

print(aacIn['ColorClean'].value_counts())
# Out:
# ColorClean
# Black           24071
# Black/White     22751
# Brown           17478
# White           17243
# Brown Tabby     16276
#                 ...
# Black Tiger         9
# Orange Tiger        6
# Ruddy               3
# Cream Tiger         2
# Unknown             1
# Name: count, Length: 61, dtype: int64

# %% [markdown]
# That alone reduced our color count to 61, versus the previous 660 we had. Now to standardize things such as "Grey"/"Gray", "White/Black"/"Black/White", "Tiger"/"Tabby", etc.

# %%
pprint(aacIn['ColorClean'].unique())
# Out:
# array(['White', 'Orange', 'Blue', 'Black/White', 'Brown Tabby', 'Black',
#        'Buff', 'Silver', 'Tortie', 'Tan', 'Orange Tabby', 'Brown', 'Red',
#        'Tricolor', 'Apricot', 'Gray', 'Brown Brindle', 'Cream', 'Calico',
#        'Black Tabby', 'Blue Tabby', 'Sable', 'Fawn', 'Torbie',
#        'Chocolate', 'Blue Merle', 'Yellow', 'Gold', 'Cream Tabby',
#        'Black Brindle', 'Black Smoke', 'Red Merle', 'Tortie Point',
#        'Seal Point', 'Brown Merle', 'Liver', 'Lynx Point', 'Lilac Point',
#        'Blue Tick', 'Brown Tiger', 'Blue Cream', 'Flame Point',
#        'Blue Point', 'Calico Point', 'Chocolate Point', 'Red Tick',
#        'Gray Tabby', 'Green', 'Silver Tabby', 'Yellow Brindle',
#        'Blue Tiger', 'Blue Smoke', 'Ruddy', 'Black Tiger', 'Pink',
#        'Agouti', 'Liver Tick', 'Silver Lynx Point', 'Orange Tiger',
#        'Cream Tiger', 'Unknown'], dtype=object)

# %% [markdown]
# There are some that are still overly specific, so I may make a condensed column with just the most basic color (e.g. "Brown Tabby" -> "Brown") eventually.

# %%
color_remaps = {
    "Tortie" : "Tortoiseshell",
    "Tortie Point" : "Tortoiseshell Point",
    "Orange Tiger" : "Orange Tabby", # Some exploring shows there are no dogs in this group
    "Cream Tiger" : "Cream Tabby" # Same as above
}

# Brown, Blue, and Black Tiger are complicated, because they are correct if referring to dogs, but not to cats
    # (and all three of these are applied to both currently)

color_remap_not_dog = {
    "Brown Tiger" : "Brown Tabby",
    "Blue Tiger" : "Blue Tabby", 
    "Black Tiger" : "Black Tabby"
}

# %%
# For these, I don't need a full function the way I did for Breeds

# First the overall replacements

for old_val, new_val in color_remaps.items():
    aacIn.loc[(aacIn['ColorClean'] == old_val), 'ColorClean'] = new_val

# Then the cat-specific ones--only replace if the AnimalType refers to a cat

for old_value, new_value in color_remap_not_dog.items():
    aacIn.loc[(aacIn['AnimalType'] == "Cat") & (aacIn['ColorClean'] == old_value), 'ColorClean'] = new_value

# Check it worked...

print(aacIn['AnimalType'].loc[(aacIn['ColorClean'] == 'Brown Tiger')].value_counts())
# Out:
# AnimalType
# Dog    37
# Name: count, dtype: int64

# %%
pprint(aacIn['ColorClean'].unique())
print()
print(aacIn['ColorClean'].nunique())
# Out:
# array(['White', 'Orange', 'Blue', 'Black/White', 'Brown Tabby', 'Black',
#        'Buff', 'Silver', 'Tortoiseshell', 'Tan', 'Orange Tabby', 'Brown',
#        'Red', 'Tricolor', 'Apricot', 'Gray', 'Brown Brindle', 'Cream',
#        'Calico', 'Black Tabby', 'Blue Tabby', 'Sable', 'Fawn', 'Torbie',
#        'Chocolate', 'Blue Merle', 'Yellow', 'Gold', 'Cream Tabby',
#        'Black Brindle', 'Black Smoke', 'Red Merle', 'Tortoiseshell Point',
#        'Seal Point', 'Brown Merle', 'Liver', 'Lynx Point', 'Lilac Point',
#        'Blue Tick', 'Blue Cream', 'Flame Point', 'Blue Point',
#        'Calico Point', 'Chocolate Point', 'Red Tick', 'Gray Tabby',
#        'Green', 'Silver Tabby', 'Yellow Brindle', 'Blue Tiger',
#        'Blue Smoke', 'Ruddy', 'Pink', 'Agouti', 'Liver Tick',
#        'Silver Lynx Point', 'Brown Tiger', 'Black Tiger', 'Unknown'],
#       dtype=object)
#
# 59

# %% [markdown]
# It appears to have worked! So now, instead of 600 colors and combinations of colors, we have 69 categories, which is much easier to work with.

# %% [markdown]
# #### Outcomes

# %% [markdown]
# For the Outcomes dataset, all I need to do is essentially the same thing I did for Intakes, and then double-check that there are not any new anomalies that need fixing.

# %%
# Our function is already defined, so we just apply it

aacOut['ColorClean'] = aacOut['Color'].apply(process_colors)

# %%
# Overall replacements, using the dicts we created for aacIn

for old_val, new_val in color_remaps.items():
    aacOut.loc[(aacOut['ColorClean'] == old_val), 'ColorClean'] = new_val

# Cat-specific replacements

for old_value, new_value in color_remap_not_dog.items():
    aacOut.loc[(aacOut['AnimalType'] == "Cat") & (aacOut['ColorClean'] == old_value), 'ColorClean'] = new_value

# Check it worked...

print(aacOut['AnimalType'].loc[(aacOut['ColorClean'] == 'Brown Tiger')].value_counts())
# Out:
# AnimalType
# Dog    37
# Name: count, dtype: int64

# %%
# Check it worked and there are no further issues

print(aacOut['ColorClean'].unique())
# Out:
# ['Black/White' 'Brown Tabby' 'White' 'Gray' 'Buff' 'Orange Tabby' 'Brown'
#  'Blue Tabby' 'Black' 'Blue' 'Red' 'Torbie' 'Lilac Point' 'Calico'
#  'Tricolor' 'Chocolate' 'Brown Brindle' 'Tan' 'Cream Tabby' 'Blue Tick'
#  'Fawn' 'Tortoiseshell' 'Sable' 'Cream' 'Blue Merle' 'Silver Lynx Point'
#  'Brown Merle' 'Silver' 'Apricot' 'Green' 'Tortoiseshell Point'
#  'Seal Point' 'Lynx Point' 'Black Brindle' 'Yellow' 'Yellow Brindle'
#  'Chocolate Point' 'Blue Smoke' 'Silver Tabby' 'Gray Tabby' 'Orange'
#  'Brown Tiger' 'Gold' 'Flame Point' 'Black Tabby' 'Black Smoke'
#  'Calico Point' 'Blue Cream' 'Agouti' 'Red Merle' 'Blue Point' 'Red Tick'
#  'Liver' 'Liver Tick' 'Black Tiger' 'Pink' 'Blue Tiger' 'Unknown' 'Ruddy']

# %%
# Just making sure "Green" is assigned to the appropriate species, for my own peace of mind

print(aacOut[['AnimalType', 'PrimaryBreed']].loc[(aacOut['ColorClean'] == 'Green')].value_counts())
# Out:
# AnimalType  PrimaryBreed
# Bird        Parakeet         33
# Wildlife    Turtle           27
# Bird        Parrot            9
#             Quaker Parrot     9
# Wildlife    Lizard            8
#             Tortoise          5
# Bird        Conure            4
#             Lovebird          4
#             Peafowl           2
#             Budgerigar        1
#             Cockatiel         1
#             Macaw             1
# Wildlife    Snake             1
# Name: count, dtype: int64

# %% [markdown]
# And that's it for color! Relatively painless, after Breeds...

# %% [markdown]
# ## Final Steps

# %% [markdown]
# Checking dtypes one more time
#
# What I should see is
# * String/Object: AnimalID, Name, IntakeType, IntakeCondition, AnimalType, IntakeSex, IntakeAge (that original column), Breed, Color, AgeCategory, PrimaryBreed, ColorClean, OutcomeType, OutcomeSubtype, OutcomeSex, OutcomeAge (again, that original column)
# * Datetime: IntakeDT, OutcomeDT, BirthDate
# * Integer: AgeYears
# * Boolean: IsMix

# %%
print(aacIn.dtypes)
print() 
print(aacOut.dtypes)
# Out:
# AnimalID                   object
# Name                       object
# IntakeDT           datetime64[ns]
# IntakeType                 object
# IntakeCondition            object
# AnimalType                 object
# IntakeSex                  object
# IntakeAge                  object
# Breed                      object
# Color                      object
# AgeYears                    Int64
# AgeCategory                object
# IsMix                        bool
# PrimaryBreed               object
# ColorClean                 object
# dtype: object
#
# AnimalID                  object
# Name                      object
# OutcomeDT         datetime64[ns]
# BirthDate         datetime64[ns]
# OutcomeType               object
# OutcomeSubtype            object
# AnimalType                object
# OutcomeSex                object
# OutcomeAge                object
# Breed                     object
# Color                     object
# AgeYears                   Int64
# AgeCategory               object
# IsMix                       bool
# PrimaryBreed              object
# ColorClean                object
# dtype: object

# %% [markdown]
# ### Revisiting Nulls

# %%
# Revisiting missing values

print(aacIn.isnull().sum())
print()
print(aacOut.isnull().sum())
# Out:
# AnimalID           0
# Name               0
# IntakeDT           0
# IntakeType         0
# IntakeCondition    0
# AnimalType         0
# IntakeSex          2
# IntakeAge          1
# Breed              0
# Color              0
# AgeYears           1
# AgeCategory        0
# IsMix              0
# PrimaryBreed       0
# ColorClean         0
# dtype: int64
#
# AnimalID              0
# Name                  0
# OutcomeDT             0
# BirthDate             0
# OutcomeType          46
# OutcomeSubtype    93762
# AnimalType            0
# OutcomeSex            2
# OutcomeAge            9
# Breed                 0
# Color                 0
# AgeYears              9
# AgeCategory           0
# IsMix                 0
# PrimaryBreed          0
# ColorClean            0
# dtype: int64

# %%
# IntakeSex & OutcomeSex--fill with "Unknown"

aacIn['IntakeSex'] = aacIn['IntakeSex'].fillna('Unknown')
aacOut['OutcomeSex'] = aacOut['OutcomeSex'].fillna('Unknown')

print(aacIn['IntakeSex'].value_counts())
print()
print(aacOut['OutcomeSex'].value_counts())
# Out:
# IntakeSex
# Intact Male      58813
# Intact Female    56512
# Neutered Male    24190
# Spayed Female    20280
# Unknown          13462
# Name: count, dtype: int64
#
# OutcomeSex
# Neutered Male    60681
# Spayed Female    55062
# Intact Male      22167
# Intact Female    21731
# Unknown          13411
# Name: count, dtype: int64

# %%
# IntakeAge & OutcomeAge: I'm going to employ the same method again, and set them as "Unknown"

aacIn['IntakeAge'] = aacIn['IntakeAge'].fillna('Unknown')
aacOut['OutcomeAge'] = aacOut['OutcomeAge'].fillna('Unknown')

print(aacIn['IntakeAge'].value_counts())
print()
print(aacOut['OutcomeAge'].value_counts())
# Out:
# IntakeAge
# 1 year       28202
# 2 years      27952
# 1 month      18148
# 2 months     10409
# 3 years       9581
# 4 weeks       6295
# 4 years       5827
# 5 years       5177
# 3 weeks       5101
# 3 months      4900
# 4 months      4773
# 5 months      4368
# 2 weeks       3650
# 6 years       3421
# 6 months      3325
# 7 years       3001
# 8 years       2829
# 7 months      2585
# 9 months      2487
# 10 years      2288
# 8 months      2025
# 9 years       1670
# 1 week        1469
# 1 weeks       1413
# 10 months     1383
# 0 years       1247
# 11 months     1137
# 12 years      1116
# 1 day         1009
# 11 years       923
# 3 days         920
# 2 days         768
# 13 years       715
# 6 days         532
# 14 years       523
# 4 days         497
# 15 years       451
# 5 weeks        444
# 5 days         263
# 16 years       192
# 17 years       104
# 18 years        62
# 19 years        29
# 20 years        26
# 22 years         6
# 1 years          6
# 25 years         2
# 24 years         1
# 21 years         1
# 23 years         1
# Unknown          1
# 30 years         1
# 28 years         1
# Name: count, dtype: int64
#
# OutcomeAge
# 1 year       28667
# 2 years      27794
# 2 months     23182
# 3 years       9760
# 3 months      9174
# 1 month       7378
# 4 months      6037
# 4 years       5798
# 5 years       5249
# 5 months      4429
# 6 months      4184
# 6 years       3416
# 7 years       3009
# 8 years       2950
# 3 weeks       2885
# 2 weeks       2877
# 8 months      2706
# 4 weeks       2407
# 10 months     2392
# 10 years      2382
# 7 months      2269
# 9 months      1763
# 9 years       1656
# 1 weeks       1345
# 12 years      1161
# 11 months     1099
# 1 week         961
# 11 years       922
# 13 years       743
# 3 days         567
# 14 years       535
# 2 days         526
# 1 day          506
# 15 years       462
# 4 days         357
# 6 days         341
# 0 years        272
# 5 days         235
# 5 weeks        202
# 16 years       200
# 17 years       107
# 18 years        64
# 19 years        29
# 20 years        26
# Unknown          9
# 1 years          6
# 22 years         6
# 25 years         2
# 23 years         1
# 30 years         1
# 28 years         1
# 24 years         1
# 21 years         1
# Name: count, dtype: int64

# %%
# AgeYears: fill with the median

aacIn['AgeYears'] = aacIn['AgeYears'].fillna(aacIn['AgeYears'].median())
aacOut['AgeYears'] = aacOut['AgeYears'].fillna(aacOut['AgeYears'].median())

print(aacIn['AgeYears'].isna().sum())
print()
print(aacOut['AgeYears'].isna().sum())
# Out:
# 0
#
# 0

# %%
# OutcomeType

# Remind myself what the current categories are...

print(aacOut['OutcomeType'].value_counts())
# Out:
# OutcomeType
# Adoption           84214
# Transfer           48527
# Return to Owner    26865
# Euthanasia         11638
# Died                1663
# Missing               99
# Name: count, dtype: int64

# %%
# I think we're going to add those nulls to "Missing" as, after all, the Outcome is missing.
# (It's obviously not a direct correlation, but it's close enough)

aacOut['OutcomeType'] = aacOut['OutcomeType'].fillna('Missing')

print(aacOut['OutcomeType'].value_counts())
# Out:
# OutcomeType
# Adoption           84214
# Transfer           48527
# Return to Owner    26865
# Euthanasia         11638
# Died                1663
# Missing              145
# Name: count, dtype: int64

# %%
# OutcomeSubtype

# Remind myself again, what categories we have

print(aacOut['OutcomeSubtype'].value_counts())
# Out:
# OutcomeSubtype
# Partner                  40247
# Foster                   17851
# Rabies Risk               4891
# Suffering                 4123
# Shelter Neuter Return     4078
# Scratched Person          3208
# Out of State               931
# In Kennel                  868
# Aggressive                 612
# Offsite                    512
# In Foster                  416
# Medical                    353
# At Vet                     352
# In Field                   242
# Behavior                   176
# Enroute                    112
# Court/Investigation        100
# Emergency                   64
# Underage                    37
# In Surgery                  33
# Customer S                  20
# Pet Resource Center         20
# Possible Theft              16
# Barn                        16
# In State                    12
# Name: count, dtype: int64

# %%
# As much as I would like to have these details around,
    # I think there are not enough of them to justify keeping the column,
    # as it is not particularly helpful to the scope of this project;
    # OutcomeType is enough.

aacOut = aacOut.drop(columns = 'OutcomeSubtype')

print(aacOut.columns)
# Out:
# Index(['AnimalID', 'Name', 'OutcomeDT', 'BirthDate', 'OutcomeType',
#        'AnimalType', 'OutcomeSex', 'OutcomeAge', 'Breed', 'Color', 'AgeYears',
#        'AgeCategory', 'IsMix', 'PrimaryBreed', 'ColorClean'],
#       dtype='object')

# %% [markdown]
# ### Joining the dataframes

# %%
# Prep datasets for merging by organizing them by AnimalID and datetimes

aacIn_sorted = aacIn.sort_values(['IntakeDT', 'AnimalID'])
aacOut_sorted = aacOut.sort_values(['OutcomeDT', 'AnimalID'])

aac = pd.merge_asof(
    aacIn_sorted,
    aacOut_sorted,
    by='AnimalID',
    left_on='IntakeDT',
    right_on='OutcomeDT',
    direction='forward',
    allow_exact_matches=True
).dropna(subset=['OutcomeDT'])  # Ensures only matched outcomes remain

# %%
# Check columns

print(aac.columns)
# Out:
# Index(['AnimalID', 'Name_x', 'IntakeDT', 'IntakeType', 'IntakeCondition',
#        'AnimalType_x', 'IntakeSex', 'IntakeAge', 'Breed_x', 'Color_x',
#        'AgeYears_x', 'AgeCategory_x', 'IsMix_x', 'PrimaryBreed_x',
#        'ColorClean_x', 'Name_y', 'OutcomeDT', 'BirthDate', 'OutcomeType',
#        'AnimalType_y', 'OutcomeSex', 'OutcomeAge', 'Breed_y', 'Color_y',
#        'AgeYears_y', 'AgeCategory_y', 'IsMix_y', 'PrimaryBreed_y',
#        'ColorClean_y'],
#       dtype='object')

# %% [markdown]
# Let's investigate how closely matched each column (x vs y) is.

# %%
# Checking how closely columns match

name_match = (aac['Name_x'] == aac['Name_y']).mean()
print(f"Row-wise Name match rate: {name_match:.2f}")

type_match = (aac['AnimalType_x'] == aac['AnimalType_y']).mean()
print(f"Row-wise AnimalType match rate: {type_match:.2f}")

breed_match = (aac['Breed_x'] == aac['Breed_y']).mean()
print(f"Row-wise Breed match rate: {breed_match:.2f}")

color_match = (aac['Color_x'] == aac['Color_y']).mean()
print(f"Row-wise Color match rate: {color_match:.2f}")

age_yr_match = (aac['AgeYears_x'] <= aac['AgeYears_y']).mean()
print(f"Row-wise AgeYears (Intake =< Outcome) rate: {age_yr_match:.2f}")

age_cat_match = (aac['AgeCategory_x'] == aac['AgeCategory_y']).mean()
print(f"Row-wise AgeCategory match rate: {age_cat_match:.2f}")

mix_match = (aac['IsMix_x'] == aac['IsMix_y']).mean()
print(f"Row-wise IsMix match rate: {mix_match:.2f}")

breed1_match = (aac['PrimaryBreed_x'] == aac['PrimaryBreed_y']).mean()
print(f"Row-wise PrimaryBreed match rate: {breed1_match:.2f}")

color2_match = (aac['ColorClean_x'] == aac['ColorClean_y']).mean()
print(f"Row-wise ColorClean match rate: {color2_match:.2f}")
# Out:
# Row-wise Name match rate: 1.00
# Row-wise AnimalType match rate: 1.00
# Row-wise Breed match rate: 1.00
# Row-wise Color match rate: 1.00
# Row-wise AgeYears (Intake =< Outcome) rate: 1.00
# Row-wise AgeCategory match rate: 0.99
# Row-wise IsMix match rate: 1.00
# Row-wise PrimaryBreed match rate: 1.00
# Row-wise ColorClean match rate: 1.00

# %% [markdown]
# Almost all of them match perfectly, which is encouraging!
#
# AgeYears seems to be correct, but AgeCategory is slightly off; however, since Intake Ages were likely guesses to begin with, I can probably just ignore the age-related _x columns (including IntakeAge, AgeYears_x, and AgeCategory_x).

# %%
# Let's just drop those redundant age columns now

aac = aac.drop(columns=['IntakeAge', 'AgeYears_x', 'AgeCategory_x'])
print(aac.columns)
# Out:
# Index(['AnimalID', 'Name_x', 'IntakeDT', 'IntakeType', 'IntakeCondition',
#        'AnimalType_x', 'IntakeSex', 'Breed_x', 'Color_x', 'IsMix_x',
#        'PrimaryBreed_x', 'ColorClean_x', 'Name_y', 'OutcomeDT', 'BirthDate',
#        'OutcomeType', 'AnimalType_y', 'OutcomeSex', 'OutcomeAge', 'Breed_y',
#        'Color_y', 'AgeYears_y', 'AgeCategory_y', 'IsMix_y', 'PrimaryBreed_y',
#        'ColorClean_y'],
#       dtype='object')

# %%
# Check numerical columns for outliers

print(aac.describe())
# Out:
#                             IntakeDT                      OutcomeDT  \
# count                         171489                         171489
# mean   2018-11-08 17:46:25.272991232  2018-11-29 20:07:44.658607616
# min              2013-10-01 07:51:00            2013-10-01 10:39:00
# 25%              2016-02-07 13:00:00            2016-02-24 09:56:00
# 50%              2018-07-18 13:23:00            2018-08-10 16:38:00
# 75%              2021-07-27 17:13:00            2021-08-19 00:00:00
# max              2025-04-09 07:26:00            2025-04-09 14:50:00
# std                              NaN                            NaN
#
#                            BirthDate  AgeYears_y
# count                         171489    171489.0
# mean   2016-10-27 07:54:14.881654272    1.924893
# min              1991-09-22 00:00:00         0.0
# 25%              2014-03-26 00:00:00         0.0
# 50%              2016-11-13 00:00:00         1.0
# 75%              2019-12-19 00:00:00         2.0
# max              2028-05-01 00:00:00        30.0
# std                              NaN    2.842837

# %% [markdown]
# * Okay, most things look okay, but we seem to have a couple anomalies.
# * We also have a BirthDate in 2028, which would be an impressive feat of time travel for an animal
# * A BirthDate in 1991 is feasible, but I will check it in case--1991 to 2013 (at the earliest) would be quite an old animal
# * And again, an age of 30 is feasible, but warrants a little bit of suspicion

# %%
# I also noticed some BirthDates coming after the animals OutcomeDate, which is incorrect

aac.loc[(aac['BirthDate'] > aac['OutcomeDT']), ['AnimalID', 'BirthDate', 'OutcomeDT', 'OutcomeAge']]
# Out:
#        AnimalID  BirthDate           OutcomeDT OutcomeAge
# 17408   A751749 2014-12-12 2014-09-10 17:29:00    0 years
# 28695   A702326 2015-08-29 2015-05-24 17:01:00    0 years
# 29597   A703416 2015-05-29 2015-05-26 16:58:00    0 years
# 32007   A753893 2016-07-12 2015-07-02 11:06:00    1 years
# 32556   A706929 2015-07-06 2015-07-05 14:46:00    0 years
# 43840   A754280 2016-07-12 2016-04-11 00:00:00    0 years
# 49607   A725472 2020-04-29 2016-07-24 15:54:00    3 years
# 55394   A736114 2016-10-28 2016-10-04 15:13:00    0 years
# 56431   A737397 2016-11-15 2016-11-05 18:16:00    0 years
# 62128   A745085 2017-10-11 2017-03-13 18:11:00    0 years
# 65153   A749253 2017-07-01 2017-05-12 16:43:00    0 years
# 71437   A757376 2019-11-05 2017-09-05 19:25:00    2 years
# 85724   A725472 2020-04-29 2018-07-11 16:40:00    1 years
# 90441   A757376 2019-11-05 2018-10-21 19:01:00    1 years
# 91547   A783723 2023-02-07 2018-11-12 11:53:00    4 years
# 95375   A788866 2019-12-06 2019-02-15 12:02:00    0 years
# 95383   A788874 2019-12-06 2019-02-14 17:13:00    0 years
# 96016   A725472 2020-04-29 2019-02-26 14:34:00    1 years
# 102354  A797495 2020-12-16 2019-06-15 12:44:00    1 years
# 104065  A799589 2019-10-15 2019-07-16 19:04:00    0 years
# 107906  A804197 2019-09-12 2019-09-11 18:24:00    0 years
# 116419  A871020 2021-12-16 2020-03-17 12:04:00    1 years
# 121587  A825065 2021-10-01 2020-10-31 11:05:00    0 years
# 125933  A834123 2021-07-04 2021-05-14 13:09:00    0 years
# 126989  A853991 2021-09-28 2021-06-15 16:07:00    0 years
# 135616  A850078 2022-05-07 2022-01-19 16:10:00    0 years
# 141070  A860186 2022-07-08 2022-06-28 19:18:00    0 years
# 151410  A881120 2024-03-17 2023-05-21 15:23:00    0 years
# 158542  A896364 2024-01-15 2024-01-14 16:42:00    0 years
# 158744  A896867 2024-03-18 2024-01-29 11:53:00    0 years
# 171830  A922017 2028-05-01 2025-03-05 13:00:00    3 years

# %%
# One of these, at least, is an obvious error (BirthDate in 2028). Assuming the animal's AgeYears entry is correct, I correct the value

aac.loc[171830, 'BirthDate'] = pd.to_datetime('2021-05-01')

# There is still the matter of the other 30, however

# %%
# I am uncertain what to do with the rest, but given that I'm not sure what pieces are incorrect, and it is only 30 rows, I'm going to drop them

aac = aac[aac['BirthDate'] <= aac['OutcomeDT']]

print(aac.describe())
# Out:
#                             IntakeDT                      OutcomeDT  \
# count                         171459                         171459
# mean   2018-11-08 17:42:41.083407616  2018-11-29 20:07:43.260371456
# min              2013-10-01 07:51:00            2013-10-01 10:39:00
# 25%              2016-02-07 12:25:00            2016-02-24 08:07:30
# 50%              2018-07-18 13:17:00            2018-08-10 16:15:00
# 75%              2021-07-27 21:01:00            2021-08-19 04:02:30
# max              2025-04-09 07:26:00            2025-04-09 14:50:00
# std                              NaN                            NaN
#
#                            BirthDate  AgeYears_y
# count                         171459    171459.0
# mean   2016-10-27 03:05:13.243399424    1.925142
# min              1991-09-22 00:00:00         0.0
# 25%              2014-03-26 00:00:00         0.0
# 50%              2016-11-13 00:00:00         1.0
# 75%              2019-12-19 00:00:00         2.0
# max              2025-04-02 00:00:00        30.0
# std                              NaN    2.842995

# %%
# Let's look at the rest of BirthDate and AgeYears together, since they directly correspond
# Calculating age from BirthDate--do they match?

aac['BirthAge'] = (aac['OutcomeDT'] - aac['BirthDate']).dt.days / 365.25

# Check the difference between the two

aac['AgeDiff'] = aac['BirthAge'] - aac['AgeYears_y']

# Summary of age differences
print(aac['AgeDiff'].describe())

# Check for outliers
mismatches = aac[aac['AgeDiff'].abs() > 1.5]  # Difference larger than 1 year
mismatches[['AnimalID', 'AnimalType_x', 'BirthDate', 'OutcomeDT', 'AgeYears_y', 'BirthAge', 'AgeDiff']]
# Out:
# count    171459.0
# mean     0.164101
# std      0.230384
# min          -1.0
# 25%      0.013005
# 50%      0.103354
# 75%      0.260096
# max           7.0
# Name: AgeDiff, dtype: Float64
#        AnimalID AnimalType_x  BirthDate           OutcomeDT  AgeYears_y  \
# 170972  A923553          Dog 2022-02-04 2025-02-21 11:57:00           1
# 172838  A927996          Cat 2017-04-05 2025-04-05 15:32:00           1
#
#         BirthAge   AgeDiff
# 170972  3.047228  2.047228
# 172838  8.000000       7.0

# %%
# Only 2 significant mismatches--whew. For these, I will manually adjust the AgeYears_y value

aac.loc[170972, 'AgeYears_y'] = 3
aac.loc[172838, 'AgeYears_y'] = 8

# %%
# Check that it worked

mismatches = aac[aac['AgeDiff'].abs() > 1.5]  # The same rows we looked at before
mismatches[['AnimalID', 'AnimalType_x', 'BirthDate', 'OutcomeDT', 'AgeYears_y', 'BirthAge', 'AgeDiff']]
# Out:
#        AnimalID AnimalType_x  BirthDate           OutcomeDT  AgeYears_y  \
# 170972  A923553          Dog 2022-02-04 2025-02-21 11:57:00           3
# 172838  A927996          Cat 2017-04-05 2025-04-05 15:32:00           8
#
#         BirthAge   AgeDiff
# 170972  3.047228  2.047228
# 172838  8.000000       7.0

# %%
# So now the ages and birthdates should align, it appears that 1991 BirthDate does agree with the animal's age
# Let's look at some very early BirthDates and very old animals

aac.loc[(aac['BirthDate'] < pd.to_datetime('1995-01-01')), ['AnimalID', 'AnimalType_x', 'PrimaryBreed_x', 'BirthDate', 'OutcomeDT', 'OutcomeAge']]
# Out:
#        AnimalID AnimalType_x        PrimaryBreed_x  BirthDate  \
# 3465    A214991          Cat    Domestic Shorthair 1994-03-01
# 5198    A559240          Dog      Miniature Poodle 1994-10-21
# 5218    A671488          Cat    Domestic Shorthair 1994-01-25
# 6096    A672841          Cat  Domestic Medium Hair 1994-02-17
# 12914   A682010          Cat    Domestic Shorthair 1992-06-25
# 19199   A689957          Cat  Domestic Medium Hair 1994-10-11
# 20462   A261770          Cat    Domestic Shorthair 1994-11-07
# 21128   A692485          Cat    Domestic Shorthair 1994-11-21
# 22067   A693678          Cat    Domestic Shorthair 1994-12-12
# 37279   A712996          Cat               Siamese 1993-10-03
# 45323   A723385          Cat    Domestic Shorthair 1994-04-03
# 58445   A740127         Bird              Cockatoo 1991-12-11
# 83791   A773881          Dog       German Shepherd 1994-06-07
# 133057  A842878         Bird                 Macaw 1991-09-22
# 138073  A855081     Wildlife              Tortoise 1994-04-14
#
#                  OutcomeDT OutcomeAge
# 3465   2013-12-14 13:28:00   19 years
# 5198   2014-01-25 12:02:00   19 years
# 5218   2014-09-17 11:18:00   20 years
# 6096   2014-02-20 14:52:00   20 years
# 12914  2014-06-25 13:26:00   22 years
# 19199  2014-10-11 17:58:00   20 years
# 20462  2014-11-07 15:51:00   20 years
# 21128  2014-11-25 16:04:00   20 years
# 22067  2014-12-13 16:38:00   20 years
# 37279  2015-10-01 13:46:00   22 years
# 45323  2016-04-03 15:48:00   22 years
# 58445  2016-12-16 00:00:00   25 years
# 83791  2018-06-07 15:33:00   24 years
# 133057 2021-10-30 15:07:00   30 years
# 138073 2022-04-14 10:53:00   28 years

# %% [markdown]
# Cats can get pretty old, so that looks fine to me. One dog making it to 19 isn't shocking either, and birds and tortoises both live long lives. These look correct!

# %%
# Looking at animals with old listed ages

aac.loc[(aac['AgeYears_y'] > 20), ['AnimalID', 'AnimalType_x', 'PrimaryBreed_x', 'IsMix_x', 'BirthDate', 'OutcomeDT', 'AgeYears_y', 'OutcomeType']]
# Out:
#        AnimalID AnimalType_x        PrimaryBreed_x  IsMix_x  BirthDate  \
# 12914   A682010          Cat    Domestic Shorthair     True 1992-06-25
# 37279   A712996          Cat               Siamese     True 1993-10-03
# 45323   A723385          Cat    Domestic Shorthair     True 1994-04-03
# 58445   A740127         Bird              Cockatoo    False 1991-12-11
# 61872   A744732          Cat    Domestic Shorthair     True 1995-03-06
# 83791   A773881          Dog       German Shepherd     True 1994-06-07
# 96373   A790169     Wildlife                   Bat    False 1998-03-05
# 119393  A821351          Cat  Domestic Medium Hair    False 1998-08-10
# 119961  A498745          Dog           Wolf Hybrid     True 1997-08-31
# 133057  A842878         Bird                 Macaw    False 1991-09-22
# 134929  A848731          Cat    Domestic Shorthair    False 1999-12-27
# 138073  A855081     Wildlife              Tortoise    False 1994-04-14
# 166366  A912407     Wildlife              Tortoise    False 1999-08-30
#
#                  OutcomeDT  AgeYears_y      OutcomeType
# 12914  2014-06-25 13:26:00          22  Return to Owner
# 37279  2015-10-01 13:46:00          22  Return to Owner
# 45323  2016-04-03 15:48:00          22  Return to Owner
# 58445  2016-12-16 00:00:00          25         Transfer
# 61872  2017-03-06 17:09:00          22       Euthanasia
# 83791  2018-06-07 15:33:00          24  Return to Owner
# 96373  2019-03-06 09:55:00          21       Euthanasia
# 119393 2020-08-10 13:08:00          22  Return to Owner
# 119961 2020-08-31 12:36:00          23       Euthanasia
# 133057 2021-10-30 15:07:00          30         Transfer
# 134929 2021-12-27 15:52:00          22       Euthanasia
# 138073 2022-04-14 10:53:00          28  Return to Owner
# 166366 2024-09-04 17:10:00          25         Transfer

# %% [markdown]
# Again, we have some ancient cats, some birds and tortoises, and then a couple of dogs. The dogs do seem odd to me, but since they are mixed breeds, I think it is feasible (if likely overestimated).
#
# The numerical columns appear to be in order!

# %%
# Also checking for duplicates

print(aac.duplicated().sum())
# Out:
# 0

# %%
# Sanity check time columns as well (do outcome dates actually come after intake dates?)

print((aac['IntakeDT'] > aac['OutcomeDT']).sum())
# Out:
# 0

# %% [markdown]
# Now to remove unhelpful columns.

# %%
# First we list the columns

aac_cols = aac.columns
print(aac_cols)
# Out:
# Index(['AnimalID', 'Name_x', 'IntakeDT', 'IntakeType', 'IntakeCondition',
#        'AnimalType_x', 'IntakeSex', 'Breed_x', 'Color_x', 'IsMix_x',
#        'PrimaryBreed_x', 'ColorClean_x', 'Name_y', 'OutcomeDT', 'BirthDate',
#        'OutcomeType', 'AnimalType_y', 'OutcomeSex', 'OutcomeAge', 'Breed_y',
#        'Color_y', 'AgeYears_y', 'AgeCategory_y', 'IsMix_y', 'PrimaryBreed_y',
#        'ColorClean_y', 'BirthAge', 'AgeDiff'],
#       dtype='object')

# %%
full_clean_aac = aac.drop(columns = ['Name_x', 'AnimalType_x', 'Breed_x', 'Color_x', 'IsMix_x',
                                     'PrimaryBreed_x', 'ColorClean_x', 'BirthAge', 'AgeDiff'])

# %%
col_rename = {
    'Name_y' : 'Name',
    'AnimalType_y' : 'AnimalType',
    'Breed_y' : 'BreedOG',
    'Color_y' : 'ColorOG',
    'AgeYears_y' : 'AgeYears',
    'AgeCategory_y' : 'AgeCategory',
    'IsMix_y' : 'IsMix',
    'PrimaryBreed_y' : 'PrimaryBreed',
    'ColorClean_y' : 'ColorClean'
}

full_clean_aac.rename(columns = col_rename, inplace=True)
full_clean_aac.columns
# Out:
# Index(['AnimalID', 'IntakeDT', 'IntakeType', 'IntakeCondition', 'IntakeSex',
#        'Name', 'OutcomeDT', 'BirthDate', 'OutcomeType', 'AnimalType',
#        'OutcomeSex', 'OutcomeAge', 'BreedOG', 'ColorOG', 'AgeYears',
#        'AgeCategory', 'IsMix', 'PrimaryBreed', 'ColorClean'],
#       dtype='object')

# %%
# Reorder the remaining columns for clarity

full_aac_order = ['AnimalID', 'Name', 'AnimalType', 'BreedOG', 'PrimaryBreed', 'IsMix', 'ColorOG', 'ColorClean',
                  'BirthDate', 'OutcomeAge', 'AgeYears', 'AgeCategory', 'IntakeSex', 'IntakeType', 
                  'IntakeCondition', 'OutcomeType', 'OutcomeSex', 'IntakeDT', 'OutcomeDT']

full_clean_aac = full_clean_aac[full_aac_order + [col for col in full_clean_aac.columns if col not in full_aac_order]]

full_clean_aac.head()
# Out:
#   AnimalID    Name AnimalType                       BreedOG  \
# 0  A521520    Nina        Dog  Border Terrier/Border Collie
# 1  A664235     nan        Cat        Domestic Shorthair Mix
# 2  A664236     nan        Cat        Domestic Shorthair Mix
# 3  A664237     nan        Cat        Domestic Shorthair Mix
# 4  A664233  Stevie        Dog                  Pit Bull Mix
#
#                 PrimaryBreed IsMix       ColorOG ColorClean  BirthDate  \
# 0             Border Terrier  True     White/Tan      White 2006-09-07
# 1         Domestic Shorthair  True  Orange/White     Orange 2013-09-24
# 2         Domestic Shorthair  True  Orange/White     Orange 2013-09-24
# 3         Domestic Shorthair  True  Orange/White     Orange 2013-09-24
# 4  American Pit Bull Terrier  True    Blue/White       Blue 2010-09-30
#
#   OutcomeAge  AgeYears AgeCategory      IntakeSex IntakeType IntakeCondition  \
# 0    7 years         7       Adult  Spayed Female      Stray          Normal
# 1     1 week         0      Infant        Unknown      Stray          Normal
# 2     1 week         0      Infant        Unknown      Stray          Normal
# 3     1 week         0      Infant        Unknown      Stray          Normal
# 4    3 years         3       Adult  Intact Female      Stray         Injured
#
#        OutcomeType     OutcomeSex            IntakeDT           OutcomeDT
# 0  Return to Owner  Spayed Female 2013-10-01 07:51:00 2013-10-01 15:39:00
# 1         Transfer        Unknown 2013-10-01 08:33:00 2013-10-01 10:39:00
# 2         Transfer        Unknown 2013-10-01 08:33:00 2013-10-01 10:44:00
# 3         Transfer        Unknown 2013-10-01 08:33:00 2013-10-01 10:44:00
# 4       Euthanasia  Intact Female 2013-10-01 08:53:00 2013-10-01 15:33:00

# %% [markdown]
# ### Saving Final, Cleaned Dataframes

# %%
print(aacIn.columns)

print(aacOut.columns)
# Out:
# Index(['AnimalID', 'Name', 'IntakeDT', 'IntakeType', 'IntakeCondition',
#        'AnimalType', 'IntakeSex', 'IntakeAge', 'Breed', 'Color', 'AgeYears',
#        'AgeCategory', 'IsMix', 'PrimaryBreed', 'ColorClean'],
#       dtype='object')
# Index(['AnimalID', 'Name', 'OutcomeDT', 'BirthDate', 'OutcomeType',
#        'AnimalType', 'OutcomeSex', 'OutcomeAge', 'Breed', 'Color', 'AgeYears',
#        'AgeCategory', 'IsMix', 'PrimaryBreed', 'ColorClean'],
#       dtype='object')

# %%
intakes = aacIn[['AnimalID', 'Name', 'IntakeDT', 'IntakeType', 'IntakeCondition', 'IntakeSex', 'AnimalType', 
                 'Breed', 'PrimaryBreed', 'IsMix', 'Color', 'ColorClean', 'IntakeAge', 'AgeYears', 'AgeCategory']]

outcomes = aacOut[['AnimalID', 'Name', 'OutcomeDT', 'OutcomeType', 'AnimalType', 'Breed', 'PrimaryBreed', 'IsMix',
                  'Color', 'ColorClean', 'OutcomeSex', 'BirthDate', 'OutcomeAge', 'AgeYears', 'AgeCategory']]

# %%
# Check intakes one last time

intakes.head()
# Out:
#   AnimalID    Name            IntakeDT IntakeType IntakeCondition  \
# 0  A521520    Nina 2013-10-01 07:51:00      Stray          Normal
# 1  A664235     nan 2013-10-01 08:33:00      Stray          Normal
# 2  A664236     nan 2013-10-01 08:33:00      Stray          Normal
# 3  A664237     nan 2013-10-01 08:33:00      Stray          Normal
# 4  A664233  Stevie 2013-10-01 08:53:00      Stray         Injured
#
#        IntakeSex AnimalType                         Breed  \
# 0  Spayed Female        Dog  Border Terrier/Border Collie
# 1        Unknown        Cat        Domestic Shorthair Mix
# 2        Unknown        Cat        Domestic Shorthair Mix
# 3        Unknown        Cat        Domestic Shorthair Mix
# 4  Intact Female        Dog                  Pit Bull Mix
#
#                 PrimaryBreed  IsMix         Color ColorClean IntakeAge  \
# 0             Border Terrier   True     White/Tan      White   7 years
# 1         Domestic Shorthair   True  Orange/White     Orange    1 week
# 2         Domestic Shorthair   True  Orange/White     Orange    1 week
# 3         Domestic Shorthair   True  Orange/White     Orange    1 week
# 4  American Pit Bull Terrier   True    Blue/White       Blue   3 years
#
#    AgeYears AgeCategory
# 0         7       Adult
# 1         0      Infant
# 2         0      Infant
# 3         0      Infant
# 4         3       Adult

# %%
# As well as outcomes

outcomes.head()
# Out:
#   AnimalID      Name           OutcomeDT      OutcomeType AnimalType  \
# 0  A882831  Hamilton 2023-07-01 18:12:00         Adoption        Cat
# 1  A794011     Chunk 2019-05-08 18:20:00  Return to Owner        Cat
# 2  A776359     Gizmo 2018-07-18 16:02:00         Adoption        Dog
# 3  A821648       nan 2020-08-16 11:38:00       Euthanasia   Wildlife
# 4  A720371     Moose 2016-02-13 17:59:00         Adoption        Dog
#
#                                 Breed        PrimaryBreed  IsMix  \
# 0              Domestic Shorthair Mix  Domestic Shorthair   True
# 1              Domestic Shorthair Mix  Domestic Shorthair   True
# 2             Chihuahua Shorthair Mix           Chihuahua   True
# 3                             Raccoon             Raccoon  False
# 4  Anatol Shepherd/Labrador Retriever  Anatolian Shepherd   True
#
#                Color   ColorClean     OutcomeSex  BirthDate OutcomeAge  \
# 0        Black/White  Black/White  Neutered Male 2023-03-25   3 months
# 1  Brown Tabby/White  Brown Tabby  Neutered Male 2017-05-02    2 years
# 2        White/Brown        White  Neutered Male 2017-07-12     1 year
# 3               Gray         Gray        Unknown 2019-08-16     1 year
# 4               Buff         Buff  Neutered Male 2015-10-08   4 months
#
#    AgeYears AgeCategory
# 0         0      Infant
# 1         2       Young
# 2         1       Young
# 3         1       Young
# 4         0      Infant

# %%
# Final saves!

intakes.to_csv('../Data/Clean/intakes_clean.csv', index=False)
outcomes.to_csv('../Data/Clean/outcomes_clean.csv', index = False)
full_clean_aac.to_csv('../Data/Clean/joined_clean.csv', index = False)

# %% [markdown]
# # Concluding

# %% [markdown]
# ## For EDA
#
# ### Features to Possibly Create or Alter:
#
# * Fixed in shelter column
# * Time in shelter
# * Possibly split sex from fixed status
# * Outcome success?
# * Basic color categories (brown, blue, tan...)
# * Simplify breeds
#
# ### Groupings to Evaluate:
#
# * Outcome by Breed/Age/Sex
# * Length of Stay by IntakeType/Condition/Breed/Age/Sex
# * Outcome by Intake Condition
# * Seasonal trends in intake and outcome types, Seasonal trends in adoptions
